# %% [markdown]
# <div style="text-align: center;">
#     <h3>Applied Data Science Project</h3>
#     <h2><b>Patient Preferences Studies Classification System</b><h2>
#     <h1><b>Design & Test K-Nearest Neighbors Classifier Parameters</b></h1>
#     <h5>Francesco Giuseppe Gillio</h5>
#     <h5>César Augusto Seminario Yrigoyen</h5>
# </div>
#
# <div style="text-align: center;">
#     <img src="https://upload.wikimedia.org/wikipedia/it/4/47/Logo_PoliTo_dal_2021_blu.png" width="250">
# </div>

# %% [markdown]
# https://github.com/adsp-polito/2024-P8-PPS

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # *Drive* **Setup**

# %%
import os
import warnings
warnings.filterwarnings('ignore')

# %%
# Patient Preference Studies Binary Classifier
root = 'PPS-BC'

# %%
path = os.path.join('/content/drive/MyDrive', root)
if not os.path.exists(path):
    os.makedirs(path)

# %%
paths = {
    'input-data': f'{root}/input-data',
    'bert-embeddings': f'{root}/bert-embeddings',
    'notebook-results': f'{root}/notebook-results',
}

# %%
for key, value in paths.items():
    path = os.path.join('/content/drive/MyDrive', value)
    if not os.path.exists(path):
        os.makedirs(path)

# %% [markdown]
# **Notebook Directory Structure**
# ```
# /PPS-BC
# ├── /input-data
# │   ├── logs.txt
# │   ├── clean-articles-2023.csv
# │   ├── raw-articles-2023.csv
# │   └── /cv-splits
# │       ├── /k-fold-2
# │       │   ├── fold-1-test.csv
# │       │   ├── fold-1-train.csv
# │       │   └── ...
# │       ├── /k-fold-3
# │       │   └── ...
# │       ├── /k-fold-5
# │       │   └── ...
# │       └── ...
# ├── /bert-embeddings
# │   ├── logs.txt
# │   ├── /bert-base-uncased
# │   │   ├── abstract-text-classification-token.pkl
# │   │   ├── abstract-text-hidden-states.pkl
# │   │   └── ...
# │   ├── /pubmedbert-base-embeddings
# │   │   └── ...
# │   ├── /S-PubMedBert-MS-MARCO
# │   │   └── ...
# │   └── ...
# └── /notebook-results
#     ├── ...
#     └── /k-nearest-neighbors-params
#         ├── /BiomedNLP-BiomedBERT-base-uncased-abstract
#         │   └── ...
#         └── /pubmedbert-base-embeddings
#             └── ...
# ```

# %% [markdown]
# # **Design & Test** *K-Nearest Neighbors Classifier* **Parameters** for **BiomedNLP-BiomedBERT-base-uncased-abstract**

# %% [markdown]
# ## **Design & Test** *K-Nearest Neighbors Classifier* **Parameters**

# %% [markdown]
# **Requirements**

# %%
import os
import numpy as np
import pandas as pd

from typing import Dict, List, Tuple, Union

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
from itertools import product
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    accuracy_score,
    balanced_accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    matthews_corrcoef,
    fbeta_score,
    roc_auc_score,
    average_precision_score,
    log_loss,
    brier_score_loss
)

# %%
np.random.seed(42)

# %%
device = 'cpu'
device
# Out:
# 'cpu'

# %%
input = f"/content/drive/MyDrive/{paths['input-data']}"

# %%
branch = os.path.join(f"/content/drive/MyDrive/{paths['notebook-results']}", 'k-nearest-neighbors-params')
if not os.path.exists(branch):
    os.makedirs(branch)

# %% [markdown]
# *BiomedNLP-BiomedBERT-base-uncased-abstract*

# %%
output = os.path.join(branch, 'BiomedNLP-BiomedBERT-base-uncased-abstract')
if not os.path.exists(output):
    os.makedirs(output)

# %%
with open(os.path.join(output, 'logs.txt'), 'w') as file:
    pass

# %% [markdown]
# **BERT-Base Model:** *BiomedNLP-BiomedBERT-base-uncased-abstract*

# %%
model = os.path.join(f"/content/drive/MyDrive/{paths['bert-embeddings']}", 'BiomedNLP-BiomedBERT-base-uncased-abstract')

# %% [markdown]
# **T&A Link:** *vector-weighted-average-2080-hidden-states*

# %%
link = 'vector-weighted-average-2080-hidden-states.pkl'

# %% [markdown]
# **K-Nearest Neighbors Classifier Parameters**

# %%
params = {
    'n_neighbors': [
        3, 5, 8, 13, 21
    ],
    'metric': [
        'euclidean',
        'manhattan',
        'minkowski'
    ]
}

# %% [markdown]
# **Evaluation Metrics**

# %%
def compute(
    y_true: np.ndarray,
    y_pred: np.ndarray,
    y_prob: np.ndarray
) -> Dict[str, float]:
    """
    compute classification metrics for predictions

    args:
        y_true (np.ndarray): ground truth labels for the test set
        y_pred (np.ndarray): predictions for the test set
        y_prob (np.ndarray): probabilities for the positive class

    returns:
        Dict[str, float]: a dictionary with classification metrics
    """
    metrics = {
        'F2-PPS': fbeta_score(
            y_true, y_pred, beta=2, pos_label=1
        ),  # F2-Score (Class 1)
        'F1-PPS': f1_score(
            y_true, y_pred, pos_label=1
        ),  # F1-Score (Class 1)

        'TPR': recall_score(
            y_true, y_pred, pos_label=1
        ),  # True Positive Rate (TPR)
        'FNR': 1 - recall_score(
            y_true, y_pred, pos_label=1
        ),  # False Negative Rate (FNR)
        'PPV': precision_score(
            y_true, y_pred, pos_label=1
        ),  # Positive Predictive Value (PPV)
        'FDR': 1 - precision_score(
            y_true, y_pred, pos_label=1
        ),  # False Discovery Rate (FDR)

        'AUC-PR': average_precision_score(
            y_true, y_prob
        ),  # Area Under Precision-Recall Curve (AUC-PR)
        'BA': balanced_accuracy_score(
            y_true, y_pred
        ),  # Balanced Accuracy (BA)
        'AUC-ROC': roc_auc_score(
            y_true, y_prob
        ),  # Area Under ROC Curve (AUC-ROC)

        'G-Mean': np.sqrt(
            recall_score(
                y_true, y_pred, pos_label=1
            ) *
            recall_score(
                y_true, y_pred, pos_label=0
            )
        ),  # Geometric Mean (G-Mean)
        'MCC': matthews_corrcoef(
            y_true, y_pred
        ),  # Matthews Correlation Coefficient (MCC)

        'Log-Loss': log_loss(
            y_true, y_prob
        ),  # Log-Loss
        'BS': brier_score_loss(
            y_true, y_prob
        ),  # Brier Score

        'TNR': recall_score(
            y_true, y_pred, pos_label=0
        ),  # True Negative Rate (TNR)
        'FPR': 1 - recall_score(
            y_true, y_pred, pos_label=0
        ),  # False Positive Rate (FPR)
        'NPV': precision_score(
            y_true, y_pred, pos_label=0
        ),  # Negative Predictive Value (NPV)
        'FOR': 1 - precision_score(
            y_true, y_pred, pos_label=0
        ),  # False Omission Rate (FOR)

        'Accuracy': accuracy_score(
            y_true, y_pred
        ),  # Accuracy
        'Weighted F1-Score': f1_score(
            y_true, y_pred, average='weighted'
        ),  # Weighted F1-Score
        'Weighted Precision': precision_score(
            y_true, y_pred, average='weighted'
        ),  # Weighted Precision
        'Weighted Recall': recall_score(
            y_true, y_pred, average='weighted'
        ),  # Weighted Recall
        'Macro F1-Score': f1_score(
            y_true, y_pred, average='macro'
        ),  # Macro F1-Score
        'Macro Precision': precision_score(
            y_true, y_pred, average='macro'
        ),  # Macro Precision
        'Macro Recall': recall_score(
            y_true, y_pred, average='macro'
        )   # Macro Recall
    }
    return metrics

# %% [markdown]
# *Evaluation Metrics Sorting Criteria*

# %%
order = [
    'F2-PPS', # F2-Score (Class 1 - Patient Preference Studies)
    'F1-PPS', # F1-Score (Class 1 - Patient Preference Studies)
    'TPR',    # True Positive Rate
    'PPV',    # Positive Predictive Value
    'AUC-PR', # Area Under Precision-Recall Curve
    'BA',     # Balanced Accuracy
    'AUC-ROC' # Area Under ROC Curve
]

# %% [markdown]
# **Binary Classification**

# %%
def evaluate(
    dir: str,
    loc: str,
    case: str,
    input: str,
    output: str,
    params: Dict[str, List[Union[Tuple[int, ...], str]]],
    order: List[str]
) -> pd.DataFrame:
    """
    evaluate k-nearest neighbors classifier parameters for class prediction

    args:
        dir (str): path to the directory with bert-base model
        loc (str): path to file with title-abstract link (.pkl file)
        case (str): cross-validation case identifier (e.g. 'k-fold-2' or 'k-fold-3')
        input (str): path to the input folder with data and splits
        output (str): path to output folder to store logs
        params (Dict[str, List[Union[Tuple[int, ...], str]]]): a dictionary of params
        order (List[str]): evaluation metrics sorting criteria

    returns:
        pd.DataFrame: DataFrame with evaluation results
    """

    def add(
        by: str,
        to: str
    ) -> pd.DataFrame:
        """
        add an embeddings column to the input split file

        args:
            by (str): path to the .pkl file with embeddings
            to (str): path to the .csv split file
        """
        dataset = pd.read_pickle(by)
        frame = pd.read_csv(to)
        embeddings = [
            column for column in dataset.columns
            if column not in ['title', 'abstract', 'label']
        ]
        data = frame.merge(
            dataset[['title', 'abstract', 'label'] + embeddings],
            on=['title', 'abstract', 'label'],
            how='left'
        )
        return data

    def collect(
        dir: str
    ) -> List[Tuple[str, str]]:
        """
        collect train and test file pairs from the directory

        args:
            dir (str): path to the directory with train/test files

        returns:
            List[Tuple[str, str]]: list of (train file, test file) tuples
        """
        files = {'train': [], 'test': []}
        for idx, _, walk in os.walk(dir):
            for file in walk:
                if file.endswith('.csv'):
                    if 'train' in file:
                        files['train'].append(
                            os.path.join(idx, file)
                        )
                    elif 'test' in file:
                        files['test'].append(
                            os.path.join(idx, file)
                        )
        files['train'].sort()
        files['test'].sort()
        return list(zip(files['train'], files['test']))

    log = f'\n{case}\n'
    with open(os.path.join(output, 'logs.txt'), 'a') as file:
        file.write(log + '\n')
    print(log)
    combinations = [
        {'n_neighbors': x,
         'metric': y}
        for x, y in product(
             params['n_neighbors'],
             params['metric']
        )
    ]
    results = list()
    for params in combinations:
        log = f'-' * 50 + '\n' + f'K-Nearest Neighbors Classifier Parameters: {params}\n' + f'-' * 50 + '\n'
        with open(os.path.join(output, 'logs.txt'), 'a') as file:
            file.write(log + '\n')
        print(log)
        averages = {}
        route = os.path.join(input, 'cv-splits', case)
        for files in collect(route):
            log = f'classifier execution on:\n- train file: {os.path.basename(files[0])}\n- test file: {os.path.basename(files[1])}'
            with open(os.path.join(output, 'logs.txt'), 'a') as file:
                file.write(log + '\n')
            print(log)
            embeddings = os.path.join(dir, loc)
            data_train = add(
                by=embeddings,
                to=files[0]
            )
            data_test = add(
                by=embeddings,
                to=files[1]
            )
            y_train = data_train['label']
            y_test = np.array(data_test['label'].tolist())
            # skip non-embedding columns
            column = [
                column for column in data_train.columns
                if column not in ['label', 'title', 'abstract']
            ][0]
            if not isinstance(data_train[column].values[0], np.ndarray):
                # debug
                print(f'WARNING: {column} not of type np.ndarray')
                continue
            x_train = np.array(data_train[column].tolist())
            x_test = np.array(data_test[column].tolist())
            try:
                knn = KNeighborsClassifier(
                    weights="distance",
                    **params
                )
                pipeline = Pipeline([
                    ('scaler', StandardScaler()),
                    ('classifier', knn)
                ])
                # train
                pipeline.fit(x_train, y_train)
                # test
                y_pred = pipeline.predict(x_test)
                y_prob = pipeline.predict_proba(x_test)
                metrics = compute(
                    y_true=y_test,
                    y_pred=y_pred,
                    y_prob=y_prob[:, 1]
                )
                log = f"F2-PPS: {metrics['F2-PPS']}"
                with open(os.path.join(output, 'logs.txt'), 'a') as file:
                    file.write(log + '\n')
                print(log)
                log = f"F1-PPS: {metrics['F1-PPS']}"
                with open(os.path.join(output, 'logs.txt'), 'a') as file:
                    file.write(log + '\n')
                print(log)
                log = f"TPR: {metrics['TPR']}"
                with open(os.path.join(output, 'logs.txt'), 'a') as file:
                    file.write(log + '\n')
                print(log)
                log = f"PPV: {metrics['PPV']}"
                with open(os.path.join(output, 'logs.txt'), 'a') as file:
                    file.write(log + '\n')
                print(log)
            except Exception as e:
                # debug
                print(f'ERROR for {column}: {e}')
                continue
            if str(params) not in averages:
                averages[str(params)] = {
                    key: [] for key in metrics
                }
            for key, value in metrics.items():
                averages[str(params)][key].append(value)
        for param, scores in averages.items():
            mean = {
                key: np.mean(values)
                for key, values in scores.items()
            }
            results.append({
                'K-Nearest Neighbors Parameters': param,
                **mean
            })
            log = f"\nF2-PPS: {mean['F2-PPS']}"
            with open(os.path.join(output, 'logs.txt'), 'a') as file:
                file.write(log + '\n')
            print(log)
            log = f"F1-PPS: {mean['F1-PPS']}"
            with open(os.path.join(output, 'logs.txt'), 'a') as file:
                file.write(log + '\n')
            print(log)
            log = f"TPR: {mean['TPR']}"
            with open(os.path.join(output, 'logs.txt'), 'a') as file:
                file.write(log + '\n')
            print(log)
            log = f"PPV: {mean['PPV']}"
            with open(os.path.join(output, 'logs.txt'), 'a') as file:
                file.write(log + '\n')
            print(log)
    data = pd.DataFrame(results)
    data = data.sort_values(
        by=order,
        ascending=[False] * len(order)
    )
    return data

# %% [markdown]
# *Fibonacci Sequence:* **[2, 3, 5, 8, 13, 21]**
#
# Splits: **[2 + 3 + 21]** & **[5 + 8 + 13]**
#
# *Split into 2 blocks of 26 iterations for* **M** *configurations, with* **M = 15** *parameter combinations*
#
# *Computational effort per split:* **Mx26 = 15x26=390** *iterations on* **1.215** *data points each*

# %%
for seed in [2, 3, 21]:
    print('-' * 50)
    print(f'seed: {seed}\n' + '-' * 50)
    results = evaluate(
        dir = model,
        loc = link,
        case = f'k-fold-{seed}',
        input = input,
        output = output,
        params = params,
        order = order
    )
    results.to_csv(os.path.join(output, f'k-fold-{seed}-results.csv'), index=False)
# Out:
# --------------------------------------------------
# seed: 2
# --------------------------------------------------
#
# k-fold-2
#
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 3, 'metric': 'euclidean'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.8225806451612904
# F1-PPS: 0.7418181818181818
# TPR: 0.8869565217391304
# PPV: 0.6375
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.8866995073891626
# F1-PPS: 0.8089887640449438
# TPR: 0.9473684210526315
# PPV: 0.7058823529411765
#
# F2-PPS: 0.8546400762752264
# F1-PPS: 0.7754034729315629
# TPR: 0.917162471395881
# PPV: 0.6716911764705882
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 3, 'metric': 'manhattan'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.8346839546191248
# F1-PPS: 0.7573529411764706
# TPR: 0.8956521739130435
# PPV: 0.6560509554140127
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.8780487804878049
# F1-PPS: 0.7912087912087912
# TPR: 0.9473684210526315
# PPV: 0.6792452830188679
#
# F2-PPS: 0.8563663675534648
# F1-PPS: 0.7742808661926308
# TPR: 0.9215102974828375
# PPV: 0.6676481192164403
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 3, 'metric': 'minkowski'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.8225806451612904
# F1-PPS: 0.7418181818181818
# TPR: 0.8869565217391304
# PPV: 0.6375
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.8866995073891626
# F1-PPS: 0.8089887640449438
# TPR: 0.9473684210526315
# PPV: 0.7058823529411765
#
# F2-PPS: 0.8546400762752264
# F1-PPS: 0.7754034729315629
# TPR: 0.917162471395881
# PPV: 0.6716911764705882
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 5, 'metric': 'euclidean'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.8467741935483871
# F1-PPS: 0.7636363636363637
# TPR: 0.9130434782608695
# PPV: 0.65625
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.8717105263157895
# F1-PPS: 0.7969924812030075
# TPR: 0.9298245614035088
# PPV: 0.6973684210526315
#
# F2-PPS: 0.8592423599320883
# F1-PPS: 0.7803144224196856
# TPR: 0.9214340198321891
# PPV: 0.6768092105263157
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 5, 'metric': 'manhattan'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.8440514469453376
# F1-PPS: 0.7581227436823105
# TPR: 0.9130434782608695
# PPV: 0.6481481481481481
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.8609271523178808
# F1-PPS: 0.7938931297709924
# TPR: 0.9122807017543859
# PPV: 0.7027027027027027
#
# F2-PPS: 0.8524892996316091
# F1-PPS: 0.7760079367266515
# TPR: 0.9126620900076277
# PPV: 0.6754254254254255
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 5, 'metric': 'minkowski'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.8467741935483871
# F1-PPS: 0.7636363636363637
# TPR: 0.9130434782608695
# PPV: 0.65625
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.8717105263157895
# F1-PPS: 0.7969924812030075
# TPR: 0.9298245614035088
# PPV: 0.6973684210526315
#
# F2-PPS: 0.8592423599320883
# F1-PPS: 0.7803144224196856
# TPR: 0.9214340198321891
# PPV: 0.6768092105263157
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 8, 'metric': 'euclidean'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.840064620355412
# F1-PPS: 0.7591240875912408
# TPR: 0.9043478260869565
# PPV: 0.6540880503144654
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.8770491803278688
# F1-PPS: 0.7985074626865671
# TPR: 0.9385964912280702
# PPV: 0.6948051948051948
#
# F2-PPS: 0.8585569003416404
# F1-PPS: 0.778815775138904
# TPR: 0.9214721586575134
# PPV: 0.67444662255983
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 8, 'metric': 'manhattan'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.8564437194127243
# F1-PPS: 0.7835820895522388
# TPR: 0.9130434782608695
# PPV: 0.6862745098039216
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.8688524590163934
# F1-PPS: 0.7910447761194029
# TPR: 0.9298245614035088
# PPV: 0.6883116883116883
#
# F2-PPS: 0.8626480892145589
# F1-PPS: 0.7873134328358209
# TPR: 0.9214340198321891
# PPV: 0.687293099057805
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 8, 'metric': 'minkowski'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.840064620355412
# F1-PPS: 0.7591240875912408
# TPR: 0.9043478260869565
# PPV: 0.6540880503144654
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.8770491803278688
# F1-PPS: 0.7985074626865671
# TPR: 0.9385964912280702
# PPV: 0.6948051948051948
#
# F2-PPS: 0.8585569003416404
# F1-PPS: 0.778815775138904
# TPR: 0.9214721586575134
# PPV: 0.67444662255983
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 13, 'metric': 'euclidean'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.8576051779935275
# F1-PPS: 0.7765567765567766
# TPR: 0.9217391304347826
# PPV: 0.6708860759493671
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.8978583196046128
# F1-PPS: 0.8226415094339623
# TPR: 0.956140350877193
# PPV: 0.7218543046357616
#
# F2-PPS: 0.8777317487990701
# F1-PPS: 0.7995991429953695
# TPR: 0.9389397406559878
# PPV: 0.6963701902925643
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 13, 'metric': 'manhattan'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.8713355048859935
# F1-PPS: 0.7955390334572491
# TPR: 0.9304347826086956
# PPV: 0.6948051948051948
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.8828382838283828
# F1-PPS: 0.8106060606060606
# TPR: 0.9385964912280702
# PPV: 0.7133333333333334
#
# F2-PPS: 0.8770868943571881
# F1-PPS: 0.8030725470316549
# TPR: 0.9345156369183829
# PPV: 0.7040692640692641
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 13, 'metric': 'minkowski'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.8576051779935275
# F1-PPS: 0.7765567765567766
# TPR: 0.9217391304347826
# PPV: 0.6708860759493671
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.8978583196046128
# F1-PPS: 0.8226415094339623
# TPR: 0.956140350877193
# PPV: 0.7218543046357616
#
# F2-PPS: 0.8777317487990701
# F1-PPS: 0.7995991429953695
# TPR: 0.9389397406559878
# PPV: 0.6963701902925643
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 21, 'metric': 'euclidean'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.8717105263157895
# F1-PPS: 0.8060836501901141
# TPR: 0.9217391304347826
# PPV: 0.7162162162162162
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.8961474036850922
# F1-PPS: 0.8392156862745098
# TPR: 0.9385964912280702
# PPV: 0.7588652482269503
#
# F2-PPS: 0.8839289650004408
# F1-PPS: 0.8226496682323119
# TPR: 0.9301678108314264
# PPV: 0.7375407322215832
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 21, 'metric': 'manhattan'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.8770491803278688
# F1-PPS: 0.8075471698113208
# TPR: 0.9304347826086956
# PPV: 0.7133333333333334
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.8803986710963455
# F1-PPS: 0.8153846153846154
# TPR: 0.9298245614035088
# PPV: 0.726027397260274
#
# F2-PPS: 0.8787239257121071
# F1-PPS: 0.8114658925979681
# TPR: 0.9301296720061022
# PPV: 0.7196803652968037
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 21, 'metric': 'minkowski'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.8717105263157895
# F1-PPS: 0.8060836501901141
# TPR: 0.9217391304347826
# PPV: 0.7162162162162162
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.8961474036850922
# F1-PPS: 0.8392156862745098
# TPR: 0.9385964912280702
# PPV: 0.7588652482269503
#
# F2-PPS: 0.8839289650004408
# F1-PPS: 0.8226496682323119
# TPR: 0.9301678108314264
# PPV: 0.7375407322215832
# --------------------------------------------------
# seed: 3
# --------------------------------------------------
#
# k-fold-3
#
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 3, 'metric': 'euclidean'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.8353510895883777
# F1-PPS: 0.745945945945946
# TPR: 0.9078947368421053
# PPV: 0.6330275229357798
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.8880778588807786
# F1-PPS: 0.7978142076502732
# TPR: 0.9605263157894737
# PPV: 0.6822429906542056
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.8716707021791767
# F1-PPS: 0.7912087912087912
# TPR: 0.935064935064935
# PPV: 0.6857142857142857
#
# F2-PPS: 0.8650332168827776
# F1-PPS: 0.77832298160167
# TPR: 0.9344953292321714
# PPV: 0.6669949331014237
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 3, 'metric': 'manhattan'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.843520782396088
# F1-PPS: 0.7624309392265194
# TPR: 0.9078947368421053
# PPV: 0.6571428571428571
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.8859223300970874
# F1-PPS: 0.7934782608695652
# TPR: 0.9605263157894737
# PPV: 0.6759259259259259
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.8759124087591241
# F1-PPS: 0.8
# TPR: 0.935064935064935
# PPV: 0.6990291262135923
#
# F2-PPS: 0.8684518404174332
# F1-PPS: 0.7853030666986949
# TPR: 0.9344953292321714
# PPV: 0.6773659697607918
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 3, 'metric': 'minkowski'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.8353510895883777
# F1-PPS: 0.745945945945946
# TPR: 0.9078947368421053
# PPV: 0.6330275229357798
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.8880778588807786
# F1-PPS: 0.7978142076502732
# TPR: 0.9605263157894737
# PPV: 0.6822429906542056
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.8716707021791767
# F1-PPS: 0.7912087912087912
# TPR: 0.935064935064935
# PPV: 0.6857142857142857
#
# F2-PPS: 0.8650332168827776
# F1-PPS: 0.77832298160167
# TPR: 0.9344953292321714
# PPV: 0.6669949331014237
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 5, 'metric': 'euclidean'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.8663366336633663
# F1-PPS: 0.7954545454545454
# TPR: 0.9210526315789473
# PPV: 0.7
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.9101941747572816
# F1-PPS: 0.8152173913043478
# TPR: 0.9868421052631579
# PPV: 0.6944444444444444
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.8684863523573201
# F1-PPS: 0.813953488372093
# TPR: 0.9090909090909091
# PPV: 0.7368421052631579
#
# F2-PPS: 0.8816723869259894
# F1-PPS: 0.8082084750436621
# TPR: 0.9389952153110048
# PPV: 0.7104288499025341
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 5, 'metric': 'manhattan'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.8578431372549019
# F1-PPS: 0.7777777777777778
# TPR: 0.9210526315789473
# PPV: 0.6730769230769231
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.9057971014492754
# F1-PPS: 0.8064516129032258
# TPR: 0.9868421052631579
# PPV: 0.6818181818181818
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.8641975308641975
# F1-PPS: 0.8045977011494253
# TPR: 0.9090909090909091
# PPV: 0.7216494845360825
#
# F2-PPS: 0.8759459231894583
# F1-PPS: 0.7962756972768097
# TPR: 0.9389952153110048
# PPV: 0.6921815298103958
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 5, 'metric': 'minkowski'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.8663366336633663
# F1-PPS: 0.7954545454545454
# TPR: 0.9210526315789473
# PPV: 0.7
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.9101941747572816
# F1-PPS: 0.8152173913043478
# TPR: 0.9868421052631579
# PPV: 0.6944444444444444
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.8684863523573201
# F1-PPS: 0.813953488372093
# TPR: 0.9090909090909091
# PPV: 0.7368421052631579
#
# F2-PPS: 0.8816723869259894
# F1-PPS: 0.8082084750436621
# TPR: 0.9389952153110048
# PPV: 0.7104288499025341
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 8, 'metric': 'euclidean'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.85995085995086
# F1-PPS: 0.7821229050279329
# TPR: 0.9210526315789473
# PPV: 0.6796116504854369
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.9046454767726161
# F1-PPS: 0.8176795580110497
# TPR: 0.9736842105263158
# PPV: 0.7047619047619048
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.8620689655172413
# F1-PPS: 0.8
# TPR: 0.9090909090909091
# PPV: 0.7142857142857143
#
# F2-PPS: 0.8755551007469058
# F1-PPS: 0.7999341543463275
# TPR: 0.9346092503987241
# PPV: 0.6995530898443519
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 8, 'metric': 'manhattan'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.8455882352941176
# F1-PPS: 0.7666666666666667
# TPR: 0.9078947368421053
# PPV: 0.6634615384615384
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.9168704156479217
# F1-PPS: 0.8287292817679558
# TPR: 0.9868421052631579
# PPV: 0.7142857142857143
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.8684863523573201
# F1-PPS: 0.813953488372093
# TPR: 0.9090909090909091
# PPV: 0.7368421052631579
#
# F2-PPS: 0.8769816677664531
# F1-PPS: 0.8031164789355718
# TPR: 0.9346092503987241
# PPV: 0.7048631193368036
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 8, 'metric': 'minkowski'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.85995085995086
# F1-PPS: 0.7821229050279329
# TPR: 0.9210526315789473
# PPV: 0.6796116504854369
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.9046454767726161
# F1-PPS: 0.8176795580110497
# TPR: 0.9736842105263158
# PPV: 0.7047619047619048
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.8620689655172413
# F1-PPS: 0.8
# TPR: 0.9090909090909091
# PPV: 0.7142857142857143
#
# F2-PPS: 0.8755551007469058
# F1-PPS: 0.7999341543463275
# TPR: 0.9346092503987241
# PPV: 0.6995530898443519
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 13, 'metric': 'euclidean'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.8620689655172413
# F1-PPS: 0.7865168539325843
# TPR: 0.9210526315789473
# PPV: 0.6862745098039216
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.8946078431372549
# F1-PPS: 0.8111111111111111
# TPR: 0.9605263157894737
# PPV: 0.7019230769230769
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.8845208845208845
# F1-PPS: 0.8181818181818182
# TPR: 0.935064935064935
# PPV: 0.7272727272727273
#
# F2-PPS: 0.8803992310584604
# F1-PPS: 0.8052699277418379
# TPR: 0.9388812941444521
# PPV: 0.705156771333242
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 13, 'metric': 'manhattan'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.8557457212713936
# F1-PPS: 0.7734806629834254
# TPR: 0.9210526315789473
# PPV: 0.6666666666666666
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.9034653465346535
# F1-PPS: 0.8295454545454546
# TPR: 0.9605263157894737
# PPV: 0.73
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.8902439024390244
# F1-PPS: 0.8156424581005587
# TPR: 0.948051948051948
# PPV: 0.7156862745098039
#
# F2-PPS: 0.8831516567483572
# F1-PPS: 0.8062228585431462
# TPR: 0.9432102984734563
# PPV: 0.7041176470588235
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 13, 'metric': 'minkowski'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.8620689655172413
# F1-PPS: 0.7865168539325843
# TPR: 0.9210526315789473
# PPV: 0.6862745098039216
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.8946078431372549
# F1-PPS: 0.8111111111111111
# TPR: 0.9605263157894737
# PPV: 0.7019230769230769
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.8845208845208845
# F1-PPS: 0.8181818181818182
# TPR: 0.935064935064935
# PPV: 0.7272727272727273
#
# F2-PPS: 0.8803992310584604
# F1-PPS: 0.8052699277418379
# TPR: 0.9388812941444521
# PPV: 0.705156771333242
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 21, 'metric': 'euclidean'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.85995085995086
# F1-PPS: 0.7821229050279329
# TPR: 0.9210526315789473
# PPV: 0.6796116504854369
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.9
# F1-PPS: 0.8372093023255814
# TPR: 0.9473684210526315
# PPV: 0.75
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.8990147783251231
# F1-PPS: 0.8342857142857143
# TPR: 0.948051948051948
# PPV: 0.7448979591836735
#
# F2-PPS: 0.8863218794253277
# F1-PPS: 0.8178726405464095
# TPR: 0.9388243335611756
# PPV: 0.7248365365563701
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 21, 'metric': 'manhattan'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.85995085995086
# F1-PPS: 0.7821229050279329
# TPR: 0.9210526315789473
# PPV: 0.6796116504854369
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.8977556109725686
# F1-PPS: 0.8323699421965318
# TPR: 0.9473684210526315
# PPV: 0.7422680412371134
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.8722358722358723
# F1-PPS: 0.8068181818181818
# TPR: 0.922077922077922
# PPV: 0.7171717171717171
#
# F2-PPS: 0.8766474477197669
# F1-PPS: 0.8071036763475488
# TPR: 0.930166324903167
# PPV: 0.7130171362980892
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 21, 'metric': 'minkowski'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.85995085995086
# F1-PPS: 0.7821229050279329
# TPR: 0.9210526315789473
# PPV: 0.6796116504854369
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.9
# F1-PPS: 0.8372093023255814
# TPR: 0.9473684210526315
# PPV: 0.75
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.8990147783251231
# F1-PPS: 0.8342857142857143
# TPR: 0.948051948051948
# PPV: 0.7448979591836735
#
# F2-PPS: 0.8863218794253277
# F1-PPS: 0.8178726405464095
# TPR: 0.9388243335611756
# PPV: 0.7248365365563701
# --------------------------------------------------
# seed: 21
# --------------------------------------------------
#
# k-fold-21
#
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 3, 'metric': 'euclidean'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.8064516129032258
# F1-PPS: 0.6896551724137931
# TPR: 0.9090909090909091
# PPV: 0.5555555555555556
# classifier execution on:
# - train file: fold-10-train.csv
# - test file: fold-10-test.csv
# F2-PPS: 0.9166666666666666
# F1-PPS: 0.8148148148148148
# TPR: 1.0
# PPV: 0.6875
# classifier execution on:
# - train file: fold-11-train.csv
# - test file: fold-11-test.csv
# F2-PPS: 0.8928571428571429
# F1-PPS: 0.8695652173913043
# TPR: 0.9090909090909091
# PPV: 0.8333333333333334
# classifier execution on:
# - train file: fold-12-train.csv
# - test file: fold-12-test.csv
# F2-PPS: 0.9322033898305084
# F1-PPS: 0.8461538461538461
# TPR: 1.0
# PPV: 0.7333333333333333
# classifier execution on:
# - train file: fold-13-train.csv
# - test file: fold-13-test.csv
# F2-PPS: 0.9322033898305084
# F1-PPS: 0.8461538461538461
# TPR: 1.0
# PPV: 0.7333333333333333
# classifier execution on:
# - train file: fold-14-train.csv
# - test file: fold-14-test.csv
# F2-PPS: 0.9649122807017544
# F1-PPS: 0.9166666666666666
# TPR: 1.0
# PPV: 0.8461538461538461
# classifier execution on:
# - train file: fold-15-train.csv
# - test file: fold-15-test.csv
# F2-PPS: 0.8035714285714286
# F1-PPS: 0.782608695652174
# TPR: 0.8181818181818182
# PPV: 0.75
# classifier execution on:
# - train file: fold-16-train.csv
# - test file: fold-16-test.csv
# F2-PPS: 0.9482758620689655
# F1-PPS: 0.88
# TPR: 1.0
# PPV: 0.7857142857142857
# classifier execution on:
# - train file: fold-17-train.csv
# - test file: fold-17-test.csv
# F2-PPS: 0.7894736842105263
# F1-PPS: 0.75
# TPR: 0.8181818181818182
# PPV: 0.6923076923076923
# classifier execution on:
# - train file: fold-18-train.csv
# - test file: fold-18-test.csv
# F2-PPS: 0.7142857142857143
# F1-PPS: 0.6956521739130435
# TPR: 0.7272727272727273
# PPV: 0.6666666666666666
# classifier execution on:
# - train file: fold-19-train.csv
# - test file: fold-19-test.csv
# F2-PPS: 0.9615384615384616
# F1-PPS: 0.9090909090909091
# TPR: 1.0
# PPV: 0.8333333333333334
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.9482758620689655
# F1-PPS: 0.88
# TPR: 1.0
# PPV: 0.7857142857142857
# classifier execution on:
# - train file: fold-20-train.csv
# - test file: fold-20-test.csv
# F2-PPS: 0.8620689655172413
# F1-PPS: 0.7142857142857143
# TPR: 1.0
# PPV: 0.5555555555555556
# classifier execution on:
# - train file: fold-21-train.csv
# - test file: fold-21-test.csv
# F2-PPS: 0.9482758620689655
# F1-PPS: 0.88
# TPR: 1.0
# PPV: 0.7857142857142857
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.7758620689655172
# F1-PPS: 0.72
# TPR: 0.8181818181818182
# PPV: 0.6428571428571429
# classifier execution on:
# - train file: fold-4-train.csv
# - test file: fold-4-test.csv
# F2-PPS: 0.9016393442622951
# F1-PPS: 0.7857142857142857
# TPR: 1.0
# PPV: 0.6470588235294118
# classifier execution on:
# - train file: fold-5-train.csv
# - test file: fold-5-test.csv
# F2-PPS: 0.9090909090909091
# F1-PPS: 0.9090909090909091
# TPR: 0.9090909090909091
# PPV: 0.9090909090909091
# classifier execution on:
# - train file: fold-6-train.csv
# - test file: fold-6-test.csv
# F2-PPS: 0.9649122807017544
# F1-PPS: 0.9166666666666666
# TPR: 1.0
# PPV: 0.8461538461538461
# classifier execution on:
# - train file: fold-7-train.csv
# - test file: fold-7-test.csv
# F2-PPS: 0.9482758620689655
# F1-PPS: 0.88
# TPR: 1.0
# PPV: 0.7857142857142857
# classifier execution on:
# - train file: fold-8-train.csv
# - test file: fold-8-test.csv
# F2-PPS: 0.9166666666666666
# F1-PPS: 0.8148148148148148
# TPR: 1.0
# PPV: 0.6875
# classifier execution on:
# - train file: fold-9-train.csv
# - test file: fold-9-test.csv
# F2-PPS: 0.819672131147541
# F1-PPS: 0.7142857142857143
# TPR: 0.9090909090909091
# PPV: 0.5882352941176471
#
# F2-PPS: 0.8884371231439869
# F1-PPS: 0.8197723546242144
# TPR: 0.9437229437229436
# PPV: 0.730991705151369
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 3, 'metric': 'manhattan'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.75
# F1-PPS: 0.6666666666666666
# TPR: 0.8181818181818182
# PPV: 0.5625
# classifier execution on:
# - train file: fold-10-train.csv
# - test file: fold-10-test.csv
# F2-PPS: 0.9166666666666666
# F1-PPS: 0.8148148148148148
# TPR: 1.0
# PPV: 0.6875
# classifier execution on:
# - train file: fold-11-train.csv
# - test file: fold-11-test.csv
# F2-PPS: 0.8620689655172413
# F1-PPS: 0.8
# TPR: 0.9090909090909091
# PPV: 0.7142857142857143
# classifier execution on:
# - train file: fold-12-train.csv
# - test file: fold-12-test.csv
# F2-PPS: 0.9166666666666666
# F1-PPS: 0.8148148148148148
# TPR: 1.0
# PPV: 0.6875
# classifier execution on:
# - train file: fold-13-train.csv
# - test file: fold-13-test.csv
# F2-PPS: 0.847457627118644
# F1-PPS: 0.7692307692307693
# TPR: 0.9090909090909091
# PPV: 0.6666666666666666
# classifier execution on:
# - train file: fold-14-train.csv
# - test file: fold-14-test.csv
# F2-PPS: 0.9649122807017544
# F1-PPS: 0.9166666666666666
# TPR: 1.0
# PPV: 0.8461538461538461
# classifier execution on:
# - train file: fold-15-train.csv
# - test file: fold-15-test.csv
# F2-PPS: 0.7758620689655172
# F1-PPS: 0.72
# TPR: 0.8181818181818182
# PPV: 0.6428571428571429
# classifier execution on:
# - train file: fold-16-train.csv
# - test file: fold-16-test.csv
# F2-PPS: 0.9649122807017544
# F1-PPS: 0.9166666666666666
# TPR: 1.0
# PPV: 0.8461538461538461
# classifier execution on:
# - train file: fold-17-train.csv
# - test file: fold-17-test.csv
# F2-PPS: 0.7894736842105263
# F1-PPS: 0.75
# TPR: 0.8181818181818182
# PPV: 0.6923076923076923
# classifier execution on:
# - train file: fold-18-train.csv
# - test file: fold-18-test.csv
# F2-PPS: 0.7142857142857143
# F1-PPS: 0.6956521739130435
# TPR: 0.7272727272727273
# PPV: 0.6666666666666666
# classifier execution on:
# - train file: fold-19-train.csv
# - test file: fold-19-test.csv
# F2-PPS: 0.9433962264150944
# F1-PPS: 0.8695652173913043
# TPR: 1.0
# PPV: 0.7692307692307693
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.9482758620689655
# F1-PPS: 0.88
# TPR: 1.0
# PPV: 0.7857142857142857
# classifier execution on:
# - train file: fold-20-train.csv
# - test file: fold-20-test.csv
# F2-PPS: 0.8620689655172413
# F1-PPS: 0.7142857142857143
# TPR: 1.0
# PPV: 0.5555555555555556
# classifier execution on:
# - train file: fold-21-train.csv
# - test file: fold-21-test.csv
# F2-PPS: 0.9482758620689655
# F1-PPS: 0.88
# TPR: 1.0
# PPV: 0.7857142857142857
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.7758620689655172
# F1-PPS: 0.72
# TPR: 0.8181818181818182
# PPV: 0.6428571428571429
# classifier execution on:
# - train file: fold-4-train.csv
# - test file: fold-4-test.csv
# F2-PPS: 0.8870967741935484
# F1-PPS: 0.7586206896551724
# TPR: 1.0
# PPV: 0.6111111111111112
# classifier execution on:
# - train file: fold-5-train.csv
# - test file: fold-5-test.csv
# F2-PPS: 0.9090909090909091
# F1-PPS: 0.9090909090909091
# TPR: 0.9090909090909091
# PPV: 0.9090909090909091
# classifier execution on:
# - train file: fold-6-train.csv
# - test file: fold-6-test.csv
# F2-PPS: 0.9649122807017544
# F1-PPS: 0.9166666666666666
# TPR: 1.0
# PPV: 0.8461538461538461
# classifier execution on:
# - train file: fold-7-train.csv
# - test file: fold-7-test.csv
# F2-PPS: 0.9482758620689655
# F1-PPS: 0.88
# TPR: 1.0
# PPV: 0.7857142857142857
# classifier execution on:
# - train file: fold-8-train.csv
# - test file: fold-8-test.csv
# F2-PPS: 0.9166666666666666
# F1-PPS: 0.8148148148148148
# TPR: 1.0
# PPV: 0.6875
# classifier execution on:
# - train file: fold-9-train.csv
# - test file: fold-9-test.csv
# F2-PPS: 0.8870967741935484
# F1-PPS: 0.7586206896551724
# TPR: 1.0
# PPV: 0.6111111111111112
#
# F2-PPS: 0.8806344860374125
# F1-PPS: 0.8079132035396759
# TPR: 0.9393939393939393
# PPV: 0.7143973751116608
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 3, 'metric': 'minkowski'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.8064516129032258
# F1-PPS: 0.6896551724137931
# TPR: 0.9090909090909091
# PPV: 0.5555555555555556
# classifier execution on:
# - train file: fold-10-train.csv
# - test file: fold-10-test.csv
# F2-PPS: 0.9166666666666666
# F1-PPS: 0.8148148148148148
# TPR: 1.0
# PPV: 0.6875
# classifier execution on:
# - train file: fold-11-train.csv
# - test file: fold-11-test.csv
# F2-PPS: 0.8928571428571429
# F1-PPS: 0.8695652173913043
# TPR: 0.9090909090909091
# PPV: 0.8333333333333334
# classifier execution on:
# - train file: fold-12-train.csv
# - test file: fold-12-test.csv
# F2-PPS: 0.9322033898305084
# F1-PPS: 0.8461538461538461
# TPR: 1.0
# PPV: 0.7333333333333333
# classifier execution on:
# - train file: fold-13-train.csv
# - test file: fold-13-test.csv
# F2-PPS: 0.9322033898305084
# F1-PPS: 0.8461538461538461
# TPR: 1.0
# PPV: 0.7333333333333333
# classifier execution on:
# - train file: fold-14-train.csv
# - test file: fold-14-test.csv
# F2-PPS: 0.9649122807017544
# F1-PPS: 0.9166666666666666
# TPR: 1.0
# PPV: 0.8461538461538461
# classifier execution on:
# - train file: fold-15-train.csv
# - test file: fold-15-test.csv
# F2-PPS: 0.8035714285714286
# F1-PPS: 0.782608695652174
# TPR: 0.8181818181818182
# PPV: 0.75
# classifier execution on:
# - train file: fold-16-train.csv
# - test file: fold-16-test.csv
# F2-PPS: 0.9482758620689655
# F1-PPS: 0.88
# TPR: 1.0
# PPV: 0.7857142857142857
# classifier execution on:
# - train file: fold-17-train.csv
# - test file: fold-17-test.csv
# F2-PPS: 0.7894736842105263
# F1-PPS: 0.75
# TPR: 0.8181818181818182
# PPV: 0.6923076923076923
# classifier execution on:
# - train file: fold-18-train.csv
# - test file: fold-18-test.csv
# F2-PPS: 0.7142857142857143
# F1-PPS: 0.6956521739130435
# TPR: 0.7272727272727273
# PPV: 0.6666666666666666
# classifier execution on:
# - train file: fold-19-train.csv
# - test file: fold-19-test.csv
# F2-PPS: 0.9615384615384616
# F1-PPS: 0.9090909090909091
# TPR: 1.0
# PPV: 0.8333333333333334
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.9482758620689655
# F1-PPS: 0.88
# TPR: 1.0
# PPV: 0.7857142857142857
# classifier execution on:
# - train file: fold-20-train.csv
# - test file: fold-20-test.csv
# F2-PPS: 0.8620689655172413
# F1-PPS: 0.7142857142857143
# TPR: 1.0
# PPV: 0.5555555555555556
# classifier execution on:
# - train file: fold-21-train.csv
# - test file: fold-21-test.csv
# F2-PPS: 0.9482758620689655
# F1-PPS: 0.88
# TPR: 1.0
# PPV: 0.7857142857142857
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.7758620689655172
# F1-PPS: 0.72
# TPR: 0.8181818181818182
# PPV: 0.6428571428571429
# classifier execution on:
# - train file: fold-4-train.csv
# - test file: fold-4-test.csv
# F2-PPS: 0.9016393442622951
# F1-PPS: 0.7857142857142857
# TPR: 1.0
# PPV: 0.6470588235294118
# classifier execution on:
# - train file: fold-5-train.csv
# - test file: fold-5-test.csv
# F2-PPS: 0.9090909090909091
# F1-PPS: 0.9090909090909091
# TPR: 0.9090909090909091
# PPV: 0.9090909090909091
# classifier execution on:
# - train file: fold-6-train.csv
# - test file: fold-6-test.csv
# F2-PPS: 0.9649122807017544
# F1-PPS: 0.9166666666666666
# TPR: 1.0
# PPV: 0.8461538461538461
# classifier execution on:
# - train file: fold-7-train.csv
# - test file: fold-7-test.csv
# F2-PPS: 0.9482758620689655
# F1-PPS: 0.88
# TPR: 1.0
# PPV: 0.7857142857142857
# classifier execution on:
# - train file: fold-8-train.csv
# - test file: fold-8-test.csv
# F2-PPS: 0.9166666666666666
# F1-PPS: 0.8148148148148148
# TPR: 1.0
# PPV: 0.6875
# classifier execution on:
# - train file: fold-9-train.csv
# - test file: fold-9-test.csv
# F2-PPS: 0.819672131147541
# F1-PPS: 0.7142857142857143
# TPR: 0.9090909090909091
# PPV: 0.5882352941176471
#
# F2-PPS: 0.8884371231439869
# F1-PPS: 0.8197723546242144
# TPR: 0.9437229437229436
# PPV: 0.730991705151369
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 5, 'metric': 'euclidean'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.9016393442622951
# F1-PPS: 0.7857142857142857
# TPR: 1.0
# PPV: 0.6470588235294118
# classifier execution on:
# - train file: fold-10-train.csv
# - test file: fold-10-test.csv
# F2-PPS: 0.9166666666666666
# F1-PPS: 0.8148148148148148
# TPR: 1.0
# PPV: 0.6875
# classifier execution on:
# - train file: fold-11-train.csv
# - test file: fold-11-test.csv
# F2-PPS: 0.9090909090909091
# F1-PPS: 0.9090909090909091
# TPR: 0.9090909090909091
# PPV: 0.9090909090909091
# classifier execution on:
# - train file: fold-12-train.csv
# - test file: fold-12-test.csv
# F2-PPS: 0.9166666666666666
# F1-PPS: 0.8148148148148148
# TPR: 1.0
# PPV: 0.6875
# classifier execution on:
# - train file: fold-13-train.csv
# - test file: fold-13-test.csv
# F2-PPS: 0.9322033898305084
# F1-PPS: 0.8461538461538461
# TPR: 1.0
# PPV: 0.7333333333333333
# classifier execution on:
# - train file: fold-14-train.csv
# - test file: fold-14-test.csv
# F2-PPS: 0.9649122807017544
# F1-PPS: 0.9166666666666666
# TPR: 1.0
# PPV: 0.8461538461538461
# classifier execution on:
# - train file: fold-15-train.csv
# - test file: fold-15-test.csv
# F2-PPS: 0.8771929824561403
# F1-PPS: 0.8333333333333334
# TPR: 0.9090909090909091
# PPV: 0.7692307692307693
# classifier execution on:
# - train file: fold-16-train.csv
# - test file: fold-16-test.csv
# F2-PPS: 0.9482758620689655
# F1-PPS: 0.88
# TPR: 1.0
# PPV: 0.7857142857142857
# classifier execution on:
# - train file: fold-17-train.csv
# - test file: fold-17-test.csv
# F2-PPS: 0.8620689655172413
# F1-PPS: 0.8
# TPR: 0.9090909090909091
# PPV: 0.7142857142857143
# classifier execution on:
# - train file: fold-18-train.csv
# - test file: fold-18-test.csv
# F2-PPS: 0.7272727272727273
# F1-PPS: 0.7272727272727273
# TPR: 0.7272727272727273
# PPV: 0.7272727272727273
# classifier execution on:
# - train file: fold-19-train.csv
# - test file: fold-19-test.csv
# F2-PPS: 0.9433962264150944
# F1-PPS: 0.8695652173913043
# TPR: 1.0
# PPV: 0.7692307692307693
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.9649122807017544
# F1-PPS: 0.9166666666666666
# TPR: 1.0
# PPV: 0.8461538461538461
# classifier execution on:
# - train file: fold-20-train.csv
# - test file: fold-20-test.csv
# F2-PPS: 0.7627118644067796
# F1-PPS: 0.6206896551724138
# TPR: 0.9
# PPV: 0.47368421052631576
# classifier execution on:
# - train file: fold-21-train.csv
# - test file: fold-21-test.csv
# F2-PPS: 0.9649122807017544
# F1-PPS: 0.9166666666666666
# TPR: 1.0
# PPV: 0.8461538461538461
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.7017543859649122
# F1-PPS: 0.6666666666666666
# TPR: 0.7272727272727273
# PPV: 0.6153846153846154
# classifier execution on:
# - train file: fold-4-train.csv
# - test file: fold-4-test.csv
# F2-PPS: 0.8064516129032258
# F1-PPS: 0.6896551724137931
# TPR: 0.9090909090909091
# PPV: 0.5555555555555556
# classifier execution on:
# - train file: fold-5-train.csv
# - test file: fold-5-test.csv
# F2-PPS: 0.9090909090909091
# F1-PPS: 0.9090909090909091
# TPR: 0.9090909090909091
# PPV: 0.9090909090909091
# classifier execution on:
# - train file: fold-6-train.csv
# - test file: fold-6-test.csv
# F2-PPS: 0.9821428571428571
# F1-PPS: 0.9565217391304348
# TPR: 1.0
# PPV: 0.9166666666666666
# classifier execution on:
# - train file: fold-7-train.csv
# - test file: fold-7-test.csv
# F2-PPS: 0.8771929824561403
# F1-PPS: 0.8333333333333334
# TPR: 0.9090909090909091
# PPV: 0.7692307692307693
# classifier execution on:
# - train file: fold-8-train.csv
# - test file: fold-8-test.csv
# F2-PPS: 0.847457627118644
# F1-PPS: 0.7692307692307693
# TPR: 0.9090909090909091
# PPV: 0.6666666666666666
# classifier execution on:
# - train file: fold-9-train.csv
# - test file: fold-9-test.csv
# F2-PPS: 0.873015873015873
# F1-PPS: 0.7333333333333333
# TPR: 1.0
# PPV: 0.5789473684210527
#
# F2-PPS: 0.8851918425929438
# F1-PPS: 0.8194895965217948
# TPR: 0.938961038961039
# PPV: 0.73590026817581
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 5, 'metric': 'manhattan'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.9166666666666666
# F1-PPS: 0.8148148148148148
# TPR: 1.0
# PPV: 0.6875
# classifier execution on:
# - train file: fold-10-train.csv
# - test file: fold-10-test.csv
# F2-PPS: 0.9166666666666666
# F1-PPS: 0.8148148148148148
# TPR: 1.0
# PPV: 0.6875
# classifier execution on:
# - train file: fold-11-train.csv
# - test file: fold-11-test.csv
# F2-PPS: 0.8928571428571429
# F1-PPS: 0.8695652173913043
# TPR: 0.9090909090909091
# PPV: 0.8333333333333334
# classifier execution on:
# - train file: fold-12-train.csv
# - test file: fold-12-test.csv
# F2-PPS: 0.9322033898305084
# F1-PPS: 0.8461538461538461
# TPR: 1.0
# PPV: 0.7333333333333333
# classifier execution on:
# - train file: fold-13-train.csv
# - test file: fold-13-test.csv
# F2-PPS: 0.9166666666666666
# F1-PPS: 0.8148148148148148
# TPR: 1.0
# PPV: 0.6875
# classifier execution on:
# - train file: fold-14-train.csv
# - test file: fold-14-test.csv
# F2-PPS: 0.9649122807017544
# F1-PPS: 0.9166666666666666
# TPR: 1.0
# PPV: 0.8461538461538461
# classifier execution on:
# - train file: fold-15-train.csv
# - test file: fold-15-test.csv
# F2-PPS: 0.8620689655172413
# F1-PPS: 0.8
# TPR: 0.9090909090909091
# PPV: 0.7142857142857143
# classifier execution on:
# - train file: fold-16-train.csv
# - test file: fold-16-test.csv
# F2-PPS: 0.9482758620689655
# F1-PPS: 0.88
# TPR: 1.0
# PPV: 0.7857142857142857
# classifier execution on:
# - train file: fold-17-train.csv
# - test file: fold-17-test.csv
# F2-PPS: 0.8771929824561403
# F1-PPS: 0.8333333333333334
# TPR: 0.9090909090909091
# PPV: 0.7692307692307693
# classifier execution on:
# - train file: fold-18-train.csv
# - test file: fold-18-test.csv
# F2-PPS: 0.7272727272727273
# F1-PPS: 0.7272727272727273
# TPR: 0.7272727272727273
# PPV: 0.7272727272727273
# classifier execution on:
# - train file: fold-19-train.csv
# - test file: fold-19-test.csv
# F2-PPS: 0.9433962264150944
# F1-PPS: 0.8695652173913043
# TPR: 1.0
# PPV: 0.7692307692307693
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.9649122807017544
# F1-PPS: 0.9166666666666666
# TPR: 1.0
# PPV: 0.8461538461538461
# classifier execution on:
# - train file: fold-20-train.csv
# - test file: fold-20-test.csv
# F2-PPS: 0.8620689655172413
# F1-PPS: 0.7142857142857143
# TPR: 1.0
# PPV: 0.5555555555555556
# classifier execution on:
# - train file: fold-21-train.csv
# - test file: fold-21-test.csv
# F2-PPS: 0.9649122807017544
# F1-PPS: 0.9166666666666666
# TPR: 1.0
# PPV: 0.8461538461538461
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.7017543859649122
# F1-PPS: 0.6666666666666666
# TPR: 0.7272727272727273
# PPV: 0.6153846153846154
# classifier execution on:
# - train file: fold-4-train.csv
# - test file: fold-4-test.csv
# F2-PPS: 0.7936507936507936
# F1-PPS: 0.6666666666666666
# TPR: 0.9090909090909091
# PPV: 0.5263157894736842
# classifier execution on:
# - train file: fold-5-train.csv
# - test file: fold-5-test.csv
# F2-PPS: 0.9259259259259259
# F1-PPS: 0.9523809523809523
# TPR: 0.9090909090909091
# PPV: 1.0
# classifier execution on:
# - train file: fold-6-train.csv
# - test file: fold-6-test.csv
# F2-PPS: 0.9649122807017544
# F1-PPS: 0.9166666666666666
# TPR: 1.0
# PPV: 0.8461538461538461
# classifier execution on:
# - train file: fold-7-train.csv
# - test file: fold-7-test.csv
# F2-PPS: 0.8771929824561403
# F1-PPS: 0.8333333333333334
# TPR: 0.9090909090909091
# PPV: 0.7692307692307693
# classifier execution on:
# - train file: fold-8-train.csv
# - test file: fold-8-test.csv
# F2-PPS: 0.8620689655172413
# F1-PPS: 0.8
# TPR: 0.9090909090909091
# PPV: 0.7142857142857143
# classifier execution on:
# - train file: fold-9-train.csv
# - test file: fold-9-test.csv
# F2-PPS: 0.9016393442622951
# F1-PPS: 0.7857142857142857
# TPR: 1.0
# PPV: 0.6470588235294118
#
# F2-PPS: 0.8912960848818757
# F1-PPS: 0.8264785272238688
# TPR: 0.9437229437229439
# PPV: 0.7432070278321937
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 5, 'metric': 'minkowski'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.9016393442622951
# F1-PPS: 0.7857142857142857
# TPR: 1.0
# PPV: 0.6470588235294118
# classifier execution on:
# - train file: fold-10-train.csv
# - test file: fold-10-test.csv
# F2-PPS: 0.9166666666666666
# F1-PPS: 0.8148148148148148
# TPR: 1.0
# PPV: 0.6875
# classifier execution on:
# - train file: fold-11-train.csv
# - test file: fold-11-test.csv
# F2-PPS: 0.9090909090909091
# F1-PPS: 0.9090909090909091
# TPR: 0.9090909090909091
# PPV: 0.9090909090909091
# classifier execution on:
# - train file: fold-12-train.csv
# - test file: fold-12-test.csv
# F2-PPS: 0.9166666666666666
# F1-PPS: 0.8148148148148148
# TPR: 1.0
# PPV: 0.6875
# classifier execution on:
# - train file: fold-13-train.csv
# - test file: fold-13-test.csv
# F2-PPS: 0.9322033898305084
# F1-PPS: 0.8461538461538461
# TPR: 1.0
# PPV: 0.7333333333333333
# classifier execution on:
# - train file: fold-14-train.csv
# - test file: fold-14-test.csv
# F2-PPS: 0.9649122807017544
# F1-PPS: 0.9166666666666666
# TPR: 1.0
# PPV: 0.8461538461538461
# classifier execution on:
# - train file: fold-15-train.csv
# - test file: fold-15-test.csv
# F2-PPS: 0.8771929824561403
# F1-PPS: 0.8333333333333334
# TPR: 0.9090909090909091
# PPV: 0.7692307692307693
# classifier execution on:
# - train file: fold-16-train.csv
# - test file: fold-16-test.csv
# F2-PPS: 0.9482758620689655
# F1-PPS: 0.88
# TPR: 1.0
# PPV: 0.7857142857142857
# classifier execution on:
# - train file: fold-17-train.csv
# - test file: fold-17-test.csv
# F2-PPS: 0.8620689655172413
# F1-PPS: 0.8
# TPR: 0.9090909090909091
# PPV: 0.7142857142857143
# classifier execution on:
# - train file: fold-18-train.csv
# - test file: fold-18-test.csv
# F2-PPS: 0.7272727272727273
# F1-PPS: 0.7272727272727273
# TPR: 0.7272727272727273
# PPV: 0.7272727272727273
# classifier execution on:
# - train file: fold-19-train.csv
# - test file: fold-19-test.csv
# F2-PPS: 0.9433962264150944
# F1-PPS: 0.8695652173913043
# TPR: 1.0
# PPV: 0.7692307692307693
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.9649122807017544
# F1-PPS: 0.9166666666666666
# TPR: 1.0
# PPV: 0.8461538461538461
# classifier execution on:
# - train file: fold-20-train.csv
# - test file: fold-20-test.csv
# F2-PPS: 0.7627118644067796
# F1-PPS: 0.6206896551724138
# TPR: 0.9
# PPV: 0.47368421052631576
# classifier execution on:
# - train file: fold-21-train.csv
# - test file: fold-21-test.csv
# F2-PPS: 0.9649122807017544
# F1-PPS: 0.9166666666666666
# TPR: 1.0
# PPV: 0.8461538461538461
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.7017543859649122
# F1-PPS: 0.6666666666666666
# TPR: 0.7272727272727273
# PPV: 0.6153846153846154
# classifier execution on:
# - train file: fold-4-train.csv
# - test file: fold-4-test.csv
# F2-PPS: 0.8064516129032258
# F1-PPS: 0.6896551724137931
# TPR: 0.9090909090909091
# PPV: 0.5555555555555556
# classifier execution on:
# - train file: fold-5-train.csv
# - test file: fold-5-test.csv
# F2-PPS: 0.9090909090909091
# F1-PPS: 0.9090909090909091
# TPR: 0.9090909090909091
# PPV: 0.9090909090909091
# classifier execution on:
# - train file: fold-6-train.csv
# - test file: fold-6-test.csv
# F2-PPS: 0.9821428571428571
# F1-PPS: 0.9565217391304348
# TPR: 1.0
# PPV: 0.9166666666666666
# classifier execution on:
# - train file: fold-7-train.csv
# - test file: fold-7-test.csv
# F2-PPS: 0.8771929824561403
# F1-PPS: 0.8333333333333334
# TPR: 0.9090909090909091
# PPV: 0.7692307692307693
# classifier execution on:
# - train file: fold-8-train.csv
# - test file: fold-8-test.csv
# F2-PPS: 0.847457627118644
# F1-PPS: 0.7692307692307693
# TPR: 0.9090909090909091
# PPV: 0.6666666666666666
# classifier execution on:
# - train file: fold-9-train.csv
# - test file: fold-9-test.csv
# F2-PPS: 0.873015873015873
# F1-PPS: 0.7333333333333333
# TPR: 1.0
# PPV: 0.5789473684210527
#
# F2-PPS: 0.8851918425929438
# F1-PPS: 0.8194895965217948
# TPR: 0.938961038961039
# PPV: 0.73590026817581
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 8, 'metric': 'euclidean'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.9016393442622951
# F1-PPS: 0.7857142857142857
# TPR: 1.0
# PPV: 0.6470588235294118
# classifier execution on:
# - train file: fold-10-train.csv
# - test file: fold-10-test.csv
# F2-PPS: 0.9016393442622951
# F1-PPS: 0.7857142857142857
# TPR: 1.0
# PPV: 0.6470588235294118
# classifier execution on:
# - train file: fold-11-train.csv
# - test file: fold-11-test.csv
# F2-PPS: 0.8928571428571429
# F1-PPS: 0.8695652173913043
# TPR: 0.9090909090909091
# PPV: 0.8333333333333334
# classifier execution on:
# - train file: fold-12-train.csv
# - test file: fold-12-test.csv
# F2-PPS: 0.9482758620689655
# F1-PPS: 0.88
# TPR: 1.0
# PPV: 0.7857142857142857
# classifier execution on:
# - train file: fold-13-train.csv
# - test file: fold-13-test.csv
# F2-PPS: 0.9322033898305084
# F1-PPS: 0.8461538461538461
# TPR: 1.0
# PPV: 0.7333333333333333
# classifier execution on:
# - train file: fold-14-train.csv
# - test file: fold-14-test.csv
# F2-PPS: 0.9649122807017544
# F1-PPS: 0.9166666666666666
# TPR: 1.0
# PPV: 0.8461538461538461
# classifier execution on:
# - train file: fold-15-train.csv
# - test file: fold-15-test.csv
# F2-PPS: 0.8035714285714286
# F1-PPS: 0.782608695652174
# TPR: 0.8181818181818182
# ...
# F1-PPS: 0.8236917828079391
# TPR: 0.9476190476190477
# PPV: 0.73440934403451
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 13, 'metric': 'minkowski'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.9016393442622951
# F1-PPS: 0.7857142857142857
# TPR: 1.0
# PPV: 0.6470588235294118
# classifier execution on:
# - train file: fold-10-train.csv
# - test file: fold-10-test.csv
# F2-PPS: 0.873015873015873
# F1-PPS: 0.7333333333333333
# TPR: 1.0
# PPV: 0.5789473684210527
# classifier execution on:
# - train file: fold-11-train.csv
# - test file: fold-11-test.csv
# F2-PPS: 0.8771929824561403
# F1-PPS: 0.8333333333333334
# TPR: 0.9090909090909091
# PPV: 0.7692307692307693
# classifier execution on:
# - train file: fold-12-train.csv
# - test file: fold-12-test.csv
# F2-PPS: 0.9322033898305084
# F1-PPS: 0.8461538461538461
# TPR: 1.0
# PPV: 0.7333333333333333
# classifier execution on:
# - train file: fold-13-train.csv
# - test file: fold-13-test.csv
# F2-PPS: 0.9166666666666666
# F1-PPS: 0.8148148148148148
# TPR: 1.0
# PPV: 0.6875
# classifier execution on:
# - train file: fold-14-train.csv
# - test file: fold-14-test.csv
# F2-PPS: 0.9649122807017544
# F1-PPS: 0.9166666666666666
# TPR: 1.0
# PPV: 0.8461538461538461
# classifier execution on:
# - train file: fold-15-train.csv
# - test file: fold-15-test.csv
# F2-PPS: 0.8928571428571429
# F1-PPS: 0.8695652173913043
# TPR: 0.9090909090909091
# PPV: 0.8333333333333334
# classifier execution on:
# - train file: fold-16-train.csv
# - test file: fold-16-test.csv
# F2-PPS: 0.9322033898305084
# F1-PPS: 0.8461538461538461
# TPR: 1.0
# PPV: 0.7333333333333333
# classifier execution on:
# - train file: fold-17-train.csv
# - test file: fold-17-test.csv
# F2-PPS: 0.8771929824561403
# F1-PPS: 0.8333333333333334
# TPR: 0.9090909090909091
# PPV: 0.7692307692307693
# classifier execution on:
# - train file: fold-18-train.csv
# - test file: fold-18-test.csv
# F2-PPS: 0.8620689655172413
# F1-PPS: 0.8
# TPR: 0.9090909090909091
# PPV: 0.7142857142857143
# classifier execution on:
# - train file: fold-19-train.csv
# - test file: fold-19-test.csv
# F2-PPS: 0.9433962264150944
# F1-PPS: 0.8695652173913043
# TPR: 1.0
# PPV: 0.7692307692307693
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.9821428571428571
# F1-PPS: 0.9565217391304348
# TPR: 1.0
# PPV: 0.9166666666666666
# classifier execution on:
# - train file: fold-20-train.csv
# - test file: fold-20-test.csv
# F2-PPS: 0.7894736842105263
# F1-PPS: 0.6666666666666666
# TPR: 0.9
# PPV: 0.5294117647058824
# classifier execution on:
# - train file: fold-21-train.csv
# - test file: fold-21-test.csv
# F2-PPS: 0.9322033898305084
# F1-PPS: 0.8461538461538461
# TPR: 1.0
# PPV: 0.7333333333333333
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.7407407407407407
# F1-PPS: 0.7619047619047619
# TPR: 0.7272727272727273
# PPV: 0.8
# classifier execution on:
# - train file: fold-4-train.csv
# - test file: fold-4-test.csv
# F2-PPS: 0.7258064516129032
# F1-PPS: 0.6206896551724138
# TPR: 0.8181818181818182
# PPV: 0.5
# classifier execution on:
# - train file: fold-5-train.csv
# - test file: fold-5-test.csv
# F2-PPS: 0.9821428571428571
# F1-PPS: 0.9565217391304348
# TPR: 1.0
# PPV: 0.9166666666666666
# classifier execution on:
# - train file: fold-6-train.csv
# - test file: fold-6-test.csv
# F2-PPS: 0.9649122807017544
# F1-PPS: 0.9166666666666666
# TPR: 1.0
# PPV: 0.8461538461538461
# classifier execution on:
# - train file: fold-7-train.csv
# - test file: fold-7-test.csv
# F2-PPS: 0.9482758620689655
# F1-PPS: 0.88
# TPR: 1.0
# PPV: 0.7857142857142857
# classifier execution on:
# - train file: fold-8-train.csv
# - test file: fold-8-test.csv
# F2-PPS: 0.9649122807017544
# F1-PPS: 0.9166666666666666
# TPR: 1.0
# PPV: 0.8461538461538461
# classifier execution on:
# - train file: fold-9-train.csv
# - test file: fold-9-test.csv
# F2-PPS: 0.847457627118644
# F1-PPS: 0.7692307692307693
# TPR: 0.9090909090909091
# PPV: 0.6666666666666666
#
# F2-PPS: 0.8976865369181368
# F1-PPS: 0.8304598288099395
# TPR: 0.951948051948052
# PPV: 0.7439240541020727
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 21, 'metric': 'euclidean'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.8064516129032258
# F1-PPS: 0.6896551724137931
# TPR: 0.9090909090909091
# PPV: 0.5555555555555556
# classifier execution on:
# - train file: fold-10-train.csv
# - test file: fold-10-test.csv
# F2-PPS: 0.9166666666666666
# F1-PPS: 0.8148148148148148
# TPR: 1.0
# PPV: 0.6875
# classifier execution on:
# - train file: fold-11-train.csv
# - test file: fold-11-test.csv
# F2-PPS: 0.8928571428571429
# F1-PPS: 0.8695652173913043
# TPR: 0.9090909090909091
# PPV: 0.8333333333333334
# classifier execution on:
# - train file: fold-12-train.csv
# - test file: fold-12-test.csv
# F2-PPS: 0.9322033898305084
# F1-PPS: 0.8461538461538461
# TPR: 1.0
# PPV: 0.7333333333333333
# classifier execution on:
# - train file: fold-13-train.csv
# - test file: fold-13-test.csv
# F2-PPS: 0.8771929824561403
# F1-PPS: 0.8333333333333334
# TPR: 0.9090909090909091
# PPV: 0.7692307692307693
# classifier execution on:
# - train file: fold-14-train.csv
# - test file: fold-14-test.csv
# F2-PPS: 0.9649122807017544
# F1-PPS: 0.9166666666666666
# TPR: 1.0
# PPV: 0.8461538461538461
# classifier execution on:
# - train file: fold-15-train.csv
# - test file: fold-15-test.csv
# F2-PPS: 0.8181818181818182
# F1-PPS: 0.8181818181818182
# TPR: 0.8181818181818182
# PPV: 0.8181818181818182
# classifier execution on:
# - train file: fold-16-train.csv
# - test file: fold-16-test.csv
# F2-PPS: 0.9649122807017544
# F1-PPS: 0.9166666666666666
# TPR: 1.0
# PPV: 0.8461538461538461
# classifier execution on:
# - train file: fold-17-train.csv
# - test file: fold-17-test.csv
# F2-PPS: 0.9649122807017544
# F1-PPS: 0.9166666666666666
# TPR: 1.0
# PPV: 0.8461538461538461
# classifier execution on:
# - train file: fold-18-train.csv
# - test file: fold-18-test.csv
# F2-PPS: 0.8035714285714286
# F1-PPS: 0.782608695652174
# TPR: 0.8181818181818182
# PPV: 0.75
# classifier execution on:
# - train file: fold-19-train.csv
# - test file: fold-19-test.csv
# F2-PPS: 0.9615384615384616
# F1-PPS: 0.9090909090909091
# TPR: 1.0
# PPV: 0.8333333333333334
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.9649122807017544
# F1-PPS: 0.9166666666666666
# TPR: 1.0
# PPV: 0.8461538461538461
# classifier execution on:
# - train file: fold-20-train.csv
# - test file: fold-20-test.csv
# F2-PPS: 0.7627118644067796
# F1-PPS: 0.6206896551724138
# TPR: 0.9
# PPV: 0.47368421052631576
# classifier execution on:
# - train file: fold-21-train.csv
# - test file: fold-21-test.csv
# F2-PPS: 0.9482758620689655
# F1-PPS: 0.88
# TPR: 1.0
# PPV: 0.7857142857142857
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.8035714285714286
# F1-PPS: 0.782608695652174
# TPR: 0.8181818181818182
# PPV: 0.75
# classifier execution on:
# - train file: fold-4-train.csv
# - test file: fold-4-test.csv
# F2-PPS: 0.7377049180327869
# F1-PPS: 0.6428571428571429
# TPR: 0.8181818181818182
# PPV: 0.5294117647058824
# classifier execution on:
# - train file: fold-5-train.csv
# - test file: fold-5-test.csv
# F2-PPS: 0.8928571428571429
# F1-PPS: 0.8695652173913043
# TPR: 0.9090909090909091
# PPV: 0.8333333333333334
# classifier execution on:
# - train file: fold-6-train.csv
# - test file: fold-6-test.csv
# F2-PPS: 0.9649122807017544
# F1-PPS: 0.9166666666666666
# TPR: 1.0
# PPV: 0.8461538461538461
# classifier execution on:
# - train file: fold-7-train.csv
# - test file: fold-7-test.csv
# F2-PPS: 0.9322033898305084
# F1-PPS: 0.8461538461538461
# TPR: 1.0
# PPV: 0.7333333333333333
# classifier execution on:
# - train file: fold-8-train.csv
# - test file: fold-8-test.csv
# F2-PPS: 0.8771929824561403
# F1-PPS: 0.8333333333333334
# TPR: 0.9090909090909091
# PPV: 0.7692307692307693
# classifier execution on:
# - train file: fold-9-train.csv
# - test file: fold-9-test.csv
# F2-PPS: 0.9016393442622951
# F1-PPS: 0.7857142857142857
# TPR: 1.0
# PPV: 0.6470588235294118
#
# F2-PPS: 0.8899705637619149
# F1-PPS: 0.8289361579352298
# TPR: 0.938961038961039
# PPV: 0.7491906616243194
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 21, 'metric': 'manhattan'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.7936507936507936
# F1-PPS: 0.6666666666666666
# TPR: 0.9090909090909091
# PPV: 0.5263157894736842
# classifier execution on:
# - train file: fold-10-train.csv
# - test file: fold-10-test.csv
# F2-PPS: 0.9482758620689655
# F1-PPS: 0.88
# TPR: 1.0
# PPV: 0.7857142857142857
# classifier execution on:
# - train file: fold-11-train.csv
# - test file: fold-11-test.csv
# F2-PPS: 0.8771929824561403
# F1-PPS: 0.8333333333333334
# TPR: 0.9090909090909091
# PPV: 0.7692307692307693
# classifier execution on:
# - train file: fold-12-train.csv
# - test file: fold-12-test.csv
# F2-PPS: 0.9322033898305084
# F1-PPS: 0.8461538461538461
# TPR: 1.0
# PPV: 0.7333333333333333
# classifier execution on:
# - train file: fold-13-train.csv
# - test file: fold-13-test.csv
# F2-PPS: 0.847457627118644
# F1-PPS: 0.7692307692307693
# TPR: 0.9090909090909091
# PPV: 0.6666666666666666
# classifier execution on:
# - train file: fold-14-train.csv
# - test file: fold-14-test.csv
# F2-PPS: 0.9649122807017544
# F1-PPS: 0.9166666666666666
# TPR: 1.0
# PPV: 0.8461538461538461
# classifier execution on:
# - train file: fold-15-train.csv
# - test file: fold-15-test.csv
# F2-PPS: 0.8035714285714286
# F1-PPS: 0.782608695652174
# TPR: 0.8181818181818182
# PPV: 0.75
# classifier execution on:
# - train file: fold-16-train.csv
# - test file: fold-16-test.csv
# F2-PPS: 0.9482758620689655
# F1-PPS: 0.88
# TPR: 1.0
# PPV: 0.7857142857142857
# classifier execution on:
# - train file: fold-17-train.csv
# - test file: fold-17-test.csv
# F2-PPS: 0.8928571428571429
# F1-PPS: 0.8695652173913043
# TPR: 0.9090909090909091
# PPV: 0.8333333333333334
# classifier execution on:
# - train file: fold-18-train.csv
# - test file: fold-18-test.csv
# F2-PPS: 0.8620689655172413
# F1-PPS: 0.8
# TPR: 0.9090909090909091
# PPV: 0.7142857142857143
# classifier execution on:
# - train file: fold-19-train.csv
# - test file: fold-19-test.csv
# F2-PPS: 0.9433962264150944
# F1-PPS: 0.8695652173913043
# TPR: 1.0
# PPV: 0.7692307692307693
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.9649122807017544
# F1-PPS: 0.9166666666666666
# TPR: 1.0
# PPV: 0.8461538461538461
# classifier execution on:
# - train file: fold-20-train.csv
# - test file: fold-20-test.csv
# F2-PPS: 0.7142857142857143
# F1-PPS: 0.6153846153846154
# TPR: 0.8
# PPV: 0.5
# classifier execution on:
# - train file: fold-21-train.csv
# - test file: fold-21-test.csv
# F2-PPS: 0.9482758620689655
# F1-PPS: 0.88
# TPR: 1.0
# PPV: 0.7857142857142857
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.8035714285714286
# F1-PPS: 0.782608695652174
# TPR: 0.8181818181818182
# PPV: 0.75
# classifier execution on:
# - train file: fold-4-train.csv
# - test file: fold-4-test.csv
# F2-PPS: 0.7377049180327869
# F1-PPS: 0.6428571428571429
# TPR: 0.8181818181818182
# PPV: 0.5294117647058824
# classifier execution on:
# - train file: fold-5-train.csv
# - test file: fold-5-test.csv
# F2-PPS: 0.8771929824561403
# F1-PPS: 0.8333333333333334
# TPR: 0.9090909090909091
# PPV: 0.7692307692307693
# classifier execution on:
# - train file: fold-6-train.csv
# - test file: fold-6-test.csv
# F2-PPS: 0.9482758620689655
# F1-PPS: 0.88
# TPR: 1.0
# PPV: 0.7857142857142857
# classifier execution on:
# - train file: fold-7-train.csv
# - test file: fold-7-test.csv
# F2-PPS: 0.9166666666666666
# F1-PPS: 0.8148148148148148
# TPR: 1.0
# PPV: 0.6875
# classifier execution on:
# - train file: fold-8-train.csv
# - test file: fold-8-test.csv
# F2-PPS: 0.8771929824561403
# F1-PPS: 0.8333333333333334
# TPR: 0.9090909090909091
# PPV: 0.7692307692307693
# classifier execution on:
# - train file: fold-9-train.csv
# - test file: fold-9-test.csv
# F2-PPS: 0.9016393442622951
# F1-PPS: 0.7857142857142857
# TPR: 1.0
# PPV: 0.6470588235294118
#
# F2-PPS: 0.8811228858489303
# F1-PPS: 0.8142144428686872
# TPR: 0.9341991341991344
# PPV: 0.7261901589245686
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 21, 'metric': 'minkowski'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.8064516129032258
# F1-PPS: 0.6896551724137931
# TPR: 0.9090909090909091
# PPV: 0.5555555555555556
# classifier execution on:
# - train file: fold-10-train.csv
# - test file: fold-10-test.csv
# F2-PPS: 0.9166666666666666
# F1-PPS: 0.8148148148148148
# TPR: 1.0
# PPV: 0.6875
# classifier execution on:
# - train file: fold-11-train.csv
# - test file: fold-11-test.csv
# F2-PPS: 0.8928571428571429
# F1-PPS: 0.8695652173913043
# TPR: 0.9090909090909091
# PPV: 0.8333333333333334
# classifier execution on:
# - train file: fold-12-train.csv
# - test file: fold-12-test.csv
# F2-PPS: 0.9322033898305084
# F1-PPS: 0.8461538461538461
# TPR: 1.0
# PPV: 0.7333333333333333
# classifier execution on:
# - train file: fold-13-train.csv
# - test file: fold-13-test.csv
# F2-PPS: 0.8771929824561403
# F1-PPS: 0.8333333333333334
# TPR: 0.9090909090909091
# PPV: 0.7692307692307693
# classifier execution on:
# - train file: fold-14-train.csv
# - test file: fold-14-test.csv
# F2-PPS: 0.9649122807017544
# F1-PPS: 0.9166666666666666
# TPR: 1.0
# PPV: 0.8461538461538461
# classifier execution on:
# - train file: fold-15-train.csv
# - test file: fold-15-test.csv
# F2-PPS: 0.8181818181818182
# F1-PPS: 0.8181818181818182
# TPR: 0.8181818181818182
# PPV: 0.8181818181818182
# classifier execution on:
# - train file: fold-16-train.csv
# - test file: fold-16-test.csv
# F2-PPS: 0.9649122807017544
# F1-PPS: 0.9166666666666666
# TPR: 1.0
# PPV: 0.8461538461538461
# classifier execution on:
# - train file: fold-17-train.csv
# - test file: fold-17-test.csv
# F2-PPS: 0.9649122807017544
# F1-PPS: 0.9166666666666666
# TPR: 1.0
# PPV: 0.8461538461538461
# classifier execution on:
# - train file: fold-18-train.csv
# - test file: fold-18-test.csv
# F2-PPS: 0.8035714285714286
# F1-PPS: 0.782608695652174
# TPR: 0.8181818181818182
# PPV: 0.75
# classifier execution on:
# - train file: fold-19-train.csv
# - test file: fold-19-test.csv
# F2-PPS: 0.9615384615384616
# F1-PPS: 0.9090909090909091
# TPR: 1.0
# PPV: 0.8333333333333334
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.9649122807017544
# F1-PPS: 0.9166666666666666
# TPR: 1.0
# PPV: 0.8461538461538461
# classifier execution on:
# - train file: fold-20-train.csv
# - test file: fold-20-test.csv
# F2-PPS: 0.7627118644067796
# F1-PPS: 0.6206896551724138
# TPR: 0.9
# PPV: 0.47368421052631576
# classifier execution on:
# - train file: fold-21-train.csv
# - test file: fold-21-test.csv
# F2-PPS: 0.9482758620689655
# F1-PPS: 0.88
# TPR: 1.0
# PPV: 0.7857142857142857
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.8035714285714286
# F1-PPS: 0.782608695652174
# TPR: 0.8181818181818182
# PPV: 0.75
# classifier execution on:
# - train file: fold-4-train.csv
# - test file: fold-4-test.csv
# F2-PPS: 0.7377049180327869
# F1-PPS: 0.6428571428571429
# TPR: 0.8181818181818182
# PPV: 0.5294117647058824
# classifier execution on:
# - train file: fold-5-train.csv
# - test file: fold-5-test.csv
# F2-PPS: 0.8928571428571429
# F1-PPS: 0.8695652173913043
# TPR: 0.9090909090909091
# PPV: 0.8333333333333334
# classifier execution on:
# - train file: fold-6-train.csv
# - test file: fold-6-test.csv
# F2-PPS: 0.9649122807017544
# F1-PPS: 0.9166666666666666
# TPR: 1.0
# PPV: 0.8461538461538461
# classifier execution on:
# - train file: fold-7-train.csv
# - test file: fold-7-test.csv
# F2-PPS: 0.9322033898305084
# F1-PPS: 0.8461538461538461
# TPR: 1.0
# PPV: 0.7333333333333333
# classifier execution on:
# - train file: fold-8-train.csv
# - test file: fold-8-test.csv
# F2-PPS: 0.8771929824561403
# F1-PPS: 0.8333333333333334
# TPR: 0.9090909090909091
# PPV: 0.7692307692307693
# classifier execution on:
# - train file: fold-9-train.csv
# - test file: fold-9-test.csv
# F2-PPS: 0.9016393442622951
# F1-PPS: 0.7857142857142857
# TPR: 1.0
# PPV: 0.6470588235294118
#
# F2-PPS: 0.8899705637619149
# F1-PPS: 0.8289361579352298
# TPR: 0.938961038961039
# PPV: 0.7491906616243194

# %%
for seed in [5, 8, 13]:
    print('-' * 50)
    print(f'seed: {seed}\n' + '-' * 50)
    results = evaluate(
        dir = model,
        loc = link,
        case = f'k-fold-{seed}',
        input = input,
        output = output,
        params = params,
        order = order
    )
    results.to_csv(os.path.join(output, f'k-fold-{seed}-results.csv'), index=False)
# Out:
# --------------------------------------------------
# seed: 5
# --------------------------------------------------
#
# k-fold-5
#
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 3, 'metric': 'euclidean'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.8163265306122449
# F1-PPS: 0.7272727272727273
# TPR: 0.8888888888888888
# PPV: 0.6153846153846154
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.92
# F1-PPS: 0.8214285714285714
# TPR: 1.0
# PPV: 0.696969696969697
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.8979591836734694
# F1-PPS: 0.822429906542056
# TPR: 0.9565217391304348
# PPV: 0.7213114754098361
# classifier execution on:
# - train file: fold-4-train.csv
# - test file: fold-4-test.csv
# F2-PPS: 0.9128630705394191
# F1-PPS: 0.8543689320388349
# TPR: 0.9565217391304348
# PPV: 0.7719298245614035
# classifier execution on:
# - train file: fold-5-train.csv
# - test file: fold-5-test.csv
# F2-PPS: 0.8401639344262295
# F1-PPS: 0.7735849056603774
# TPR: 0.8913043478260869
# PPV: 0.6833333333333333
#
# F2-PPS: 0.8774625438502726
# F1-PPS: 0.7998170085885135
# TPR: 0.938647342995169
# PPV: 0.6977857891317771
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 3, 'metric': 'manhattan'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.7959183673469388
# F1-PPS: 0.7090909090909091
# TPR: 0.8666666666666667
# PPV: 0.6
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.9311740890688259
# F1-PPS: 0.8440366972477065
# TPR: 1.0
# PPV: 0.7301587301587301
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.8906882591093117
# F1-PPS: 0.8073394495412844
# TPR: 0.9565217391304348
# PPV: 0.6984126984126984
# classifier execution on:
# - train file: fold-4-train.csv
# - test file: fold-4-test.csv
# F2-PPS: 0.9259259259259259
# F1-PPS: 0.8571428571428571
# TPR: 0.9782608695652174
# PPV: 0.7627118644067796
# classifier execution on:
# - train file: fold-5-train.csv
# - test file: fold-5-test.csv
# F2-PPS: 0.8367346938775511
# F1-PPS: 0.7663551401869159
# TPR: 0.8913043478260869
# PPV: 0.6721311475409836
#
# F2-PPS: 0.8760882670657107
# F1-PPS: 0.7967930106419346
# TPR: 0.9385507246376811
# PPV: 0.6926828881038383
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 3, 'metric': 'minkowski'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.8163265306122449
# F1-PPS: 0.7272727272727273
# TPR: 0.8888888888888888
# PPV: 0.6153846153846154
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.92
# F1-PPS: 0.8214285714285714
# TPR: 1.0
# PPV: 0.696969696969697
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.8979591836734694
# F1-PPS: 0.822429906542056
# TPR: 0.9565217391304348
# PPV: 0.7213114754098361
# classifier execution on:
# - train file: fold-4-train.csv
# - test file: fold-4-test.csv
# F2-PPS: 0.9128630705394191
# F1-PPS: 0.8543689320388349
# TPR: 0.9565217391304348
# PPV: 0.7719298245614035
# classifier execution on:
# - train file: fold-5-train.csv
# - test file: fold-5-test.csv
# F2-PPS: 0.8401639344262295
# F1-PPS: 0.7735849056603774
# TPR: 0.8913043478260869
# PPV: 0.6833333333333333
#
# F2-PPS: 0.8774625438502726
# F1-PPS: 0.7998170085885135
# TPR: 0.938647342995169
# PPV: 0.6977857891317771
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 5, 'metric': 'euclidean'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.823045267489712
# F1-PPS: 0.7407407407407407
# TPR: 0.8888888888888888
# PPV: 0.6349206349206349
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.9146341463414634
# F1-PPS: 0.8333333333333334
# TPR: 0.9782608695652174
# PPV: 0.7258064516129032
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.9036144578313253
# F1-PPS: 0.8108108108108109
# TPR: 0.9782608695652174
# PPV: 0.6923076923076923
# classifier execution on:
# - train file: fold-4-train.csv
# - test file: fold-4-test.csv
# F2-PPS: 0.9259259259259259
# F1-PPS: 0.8571428571428571
# TPR: 0.9782608695652174
# PPV: 0.7627118644067796
# classifier execution on:
# - train file: fold-5-train.csv
# - test file: fold-5-test.csv
# F2-PPS: 0.823045267489712
# F1-PPS: 0.7619047619047619
# TPR: 0.8695652173913043
# PPV: 0.6779661016949152
#
# F2-PPS: 0.8780530130156278
# F1-PPS: 0.8007865007865007
# TPR: 0.938647342995169
# PPV: 0.6987425489885851
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 5, 'metric': 'manhattan'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.8097165991902834
# F1-PPS: 0.7142857142857143
# TPR: 0.8888888888888888
# PPV: 0.5970149253731343
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.9297520661157025
# F1-PPS: 0.8653846153846154
# TPR: 0.9782608695652174
# PPV: 0.7758620689655172
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.9
# F1-PPS: 0.8035714285714286
# TPR: 0.9782608695652174
# PPV: 0.6818181818181818
# classifier execution on:
# - train file: fold-4-train.csv
# - test file: fold-4-test.csv
# F2-PPS: 0.8979591836734694
# F1-PPS: 0.822429906542056
# TPR: 0.9565217391304348
# PPV: 0.7213114754098361
# classifier execution on:
# - train file: fold-5-train.csv
# - test file: fold-5-test.csv
# F2-PPS: 0.8436213991769548
# F1-PPS: 0.780952380952381
# TPR: 0.8913043478260869
# PPV: 0.6949152542372882
#
# F2-PPS: 0.876209849631282
# F1-PPS: 0.797324809147239
# TPR: 0.938647342995169
# PPV: 0.6941843811607915
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 5, 'metric': 'minkowski'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.823045267489712
# F1-PPS: 0.7407407407407407
# TPR: 0.8888888888888888
# PPV: 0.6349206349206349
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.9146341463414634
# F1-PPS: 0.8333333333333334
# TPR: 0.9782608695652174
# PPV: 0.7258064516129032
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.9036144578313253
# F1-PPS: 0.8108108108108109
# TPR: 0.9782608695652174
# PPV: 0.6923076923076923
# classifier execution on:
# - train file: fold-4-train.csv
# - test file: fold-4-test.csv
# F2-PPS: 0.9259259259259259
# F1-PPS: 0.8571428571428571
# TPR: 0.9782608695652174
# PPV: 0.7627118644067796
# classifier execution on:
# - train file: fold-5-train.csv
# - test file: fold-5-test.csv
# F2-PPS: 0.823045267489712
# F1-PPS: 0.7619047619047619
# TPR: 0.8695652173913043
# PPV: 0.6779661016949152
#
# F2-PPS: 0.8780530130156278
# F1-PPS: 0.8007865007865007
# TPR: 0.938647342995169
# PPV: 0.6987425489885851
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 8, 'metric': 'euclidean'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.819672131147541
# F1-PPS: 0.7339449541284404
# TPR: 0.8888888888888888
# PPV: 0.625
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.9274193548387096
# F1-PPS: 0.8363636363636363
# TPR: 1.0
# PPV: 0.71875
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.9146341463414634
# F1-PPS: 0.8333333333333334
# TPR: 0.9782608695652174
# PPV: 0.7258064516129032
# classifier execution on:
# - train file: fold-4-train.csv
# - test file: fold-4-test.csv
# F2-PPS: 0.9375
# F1-PPS: 0.8823529411764706
# TPR: 0.9782608695652174
# PPV: 0.8035714285714286
# classifier execution on:
# - train file: fold-5-train.csv
# - test file: fold-5-test.csv
# F2-PPS: 0.8401639344262295
# F1-PPS: 0.7735849056603774
# TPR: 0.8913043478260869
# PPV: 0.6833333333333333
#
# F2-PPS: 0.8878779133507887
# F1-PPS: 0.8119159541324518
# TPR: 0.9473429951690822
# PPV: 0.7112922427035331
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 8, 'metric': 'manhattan'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.8232931726907631
# F1-PPS: 0.7192982456140351
# TPR: 0.9111111111111111
# PPV: 0.5942028985507246
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.9349593495934959
# F1-PPS: 0.8518518518518519
# TPR: 1.0
# PPV: 0.7419354838709677
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.9109311740890689
# F1-PPS: 0.8256880733944955
# TPR: 0.9782608695652174
# PPV: 0.7142857142857143
# classifier execution on:
# - train file: fold-4-train.csv
# - test file: fold-4-test.csv
# F2-PPS: 0.9414225941422594
# F1-PPS: 0.8910891089108911
# TPR: 0.9782608695652174
# PPV: 0.8181818181818182
# classifier execution on:
# - train file: fold-5-train.csv
# - test file: fold-5-test.csv
# F2-PPS: 0.8125
# F1-PPS: 0.7647058823529411
# TPR: 0.8478260869565217
# PPV: 0.6964285714285714
#
# F2-PPS: 0.8846212581031174
# F1-PPS: 0.8105266324248429
# TPR: 0.9430917874396135
# PPV: 0.7130068972635593
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 8, 'metric': 'minkowski'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.819672131147541
# F1-PPS: 0.7339449541284404
# TPR: 0.8888888888888888
# PPV: 0.625
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.9274193548387096
# F1-PPS: 0.8363636363636363
# TPR: 1.0
# PPV: 0.71875
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.9146341463414634
# F1-PPS: 0.8333333333333334
# TPR: 0.9782608695652174
# PPV: 0.7258064516129032
# classifier execution on:
# - train file: fold-4-train.csv
# - test file: fold-4-test.csv
# F2-PPS: 0.9375
# F1-PPS: 0.8823529411764706
# TPR: 0.9782608695652174
# PPV: 0.8035714285714286
# classifier execution on:
# - train file: fold-5-train.csv
# - test file: fold-5-test.csv
# F2-PPS: 0.8401639344262295
# F1-PPS: 0.7735849056603774
# TPR: 0.8913043478260869
# PPV: 0.6833333333333333
#
# F2-PPS: 0.8878779133507887
# F1-PPS: 0.8119159541324518
# TPR: 0.9473429951690822
# PPV: 0.7112922427035331
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 13, 'metric': 'euclidean'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.8367346938775511
# F1-PPS: 0.7454545454545455
# TPR: 0.9111111111111111
# PPV: 0.6307692307692307
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.9426229508196722
# F1-PPS: 0.8679245283018868
# TPR: 1.0
# PPV: 0.7666666666666667
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.9221311475409836
# F1-PPS: 0.8490566037735849
# TPR: 0.9782608695652174
# PPV: 0.75
# classifier execution on:
# - train file: fold-4-train.csv
# - test file: fold-4-test.csv
# F2-PPS: 0.9166666666666666
# F1-PPS: 0.8627450980392157
# TPR: 0.9565217391304348
# PPV: 0.7857142857142857
# classifier execution on:
# - train file: fold-5-train.csv
# - test file: fold-5-test.csv
# F2-PPS: 0.8467741935483871
# F1-PPS: 0.7636363636363637
# TPR: 0.9130434782608695
# PPV: 0.65625
#
# F2-PPS: 0.8929859304906522
# F1-PPS: 0.8177634278411194
# TPR: 0.9517874396135264
# PPV: 0.7178800366300366
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 13, 'metric': 'manhattan'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.8097165991902834
# F1-PPS: 0.7142857142857143
# TPR: 0.8888888888888888
# PPV: 0.5970149253731343
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.9274193548387096
# F1-PPS: 0.8363636363636363
# TPR: 1.0
# PPV: 0.71875
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.9053497942386831
# F1-PPS: 0.8380952380952381
# TPR: 0.9565217391304348
# PPV: 0.7457627118644068
# classifier execution on:
# - train file: fold-4-train.csv
# - test file: fold-4-test.csv
# F2-PPS: 0.9090909090909091
# F1-PPS: 0.8461538461538461
# TPR: 0.9565217391304348
# PPV: 0.7586206896551724
# classifier execution on:
# - train file: fold-5-train.csv
# - test file: fold-5-test.csv
# F2-PPS: 0.8467741935483871
# F1-PPS: 0.7636363636363637
# TPR: 0.9130434782608695
# PPV: 0.65625
#
# F2-PPS: 0.8796701701813945
# F1-PPS: 0.7997069597069597
# TPR: 0.9429951690821256
# PPV: 0.6952796653785427
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 13, 'metric': 'minkowski'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.8367346938775511
# F1-PPS: 0.7454545454545455
# TPR: 0.9111111111111111
# PPV: 0.6307692307692307
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.9426229508196722
# F1-PPS: 0.8679245283018868
# TPR: 1.0
# PPV: 0.7666666666666667
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.9221311475409836
# F1-PPS: 0.8490566037735849
# TPR: 0.9782608695652174
# PPV: 0.75
# classifier execution on:
# - train file: fold-4-train.csv
# - test file: fold-4-test.csv
# F2-PPS: 0.9166666666666666
# F1-PPS: 0.8627450980392157
# TPR: 0.9565217391304348
# PPV: 0.7857142857142857
# classifier execution on:
# - train file: fold-5-train.csv
# - test file: fold-5-test.csv
# F2-PPS: 0.8467741935483871
# F1-PPS: 0.7636363636363637
# TPR: 0.9130434782608695
# PPV: 0.65625
#
# F2-PPS: 0.8929859304906522
# F1-PPS: 0.8177634278411194
# TPR: 0.9517874396135264
# PPV: 0.7178800366300366
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 21, 'metric': 'euclidean'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.8298755186721992
# F1-PPS: 0.7547169811320755
# TPR: 0.8888888888888888
# PPV: 0.6557377049180327
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.9146341463414634
# F1-PPS: 0.8333333333333334
# TPR: 0.9782608695652174
# PPV: 0.7258064516129032
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.8979591836734694
# F1-PPS: 0.822429906542056
# TPR: 0.9565217391304348
# PPV: 0.7213114754098361
# classifier execution on:
# - train file: fold-4-train.csv
# - test file: fold-4-test.csv
# F2-PPS: 0.9243697478991597
# F1-PPS: 0.88
# TPR: 0.9565217391304348
# PPV: 0.8148148148148148
# classifier execution on:
# - train file: fold-5-train.csv
# - test file: fold-5-test.csv
# F2-PPS: 0.8571428571428571
# F1-PPS: 0.7850467289719626
# TPR: 0.9130434782608695
# PPV: 0.6885245901639344
#
# F2-PPS: 0.8847962907458298
# F1-PPS: 0.8151053899958856
# TPR: 0.9386473429951689
# PPV: 0.7212390073839042
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 21, 'metric': 'manhattan'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.8401639344262295
# F1-PPS: 0.7522935779816514
# TPR: 0.9111111111111111
# PPV: 0.640625
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.9053497942386831
# F1-PPS: 0.8380952380952381
# TPR: 0.9565217391304348
# PPV: 0.7457627118644068
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.9146341463414634
# F1-PPS: 0.8333333333333334
# TPR: 0.9782608695652174
# PPV: 0.7258064516129032
# classifier execution on:
# - train file: fold-4-train.csv
# - test file: fold-4-test.csv
# F2-PPS: 0.9166666666666666
# F1-PPS: 0.8627450980392157
# TPR: 0.9565217391304348
# PPV: 0.7857142857142857
# classifier execution on:
# - train file: fold-5-train.csv
# - test file: fold-5-test.csv
# F2-PPS: 0.8775510204081632
# F1-PPS: 0.8037383177570093
# TPR: 0.9347826086956522
# PPV: 0.7049180327868853
#
# F2-PPS: 0.8908731124162411
# F1-PPS: 0.8180411130412896
# TPR: 0.9474396135265701
# PPV: 0.7205652963956962
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 21, 'metric': 'minkowski'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.8298755186721992
# F1-PPS: 0.7547169811320755
# TPR: 0.8888888888888888
# PPV: 0.6557377049180327
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.9146341463414634
# F1-PPS: 0.8333333333333334
# TPR: 0.9782608695652174
# PPV: 0.7258064516129032
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.8979591836734694
# F1-PPS: 0.822429906542056
# TPR: 0.9565217391304348
# PPV: 0.7213114754098361
# classifier execution on:
# - train file: fold-4-train.csv
# - test file: fold-4-test.csv
# F2-PPS: 0.9243697478991597
# F1-PPS: 0.88
# TPR: 0.9565217391304348
# PPV: 0.8148148148148148
# classifier execution on:
# - train file: fold-5-train.csv
# - test file: fold-5-test.csv
# F2-PPS: 0.8571428571428571
# F1-PPS: 0.7850467289719626
# TPR: 0.9130434782608695
# PPV: 0.6885245901639344
#
# F2-PPS: 0.8847962907458298
# F1-PPS: 0.8151053899958856
# TPR: 0.9386473429951689
# PPV: 0.7212390073839042
# --------------------------------------------------
# seed: 8
# --------------------------------------------------
#
# k-fold-8
#
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 3, 'metric': 'euclidean'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.8387096774193549
# F1-PPS: 0.7323943661971831
# TPR: 0.9285714285714286
# PPV: 0.6046511627906976
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.8843537414965986
# F1-PPS: 0.8253968253968254
# TPR: 0.9285714285714286
# PPV: 0.7428571428571429
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.9354838709677419
# F1-PPS: 0.8529411764705882
# TPR: 1.0
# PPV: 0.7435897435897436
# classifier execution on:
# - train file: fold-4-train.csv
# - test file: fold-4-test.csv
# F2-PPS: 0.84375
# F1-PPS: 0.7397260273972602
# TPR: 0.9310344827586207
# PPV: 0.6136363636363636
# classifier execution on:
# - train file: fold-5-train.csv
# - test file: fold-5-test.csv
# F2-PPS: 0.9539473684210527
# F1-PPS: 0.8923076923076924
# TPR: 1.0
# PPV: 0.8055555555555556
# classifier execution on:
# - train file: fold-6-train.csv
# - test file: fold-6-test.csv
# F2-PPS: 0.8881578947368421
# F1-PPS: 0.8307692307692308
# TPR: 0.9310344827586207
# PPV: 0.75
# classifier execution on:
# - train file: fold-7-train.csv
# - test file: fold-7-test.csv
# F2-PPS: 0.8053691275167785
# F1-PPS: 0.7741935483870968
# TPR: 0.8275862068965517
# PPV: 0.7272727272727273
# classifier execution on:
# - train file: fold-8-train.csv
# - test file: fold-8-test.csv
# F2-PPS: 0.9210526315789473
# F1-PPS: 0.8235294117647058
# TPR: 1.0
# PPV: 0.7
#
# F2-PPS: 0.8838530390171645
# F1-PPS: 0.8089072848363228
# TPR: 0.9433497536945812
# PPV: 0.7109453369627788
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 3, 'metric': 'manhattan'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.8223684210526315
# F1-PPS: 0.7352941176470589
# TPR: 0.8928571428571429
# PPV: 0.625
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.8783783783783784
# F1-PPS: 0.8125
# TPR: 0.9285714285714286
# PPV: 0.7222222222222222
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.9354838709677419
# F1-PPS: 0.8529411764705882
# TPR: 1.0
# PPV: 0.7435897435897436
# classifier execution on:
# - train file: fold-4-train.csv
# - test file: fold-4-test.csv
# F2-PPS: 0.8695652173913043
# F1-PPS: 0.7567567567567568
# TPR: 0.9655172413793104
# PPV: 0.6222222222222222
# classifier execution on:
# - train file: fold-5-train.csv
# - test file: fold-5-test.csv
# F2-PPS: 0.9090909090909091
# F1-PPS: 0.835820895522388
# TPR: 0.9655172413793104
# PPV: 0.7368421052631579
# classifier execution on:
# - train file: fold-6-train.csv
# - test file: fold-6-test.csv
# F2-PPS: 0.8881578947368421
# F1-PPS: 0.8307692307692308
# TPR: 0.9310344827586207
# PPV: 0.75
# classifier execution on:
# - train file: fold-7-train.csv
# - test file: fold-7-test.csv
# F2-PPS: 0.7718120805369127
# F1-PPS: 0.7419354838709677
# TPR: 0.7931034482758621
# PPV: 0.696969696969697
# classifier execution on:
# - train file: fold-8-train.csv
# - test file: fold-8-test.csv
# F2-PPS: 0.9150326797385621
# F1-PPS: 0.8115942028985508
# TPR: 1.0
# PPV: 0.6829268292682927
#
# F2-PPS: 0.8737361814866602
# F1-PPS: 0.7972014829919426
# TPR: 0.9345751231527094
# PPV: 0.697471602441917
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 3, 'metric': 'minkowski'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.8387096774193549
# F1-PPS: 0.7323943661971831
# TPR: 0.9285714285714286
# PPV: 0.6046511627906976
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.8843537414965986
# F1-PPS: 0.8253968253968254
# TPR: 0.9285714285714286
# PPV: 0.7428571428571429
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.9354838709677419
# F1-PPS: 0.8529411764705882
# TPR: 1.0
# PPV: 0.7435897435897436
# classifier execution on:
# - train file: fold-4-train.csv
# - test file: fold-4-test.csv
# F2-PPS: 0.84375
# F1-PPS: 0.7397260273972602
# TPR: 0.9310344827586207
# PPV: 0.6136363636363636
# classifier execution on:
# - train file: fold-5-train.csv
# - test file: fold-5-test.csv
# F2-PPS: 0.9539473684210527
# F1-PPS: 0.8923076923076924
# TPR: 1.0
# PPV: 0.8055555555555556
# classifier execution on:
# - train file: fold-6-train.csv
# - test file: fold-6-test.csv
# F2-PPS: 0.8881578947368421
# F1-PPS: 0.8307692307692308
# TPR: 0.9310344827586207
# PPV: 0.75
# classifier execution on:
# - train file: fold-7-train.csv
# - test file: fold-7-test.csv
# F2-PPS: 0.8053691275167785
# F1-PPS: 0.7741935483870968
# TPR: 0.8275862068965517
# PPV: 0.7272727272727273
# classifier execution on:
# - train file: fold-8-train.csv
# - test file: fold-8-test.csv
# F2-PPS: 0.9210526315789473
# F1-PPS: 0.8235294117647058
# TPR: 1.0
# PPV: 0.7
#
# F2-PPS: 0.8838530390171645
# F1-PPS: 0.8089072848363228
# TPR: 0.9433497536945812
# PPV: 0.7109453369627788
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 5, 'metric': 'euclidean'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.8823529411764706
# F1-PPS: 0.782608695652174
# TPR: 0.9642857142857143
# PPV: 0.6585365853658537
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.8163265306122449
# F1-PPS: 0.7619047619047619
# TPR: 0.8571428571428571
# PPV: 0.6857142857142857
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.8940397350993378
# F1-PPS: 0.84375
# TPR: 0.9310344827586207
# PPV: 0.7714285714285715
# classifier execution on:
# - train file: fold-4-train.csv
# - test file: fold-4-test.csv
# F2-PPS: 0.8805031446540881
# F1-PPS: 0.7777777777777778
# TPR: 0.9655172413793104
# PPV: 0.6511627906976745
# classifier execution on:
# - train file: fold-5-train.csv
# - test file: fold-5-test.csv
# F2-PPS: 0.9354838709677419
# F1-PPS: 0.8529411764705882
# TPR: 1.0
# PPV: 0.7435897435897436
# classifier execution on:
# - train file: fold-6-train.csv
# - test file: fold-6-test.csv
# F2-PPS: 0.9271523178807947
# F1-PPS: 0.875
# TPR: 0.9655172413793104
# PPV: 0.8
# classifier execution on:
# - train file: fold-7-train.csv
# - test file: fold-7-test.csv
# F2-PPS: 0.8666666666666667
# F1-PPS: 0.8253968253968254
# TPR: 0.896551724137931
# PPV: 0.7647058823529411
# classifier execution on:
# - train file: fold-8-train.csv
# - test file: fold-8-test.csv
# F2-PPS: 0.9090909090909091
# F1-PPS: 0.8
# TPR: 1.0
# PPV: 0.6666666666666666
#
# F2-PPS: 0.8889520145185317
# F1-PPS: 0.8149224046502659
# TPR: 0.947506157635468
# PPV: 0.7177255657269671
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 5, 'metric': 'manhattan'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.8881578947368421
# F1-PPS: 0.7941176470588235
# TPR: 0.9642857142857143
# PPV: 0.675
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.8108108108108109
# F1-PPS: 0.75
# TPR: 0.8571428571428571
# PPV: 0.6666666666666666
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.8881578947368421
# F1-PPS: 0.8307692307692308
# TPR: 0.9310344827586207
# PPV: 0.75
# classifier execution on:
# - train file: fold-4-train.csv
# - test file: fold-4-test.csv
# F2-PPS: 0.8695652173913043
# F1-PPS: 0.7567567567567568
# TPR: 0.9655172413793104
# PPV: 0.6222222222222222
# classifier execution on:
# - train file: fold-5-train.csv
# - test file: fold-5-test.csv
# F2-PPS: 0.9294871794871795
# F1-PPS: 0.8405797101449275
# TPR: 1.0
# PPV: 0.725
# classifier execution on:
# - train file: fold-6-train.csv
# - test file: fold-6-test.csv
# F2-PPS: 0.8823529411764706
# F1-PPS: 0.8181818181818182
# TPR: 0.9310344827586207
# PPV: 0.7297297297297297
# classifier execution on:
# - train file: fold-7-train.csv
# - test file: fold-7-test.csv
# F2-PPS: 0.8666666666666667
# F1-PPS: 0.8253968253968254
# TPR: 0.896551724137931
# PPV: 0.7647058823529411
# classifier execution on:
# - train file: fold-8-train.csv
# - test file: fold-8-test.csv
# F2-PPS: 0.9150326797385621
# F1-PPS: 0.8115942028985508
# TPR: 1.0
# PPV: 0.6829268292682927
#
# F2-PPS: 0.8812789105930847
# F1-PPS: 0.8034245239008666
# TPR: 0.9431958128078818
# PPV: 0.7020314162799817
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 5, 'metric': 'minkowski'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.8823529411764706
# F1-PPS: 0.782608695652174
# TPR: 0.9642857142857143
# PPV: 0.6585365853658537
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.8163265306122449
# F1-PPS: 0.7619047619047619
# TPR: 0.8571428571428571
# PPV: 0.6857142857142857
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.8940397350993378
# F1-PPS: 0.84375
# TPR: 0.9310344827586207
# PPV: 0.7714285714285715
# classifier execution on:
# - train file: fold-4-train.csv
# - test file: fold-4-test.csv
# F2-PPS: 0.8805031446540881
# F1-PPS: 0.7777777777777778
# TPR: 0.9655172413793104
# PPV: 0.6511627906976745
# classifier execution on:
# - train file: fold-5-train.csv
# - test file: fold-5-test.csv
# F2-PPS: 0.9354838709677419
# F1-PPS: 0.8529411764705882
# TPR: 1.0
# PPV: 0.7435897435897436
# classifier execution on:
# - train file: fold-6-train.csv
# - test file: fold-6-test.csv
# F2-PPS: 0.9271523178807947
# F1-PPS: 0.875
# TPR: 0.9655172413793104
# PPV: 0.8
# classifier execution on:
# - train file: fold-7-train.csv
# - test file: fold-7-test.csv
# F2-PPS: 0.8666666666666667
# F1-PPS: 0.8253968253968254
# TPR: 0.896551724137931
# PPV: 0.7647058823529411
# classifier execution on:
# - train file: fold-8-train.csv
# - test file: fold-8-test.csv
# F2-PPS: 0.9090909090909091
# F1-PPS: 0.8
# TPR: 1.0
# PPV: 0.6666666666666666
#
# F2-PPS: 0.8889520145185317
# F1-PPS: 0.8149224046502659
# TPR: 0.947506157635468
# PPV: 0.7177255657269671
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 8, 'metric': 'euclidean'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.8881578947368421
# F1-PPS: 0.7941176470588235
# TPR: 0.9642857142857143
# PPV: 0.675
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.8389261744966443
# F1-PPS: 0.7692307692307693
# TPR: 0.8928571428571429
# PPV: 0.6756756756756757
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.9354838709677419
# F1-PPS: 0.8529411764705882
# TPR: 1.0
# PPV: 0.7435897435897436
# classifier execution on:
# - train file: fold-4-train.csv
# - test file: fold-4-test.csv
# F2-PPS: 0.89171974522293
# F1-PPS: 0.8
# TPR: 0.9655172413793104
# PPV: 0.6829268292682927
# classifier execution on:
# - train file: fold-5-train.csv
# - test file: fold-5-test.csv
# F2-PPS: 0.9415584415584416
# F1-PPS: 0.8656716417910447
# TPR: 1.0
# PPV: 0.7631578947368421
# classifier execution on:
# - train file: fold-6-train.csv
# - test file: fold-6-test.csv
# F2-PPS: 0.9
# F1-PPS: 0.8571428571428571
# TPR: 0.9310344827586207
# PPV: 0.7941176470588235
# classifier execution on:
# - train file: fold-7-train.csv
# - test file: fold-7-test.csv
# F2-PPS: 0.8552631578947368
# F1-PPS: 0.8
# TPR: 0.896551724137931
# PPV: 0.7222222222222222
# classifier execution on:
# - train file: fold-8-train.csv
# - test file: fold-8-test.csv
# F2-PPS: 0.9090909090909091
# F1-PPS: 0.8
# TPR: 1.0
# PPV: 0.6666666666666666
#
# F2-PPS: 0.8950250242460307
# F1-PPS: 0.8173880114617604
# TPR: 0.9562807881773399
# PPV: 0.7154195849022833
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 8, 'metric': 'manhattan'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.8766233766233766
# F1-PPS: 0.7714285714285715
# TPR: 0.9642857142857143
# PPV: 0.6428571428571429
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.8278145695364238
# F1-PPS: 0.746268656716418
# TPR: 0.8928571428571429
# PPV: 0.6410256410256411
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.9415584415584416
# F1-PPS: 0.8656716417910447
# TPR: 1.0
# PPV: 0.7631578947368421
# classifier execution on:
# - train file: fold-4-train.csv
# - test file: fold-4-test.csv
# F2-PPS: 0.89171974522293
# F1-PPS: 0.8
# TPR: 0.9655172413793104
# PPV: 0.6829268292682927
# classifier execution on:
# - train file: fold-5-train.csv
# - test file: fold-5-test.csv
# F2-PPS: 0.9354838709677419
# F1-PPS: 0.8529411764705882
# TPR: 1.0
# PPV: 0.7435897435897436
# classifier execution on:
# - train file: fold-6-train.csv
# - test file: fold-6-test.csv
# F2-PPS: 0.9
# F1-PPS: 0.8571428571428571
# TPR: 0.9310344827586207
# PPV: 0.7941176470588235
# classifier execution on:
# - train file: fold-7-train.csv
# - test file: fold-7-test.csv
# F2-PPS: 0.8053691275167785
# F1-PPS: 0.7741935483870968
# TPR: 0.8275862068965517
# PPV: 0.7272727272727273
# classifier execution on:
# - train file: fold-8-train.csv
# - test file: fold-8-test.csv
# F2-PPS: 0.8823529411764706
# F1-PPS: 0.782608695652174
# TPR: 0.9642857142857143
# PPV: 0.6585365853658537
#
# F2-PPS: 0.8826152590752704
# F1-PPS: 0.8062818934485938
# TPR: 0.9431958128078818
# PPV: 0.7066855263968833
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 8, 'metric': 'minkowski'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.8881578947368421
# F1-PPS: 0.7941176470588235
# TPR: 0.9642857142857143
# PPV: 0.675
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.8389261744966443
# F1-PPS: 0.7692307692307693
# TPR: 0.8928571428571429
# PPV: 0.6756756756756757
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.9354838709677419
# F1-PPS: 0.8529411764705882
# TPR: 1.0
# PPV: 0.7435897435897436
# classifier execution on:
# - train file: fold-4-train.csv
# - test file: fold-4-test.csv
# F2-PPS: 0.89171974522293
# F1-PPS: 0.8
# TPR: 0.9655172413793104
# PPV: 0.6829268292682927
# classifier execution on:
# - train file: fold-5-train.csv
# - test file: fold-5-test.csv
# F2-PPS: 0.9415584415584416
# F1-PPS: 0.8656716417910447
# TPR: 1.0
# PPV: 0.7631578947368421
# classifier execution on:
# - train file: fold-6-train.csv
# - test file: fold-6-test.csv
# F2-PPS: 0.9
# F1-PPS: 0.8571428571428571
# TPR: 0.9310344827586207
# PPV: 0.7941176470588235
# classifier execution on:
# - train file: fold-7-train.csv
# - test file: fold-7-test.csv
# F2-PPS: 0.8552631578947368
# F1-PPS: 0.8
# TPR: 0.896551724137931
# PPV: 0.7222222222222222
# classifier execution on:
# - train file: fold-8-train.csv
# - test file: fold-8-test.csv
# F2-PPS: 0.9090909090909091
# F1-PPS: 0.8
# TPR: 1.0
# PPV: 0.6666666666666666
#
# F2-PPS: 0.8950250242460307
# F1-PPS: 0.8173880114617604
# TPR: 0.9562807881773399
# PPV: 0.7154195849022833
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 13, 'metric': 'euclidean'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.8940397350993378
# F1-PPS: 0.8059701492537313
# TPR: 0.9642857142857143
# PPV: 0.6923076923076923
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.8389261744966443
# F1-PPS: 0.7692307692307693
# TPR: 0.8928571428571429
# PPV: 0.6756756756756757
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.9602649006622517
# F1-PPS: 0.90625
# TPR: 1.0
# PPV: 0.8285714285714286
# classifier execution on:
# - train file: fold-4-train.csv
# - test file: fold-4-test.csv
# F2-PPS: 0.8805031446540881
# F1-PPS: 0.7777777777777778
# TPR: 0.9655172413793104
# PPV: 0.6511627906976745
# classifier execution on:
# - train file: fold-5-train.csv
# - test file: fold-5-test.csv
# F2-PPS: 0.9294871794871795
# F1-PPS: 0.8405797101449275
# TPR: 1.0
# PPV: 0.725
# classifier execution on:
# - train file: fold-6-train.csv
# - test file: fold-6-test.csv
# F2-PPS: 0.9271523178807947
# F1-PPS: 0.875
# TPR: 0.9655172413793104
# PPV: 0.8
# classifier execution on:
# - train file: fold-7-train.csv
# - test file: fold-7-test.csv
# F2-PPS: 0.8823529411764706
# F1-PPS: 0.8181818181818182
# TPR: 0.9310344827586207
# PPV: 0.7297297297297297
# classifier execution on:
# - train file: fold-8-train.csv
# - test file: fold-8-test.csv
# F2-PPS: 0.9
# F1-PPS: 0.8181818181818182
# TPR: 0.9642857142857143
# PPV: 0.7105263157894737
#
# F2-PPS: 0.9015907991820958
# F1-PPS: 0.8263965053463553
# TPR: 0.9604371921182266
# PPV: 0.7266217040964593
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 13, 'metric': 'manhattan'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.8552631578947368
# F1-PPS: 0.7647058823529411
# TPR: 0.9285714285714286
# PPV: 0.65
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.8
# F1-PPS: 0.7272727272727273
# TPR: 0.8571428571428571
# PPV: 0.631578947368421
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.9090909090909091
# F1-PPS: 0.835820895522388
# TPR: 0.9655172413793104
# PPV: 0.7368421052631579
# classifier execution on:
# - train file: fold-4-train.csv
# - test file: fold-4-test.csv
# F2-PPS: 0.89171974522293
# F1-PPS: 0.8
# TPR: 0.9655172413793104
# PPV: 0.6829268292682927
# classifier execution on:
# - train file: fold-5-train.csv
# - test file: fold-5-test.csv
# F2-PPS: 0.9210526315789473
# F1-PPS: 0.8615384615384616
# TPR: 0.9655172413793104
# PPV: 0.7777777777777778
# classifier execution on:
# - train file: fold-6-train.csv
# - test file: fold-6-test.csv
# F2-PPS: 0.9150326797385621
# F1-PPS: 0.8484848484848485
# TPR: 0.9655172413793104
# PPV: 0.7567567567567568
# classifier execution on:
# - train file: fold-7-train.csv
# - test file: fold-7-test.csv
# F2-PPS: 0.8881578947368421
# F1-PPS: 0.8307692307692308
# TPR: 0.9310344827586207
# PPV: 0.75
# classifier execution on:
# - train file: fold-8-train.csv
# - test file: fold-8-test.csv
# F2-PPS: 0.8940397350993378
# F1-PPS: 0.8059701492537313
# TPR: 0.9642857142857143
# PPV: 0.6923076923076923
#
# F2-PPS: 0.8842945941702831
# F1-PPS: 0.8093202743992911
# TPR: 0.9428879310344828
# PPV: 0.7097737635927623
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 13, 'metric': 'minkowski'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.8940397350993378
# F1-PPS: 0.8059701492537313
# TPR: 0.9642857142857143
# PPV: 0.6923076923076923
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.8389261744966443
# F1-PPS: 0.7692307692307693
# TPR: 0.8928571428571429
# PPV: 0.6756756756756757
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.9602649006622517
# F1-PPS: 0.90625
# TPR: 1.0
# PPV: 0.8285714285714286
# classifier execution on:
# - train file: fold-4-train.csv
# - test file: fold-4-test.csv
# F2-PPS: 0.8805031446540881
# F1-PPS: 0.7777777777777778
# TPR: 0.9655172413793104
# PPV: 0.6511627906976745
# classifier execution on:
# - train file: fold-5-train.csv
# - test file: fold-5-test.csv
# F2-PPS: 0.9294871794871795
# F1-PPS: 0.8405797101449275
# TPR: 1.0
# PPV: 0.725
# classifier execution on:
# - train file: fold-6-train.csv
# - test file: fold-6-test.csv
# F2-PPS: 0.9271523178807947
# F1-PPS: 0.875
# TPR: 0.9655172413793104
# PPV: 0.8
# classifier execution on:
# - train file: fold-7-train.csv
# - test file: fold-7-test.csv
# F2-PPS: 0.8823529411764706
# F1-PPS: 0.8181818181818182
# TPR: 0.9310344827586207
# PPV: 0.7297297297297297
# classifier execution on:
# - train file: fold-8-train.csv
# - test file: fold-8-test.csv
# F2-PPS: 0.9
# F1-PPS: 0.8181818181818182
# TPR: 0.9642857142857143
# PPV: 0.7105263157894737
#
# F2-PPS: 0.9015907991820958
# F1-PPS: 0.8263965053463553
# TPR: 0.9604371921182266
# PPV: 0.7266217040964593
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 21, 'metric': 'euclidean'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.87248322147651
# F1-PPS: 0.8
# TPR: 0.9285714285714286
# PPV: 0.7027027027027027
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.8108108108108109
# F1-PPS: 0.75
# TPR: 0.8571428571428571
# PPV: 0.6666666666666666
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.9271523178807947
# F1-PPS: 0.875
# TPR: 0.9655172413793104
# PPV: 0.8
# classifier execution on:
# - train file: fold-4-train.csv
# - test file: fold-4-test.csv
# F2-PPS: 0.89171974522293
# F1-PPS: 0.8
# TPR: 0.9655172413793104
# PPV: 0.6829268292682927
# classifier execution on:
# - train file: fold-5-train.csv
# - test file: fold-5-test.csv
# F2-PPS: 0.9150326797385621
# F1-PPS: 0.8484848484848485
# TPR: 0.9655172413793104
# PPV: 0.7567567567567568
# classifier execution on:
# - train file: fold-6-train.csv
# - test file: fold-6-test.csv
# F2-PPS: 0.9121621621621622
# F1-PPS: 0.8852459016393442
# TPR: 0.9310344827586207
# PPV: 0.84375
# classifier execution on:
# - train file: fold-7-train.csv
# - test file: fold-7-test.csv
# F2-PPS: 0.8552631578947368
# F1-PPS: 0.8
# TPR: 0.896551724137931
# PPV: 0.7222222222222222
# classifier execution on:
# - train file: fold-8-train.csv
# - test file: fold-8-test.csv
# F2-PPS: 0.9150326797385621
# F1-PPS: 0.8115942028985508
# TPR: 1.0
# PPV: 0.6829268292682927
#
# F2-PPS: 0.8874570968656337
# F1-PPS: 0.821290619127843
# TPR: 0.9387315270935961
# PPV: 0.7322440008606167
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 21, 'metric': 'manhattan'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.8552631578947368
# F1-PPS: 0.7647058823529411
# TPR: 0.9285714285714286
# PPV: 0.65
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.7876712328767124
# F1-PPS: 0.7419354838709677
# TPR: 0.8214285714285714
# PPV: 0.6764705882352942
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.9271523178807947
# F1-PPS: 0.875
# TPR: 0.9655172413793104
# PPV: 0.8
# classifier execution on:
# - train file: fold-4-train.csv
# - test file: fold-4-test.csv
# F2-PPS: 0.89171974522293
# F1-PPS: 0.8
# TPR: 0.9655172413793104
# PPV: 0.6829268292682927
# classifier execution on:
# - train file: fold-5-train.csv
# - test file: fold-5-test.csv
# F2-PPS: 0.9032258064516129
# F1-PPS: 0.8235294117647058
# TPR: 0.9655172413793104
# PPV: 0.717948717948718
# classifier execution on:
# - train file: fold-6-train.csv
# - test file: fold-6-test.csv
# F2-PPS: 0.9333333333333333
# F1-PPS: 0.8888888888888888
# TPR: 0.9655172413793104
# PPV: 0.8235294117647058
# classifier execution on:
# - train file: fold-7-train.csv
# - test file: fold-7-test.csv
# F2-PPS: 0.8609271523178808
# F1-PPS: 0.8125
# TPR: 0.896551724137931
# PPV: 0.7428571428571429
# classifier execution on:
# - train file: fold-8-train.csv
# - test file: fold-8-test.csv
# F2-PPS: 0.8666666666666667
# F1-PPS: 0.7878787878787878
# TPR: 0.9285714285714286
# PPV: 0.6842105263157895
#
# F2-PPS: 0.8782449265805834
# F1-PPS: 0.8118048068445365
# TPR: 0.9296490147783252
# PPV: 0.7222429020487429
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 21, 'metric': 'minkowski'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.87248322147651
# F1-PPS: 0.8
# TPR: 0.9285714285714286
# PPV: 0.7027027027027027
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.8108108108108109
# F1-PPS: 0.75
# TPR: 0.8571428571428571
# PPV: 0.6666666666666666
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.9271523178807947
# F1-PPS: 0.875
# TPR: 0.9655172413793104
# PPV: 0.8
# classifier execution on:
# - train file: fold-4-train.csv
# - test file: fold-4-test.csv
# F2-PPS: 0.89171974522293
# F1-PPS: 0.8
# TPR: 0.9655172413793104
# PPV: 0.6829268292682927
# classifier execution on:
# - train file: fold-5-train.csv
# - test file: fold-5-test.csv
# F2-PPS: 0.9150326797385621
# F1-PPS: 0.8484848484848485
# TPR: 0.9655172413793104
# PPV: 0.7567567567567568
# classifier execution on:
# - train file: fold-6-train.csv
# - test file: fold-6-test.csv
# F2-PPS: 0.9121621621621622
# F1-PPS: 0.8852459016393442
# TPR: 0.9310344827586207
# PPV: 0.84375
# classifier execution on:
# - train file: fold-7-train.csv
# - test file: fold-7-test.csv
# F2-PPS: 0.8552631578947368
# F1-PPS: 0.8
# TPR: 0.896551724137931
# PPV: 0.7222222222222222
# classifier execution on:
# - train file: fold-8-train.csv
# - test file: fold-8-test.csv
# F2-PPS: 0.9150326797385621
# F1-PPS: 0.8115942028985508
# TPR: 1.0
# PPV: 0.6829268292682927
#
# F2-PPS: 0.8874570968656337
# F1-PPS: 0.821290619127843
# TPR: 0.9387315270935961
# PPV: 0.7322440008606167
# --------------------------------------------------
# seed: 13
# --------------------------------------------------
#
# k-fold-13
#
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 3, 'metric': 'euclidean'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.8585858585858586
# F1-PPS: 0.7555555555555555
# TPR: 0.9444444444444444
# PPV: 0.6296296296296297
# classifier execution on:
# - train file: fold-10-train.csv
# - test file: fold-10-test.csv
# F2-PPS: 0.898876404494382
# F1-PPS: 0.8421052631578947
# TPR: 0.9411764705882353
# PPV: 0.7619047619047619
# classifier execution on:
# - train file: fold-11-train.csv
# - test file: fold-11-test.csv
# F2-PPS: 0.7647058823529411
# F1-PPS: 0.7647058823529411
# TPR: 0.7647058823529411
# PPV: 0.7647058823529411
# classifier execution on:
# - train file: fold-12-train.csv
# - test file: fold-12-test.csv
# F2-PPS: 0.8673469387755102
# F1-PPS: 0.7727272727272727
# TPR: 0.9444444444444444
# PPV: 0.6538461538461539
# classifier execution on:
# - train file: fold-13-train.csv
# - test file: fold-13-test.csv
# F2-PPS: 0.9278350515463918
# F1-PPS: 0.8372093023255814
# TPR: 1.0
# PPV: 0.72
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.8333333333333334
# F1-PPS: 0.7619047619047619
# TPR: 0.8888888888888888
# PPV: 0.6666666666666666
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.8947368421052632
# F1-PPS: 0.8292682926829268
# TPR: 0.9444444444444444
# PPV: 0.7391304347826086
# classifier execution on:
# - train file: fold-4-train.csv
# - test file: fold-4-test.csv
# F2-PPS: 0.9574468085106383
# F1-PPS: 0.9
# TPR: 1.0
# PPV: 0.8181818181818182
# classifier execution on:
# - train file: fold-5-train.csv
# - test file: fold-5-test.csv
# F2-PPS: 0.9090909090909091
# F1-PPS: 0.8
# TPR: 1.0
# PPV: 0.6666666666666666
# classifier execution on:
# - train file: fold-6-train.csv
# - test file: fold-6-test.csv
# F2-PPS: 0.8585858585858586
# F1-PPS: 0.7555555555555555
# TPR: 0.9444444444444444
# PPV: 0.6296296296296297
# classifier execution on:
# - train file: fold-7-train.csv
# - test file: fold-7-test.csv
# F2-PPS: 0.8791208791208791
# F1-PPS: 0.8
# TPR: 0.9411764705882353
# PPV: 0.6956521739130435
# classifier execution on:
# - train file: fold-8-train.csv
# - test file: fold-8-test.csv
# F2-PPS: 0.9444444444444444
# F1-PPS: 0.8717948717948718
# TPR: 1.0
# PPV: 0.7727272727272727
# classifier execution on:
# - train file: fold-9-train.csv
# - test file: fold-9-test.csv
# F2-PPS: 0.9550561797752809
# F1-PPS: 0.8947368421052632
# TPR: 1.0
# PPV: 0.8095238095238095
#
# F2-PPS: 0.8883973377478225
# F1-PPS: 0.8142741230894328
# TPR: 0.9472096530920061
# PPV: 0.7175588384480773
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 3, 'metric': 'manhattan'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.78125
# F1-PPS: 0.7142857142857143
# TPR: 0.8333333333333334
# PPV: 0.625
# classifier execution on:
# - train file: fold-10-train.csv
# - test file: fold-10-test.csv
# F2-PPS: 0.8888888888888888
# F1-PPS: 0.8205128205128205
# TPR: 0.9411764705882353
# PPV: 0.7272727272727273
# classifier execution on:
# - train file: fold-11-train.csv
# - test file: fold-11-test.csv
# F2-PPS: 0.7647058823529411
# F1-PPS: 0.7647058823529411
# TPR: 0.7647058823529411
# PPV: 0.7647058823529411
# classifier execution on:
# - train file: fold-12-train.csv
# - test file: fold-12-test.csv
# F2-PPS: 0.8247422680412371
# F1-PPS: 0.7441860465116279
# TPR: 0.8888888888888888
# PPV: 0.64
# classifier execution on:
# - train file: fold-13-train.csv
# - test file: fold-13-test.csv
# F2-PPS: 0.9278350515463918
# F1-PPS: 0.8372093023255814
# TPR: 1.0
# PPV: 0.72
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.8333333333333334
# F1-PPS: 0.7619047619047619
# TPR: 0.8888888888888888
# PPV: 0.6666666666666666
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.8947368421052632
# F1-PPS: 0.8292682926829268
# TPR: 0.9444444444444444
# PPV: 0.7391304347826086
# classifier execution on:
# - train file: fold-4-train.csv
# - test file: fold-4-test.csv
# F2-PPS: 0.9473684210526315
# F1-PPS: 0.8780487804878049
# TPR: 1.0
# PPV: 0.782608695652174
# ...
# - train file: fold-7-train.csv
# - test file: fold-7-test.csv
# F2-PPS: 0.8695652173913043
# F1-PPS: 0.7804878048780488
# TPR: 0.9411764705882353
# PPV: 0.6666666666666666
# classifier execution on:
# - train file: fold-8-train.csv
# - test file: fold-8-test.csv
# F2-PPS: 0.9340659340659341
# F1-PPS: 0.85
# TPR: 1.0
# PPV: 0.7391304347826086
# classifier execution on:
# - train file: fold-9-train.csv
# - test file: fold-9-test.csv
# F2-PPS: 0.9550561797752809
# F1-PPS: 0.8947368421052632
# TPR: 1.0
# PPV: 0.8095238095238095
#
# F2-PPS: 0.9011864915215309
# F1-PPS: 0.8257145975456246
# TPR: 0.9605329311211664
# PPV: 0.7261189344598956
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 13, 'metric': 'euclidean'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.9183673469387755
# F1-PPS: 0.8181818181818182
# TPR: 1.0
# PPV: 0.6923076923076923
# classifier execution on:
# - train file: fold-10-train.csv
# - test file: fold-10-test.csv
# F2-PPS: 0.898876404494382
# F1-PPS: 0.8421052631578947
# TPR: 0.9411764705882353
# PPV: 0.7619047619047619
# classifier execution on:
# - train file: fold-11-train.csv
# - test file: fold-11-test.csv
# F2-PPS: 0.872093023255814
# F1-PPS: 0.8571428571428571
# TPR: 0.8823529411764706
# PPV: 0.8333333333333334
# classifier execution on:
# - train file: fold-12-train.csv
# - test file: fold-12-test.csv
# F2-PPS: 0.8
# F1-PPS: 0.6956521739130435
# TPR: 0.8888888888888888
# PPV: 0.5714285714285714
# classifier execution on:
# - train file: fold-13-train.csv
# - test file: fold-13-test.csv
# F2-PPS: 0.9375
# F1-PPS: 0.8571428571428571
# TPR: 1.0
# PPV: 0.75
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.8152173913043478
# F1-PPS: 0.7894736842105263
# TPR: 0.8333333333333334
# PPV: 0.75
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.8247422680412371
# F1-PPS: 0.7441860465116279
# TPR: 0.8888888888888888
# PPV: 0.64
# classifier execution on:
# - train file: fold-4-train.csv
# - test file: fold-4-test.csv
# F2-PPS: 0.967741935483871
# F1-PPS: 0.9230769230769231
# TPR: 1.0
# PPV: 0.8571428571428571
# classifier execution on:
# - train file: fold-5-train.csv
# - test file: fold-5-test.csv
# F2-PPS: 0.9574468085106383
# F1-PPS: 0.9
# TPR: 1.0
# PPV: 0.8181818181818182
# classifier execution on:
# - train file: fold-6-train.csv
# - test file: fold-6-test.csv
# F2-PPS: 0.9183673469387755
# F1-PPS: 0.8181818181818182
# TPR: 1.0
# PPV: 0.6923076923076923
# classifier execution on:
# - train file: fold-7-train.csv
# - test file: fold-7-test.csv
# F2-PPS: 0.8695652173913043
# F1-PPS: 0.7804878048780488
# TPR: 0.9411764705882353
# PPV: 0.6666666666666666
# classifier execution on:
# - train file: fold-8-train.csv
# - test file: fold-8-test.csv
# F2-PPS: 0.9239130434782609
# F1-PPS: 0.8292682926829268
# TPR: 1.0
# PPV: 0.7083333333333334
# classifier execution on:
# - train file: fold-9-train.csv
# - test file: fold-9-test.csv
# F2-PPS: 0.9550561797752809
# F1-PPS: 0.8947368421052632
# TPR: 1.0
# PPV: 0.8095238095238095
#
# F2-PPS: 0.8968374588932838
# F1-PPS: 0.8268951062450467
# TPR: 0.9519859225741579
# PPV: 0.7347023489331183
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 13, 'metric': 'manhattan'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.85
# F1-PPS: 0.7391304347826086
# TPR: 0.9444444444444444
# PPV: 0.6071428571428571
# classifier execution on:
# - train file: fold-10-train.csv
# - test file: fold-10-test.csv
# F2-PPS: 0.8888888888888888
# F1-PPS: 0.8205128205128205
# TPR: 0.9411764705882353
# PPV: 0.7272727272727273
# classifier execution on:
# - train file: fold-11-train.csv
# - test file: fold-11-test.csv
# F2-PPS: 0.8620689655172413
# F1-PPS: 0.8333333333333334
# TPR: 0.8823529411764706
# PPV: 0.7894736842105263
# classifier execution on:
# - train file: fold-12-train.csv
# - test file: fold-12-test.csv
# F2-PPS: 0.8163265306122449
# F1-PPS: 0.7272727272727273
# TPR: 0.8888888888888888
# PPV: 0.6153846153846154
# classifier execution on:
# - train file: fold-13-train.csv
# - test file: fold-13-test.csv
# F2-PPS: 0.9183673469387755
# F1-PPS: 0.8181818181818182
# TPR: 1.0
# PPV: 0.6923076923076923
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.8602150537634409
# F1-PPS: 0.8205128205128205
# TPR: 0.8888888888888888
# PPV: 0.7619047619047619
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.8163265306122449
# F1-PPS: 0.7272727272727273
# TPR: 0.8888888888888888
# PPV: 0.6153846153846154
# classifier execution on:
# - train file: fold-4-train.csv
# - test file: fold-4-test.csv
# F2-PPS: 0.9473684210526315
# F1-PPS: 0.8780487804878049
# TPR: 1.0
# PPV: 0.782608695652174
# classifier execution on:
# - train file: fold-5-train.csv
# - test file: fold-5-test.csv
# F2-PPS: 0.8947368421052632
# F1-PPS: 0.8292682926829268
# TPR: 0.9444444444444444
# PPV: 0.7391304347826086
# classifier execution on:
# - train file: fold-6-train.csv
# - test file: fold-6-test.csv
# F2-PPS: 0.9375
# F1-PPS: 0.8571428571428571
# TPR: 1.0
# PPV: 0.75
# classifier execution on:
# - train file: fold-7-train.csv
# - test file: fold-7-test.csv
# F2-PPS: 0.8888888888888888
# F1-PPS: 0.8205128205128205
# TPR: 0.9411764705882353
# PPV: 0.7272727272727273
# classifier execution on:
# - train file: fold-8-train.csv
# - test file: fold-8-test.csv
# F2-PPS: 0.9139784946236559
# F1-PPS: 0.8095238095238095
# TPR: 1.0
# PPV: 0.68
# classifier execution on:
# - train file: fold-9-train.csv
# - test file: fold-9-test.csv
# F2-PPS: 0.9444444444444444
# F1-PPS: 0.8717948717948718
# TPR: 1.0
# PPV: 0.7727272727272727
#
# F2-PPS: 0.8876238774959785
# F1-PPS: 0.8117313933856883
# TPR: 0.9477124183006537
# PPV: 0.7123546218494291
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 13, 'metric': 'minkowski'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.9183673469387755
# F1-PPS: 0.8181818181818182
# TPR: 1.0
# PPV: 0.6923076923076923
# classifier execution on:
# - train file: fold-10-train.csv
# - test file: fold-10-test.csv
# F2-PPS: 0.898876404494382
# F1-PPS: 0.8421052631578947
# TPR: 0.9411764705882353
# PPV: 0.7619047619047619
# classifier execution on:
# - train file: fold-11-train.csv
# - test file: fold-11-test.csv
# F2-PPS: 0.872093023255814
# F1-PPS: 0.8571428571428571
# TPR: 0.8823529411764706
# PPV: 0.8333333333333334
# classifier execution on:
# - train file: fold-12-train.csv
# - test file: fold-12-test.csv
# F2-PPS: 0.8
# F1-PPS: 0.6956521739130435
# TPR: 0.8888888888888888
# PPV: 0.5714285714285714
# classifier execution on:
# - train file: fold-13-train.csv
# - test file: fold-13-test.csv
# F2-PPS: 0.9375
# F1-PPS: 0.8571428571428571
# TPR: 1.0
# PPV: 0.75
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.8152173913043478
# F1-PPS: 0.7894736842105263
# TPR: 0.8333333333333334
# PPV: 0.75
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.8247422680412371
# F1-PPS: 0.7441860465116279
# TPR: 0.8888888888888888
# PPV: 0.64
# classifier execution on:
# - train file: fold-4-train.csv
# - test file: fold-4-test.csv
# F2-PPS: 0.967741935483871
# F1-PPS: 0.9230769230769231
# TPR: 1.0
# PPV: 0.8571428571428571
# classifier execution on:
# - train file: fold-5-train.csv
# - test file: fold-5-test.csv
# F2-PPS: 0.9574468085106383
# F1-PPS: 0.9
# TPR: 1.0
# PPV: 0.8181818181818182
# classifier execution on:
# - train file: fold-6-train.csv
# - test file: fold-6-test.csv
# F2-PPS: 0.9183673469387755
# F1-PPS: 0.8181818181818182
# TPR: 1.0
# PPV: 0.6923076923076923
# classifier execution on:
# - train file: fold-7-train.csv
# - test file: fold-7-test.csv
# F2-PPS: 0.8695652173913043
# F1-PPS: 0.7804878048780488
# TPR: 0.9411764705882353
# PPV: 0.6666666666666666
# classifier execution on:
# - train file: fold-8-train.csv
# - test file: fold-8-test.csv
# F2-PPS: 0.9239130434782609
# F1-PPS: 0.8292682926829268
# TPR: 1.0
# PPV: 0.7083333333333334
# classifier execution on:
# - train file: fold-9-train.csv
# - test file: fold-9-test.csv
# F2-PPS: 0.9550561797752809
# F1-PPS: 0.8947368421052632
# TPR: 1.0
# PPV: 0.8095238095238095
#
# F2-PPS: 0.8968374588932838
# F1-PPS: 0.8268951062450467
# TPR: 0.9519859225741579
# PPV: 0.7347023489331183
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 21, 'metric': 'euclidean'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.8673469387755102
# F1-PPS: 0.7727272727272727
# TPR: 0.9444444444444444
# PPV: 0.6538461538461539
# classifier execution on:
# - train file: fold-10-train.csv
# - test file: fold-10-test.csv
# F2-PPS: 0.9090909090909091
# F1-PPS: 0.8648648648648649
# TPR: 0.9411764705882353
# PPV: 0.8
# classifier execution on:
# - train file: fold-11-train.csv
# - test file: fold-11-test.csv
# F2-PPS: 0.872093023255814
# F1-PPS: 0.8571428571428571
# TPR: 0.8823529411764706
# PPV: 0.8333333333333334
# classifier execution on:
# - train file: fold-12-train.csv
# - test file: fold-12-test.csv
# F2-PPS: 0.8762886597938144
# F1-PPS: 0.7906976744186046
# TPR: 0.9444444444444444
# PPV: 0.68
# classifier execution on:
# - train file: fold-13-train.csv
# - test file: fold-13-test.csv
# F2-PPS: 0.9183673469387755
# F1-PPS: 0.8181818181818182
# TPR: 1.0
# PPV: 0.6923076923076923
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.8602150537634409
# F1-PPS: 0.8205128205128205
# TPR: 0.8888888888888888
# PPV: 0.7619047619047619
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.7894736842105263
# F1-PPS: 0.7317073170731707
# TPR: 0.8333333333333334
# PPV: 0.6521739130434783
# classifier execution on:
# - train file: fold-4-train.csv
# - test file: fold-4-test.csv
# F2-PPS: 0.9574468085106383
# F1-PPS: 0.9
# TPR: 1.0
# PPV: 0.8181818181818182
# classifier execution on:
# - train file: fold-5-train.csv
# - test file: fold-5-test.csv
# F2-PPS: 0.8947368421052632
# F1-PPS: 0.8292682926829268
# TPR: 0.9444444444444444
# PPV: 0.7391304347826086
# classifier execution on:
# - train file: fold-6-train.csv
# - test file: fold-6-test.csv
# F2-PPS: 0.9278350515463918
# F1-PPS: 0.8372093023255814
# TPR: 1.0
# PPV: 0.72
# classifier execution on:
# - train file: fold-7-train.csv
# - test file: fold-7-test.csv
# F2-PPS: 0.8791208791208791
# F1-PPS: 0.8
# TPR: 0.9411764705882353
# PPV: 0.6956521739130435
# classifier execution on:
# - train file: fold-8-train.csv
# - test file: fold-8-test.csv
# F2-PPS: 0.9340659340659341
# F1-PPS: 0.85
# TPR: 1.0
# PPV: 0.7391304347826086
# classifier execution on:
# - train file: fold-9-train.csv
# - test file: fold-9-test.csv
# F2-PPS: 0.9090909090909091
# F1-PPS: 0.8648648648648649
# TPR: 0.9411764705882353
# PPV: 0.8
#
# F2-PPS: 0.8919363107899081
# F1-PPS: 0.8259366988303678
# TPR: 0.9431875314228256
# PPV: 0.7373585166227308
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 21, 'metric': 'manhattan'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.85
# F1-PPS: 0.7391304347826086
# TPR: 0.9444444444444444
# PPV: 0.6071428571428571
# classifier execution on:
# - train file: fold-10-train.csv
# - test file: fold-10-test.csv
# F2-PPS: 0.9090909090909091
# F1-PPS: 0.8648648648648649
# TPR: 0.9411764705882353
# PPV: 0.8
# classifier execution on:
# - train file: fold-11-train.csv
# - test file: fold-11-test.csv
# F2-PPS: 0.8235294117647058
# F1-PPS: 0.8235294117647058
# TPR: 0.8235294117647058
# PPV: 0.8235294117647058
# classifier execution on:
# - train file: fold-12-train.csv
# - test file: fold-12-test.csv
# F2-PPS: 0.8247422680412371
# F1-PPS: 0.7441860465116279
# TPR: 0.8888888888888888
# PPV: 0.64
# classifier execution on:
# - train file: fold-13-train.csv
# - test file: fold-13-test.csv
# F2-PPS: 0.8762886597938144
# F1-PPS: 0.7906976744186046
# TPR: 0.9444444444444444
# PPV: 0.68
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.8602150537634409
# F1-PPS: 0.8205128205128205
# TPR: 0.8888888888888888
# PPV: 0.7619047619047619
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.7894736842105263
# F1-PPS: 0.7317073170731707
# TPR: 0.8333333333333334
# PPV: 0.6521739130434783
# classifier execution on:
# - train file: fold-4-train.csv
# - test file: fold-4-test.csv
# F2-PPS: 0.9473684210526315
# F1-PPS: 0.8780487804878049
# TPR: 1.0
# PPV: 0.782608695652174
# classifier execution on:
# - train file: fold-5-train.csv
# - test file: fold-5-test.csv
# F2-PPS: 0.8947368421052632
# F1-PPS: 0.8292682926829268
# TPR: 0.9444444444444444
# PPV: 0.7391304347826086
# classifier execution on:
# - train file: fold-6-train.csv
# - test file: fold-6-test.csv
# F2-PPS: 0.9375
# F1-PPS: 0.8571428571428571
# TPR: 1.0
# PPV: 0.75
# classifier execution on:
# - train file: fold-7-train.csv
# - test file: fold-7-test.csv
# F2-PPS: 0.8695652173913043
# F1-PPS: 0.7804878048780488
# TPR: 0.9411764705882353
# PPV: 0.6666666666666666
# classifier execution on:
# - train file: fold-8-train.csv
# - test file: fold-8-test.csv
# F2-PPS: 0.9340659340659341
# F1-PPS: 0.85
# TPR: 1.0
# PPV: 0.7391304347826086
# classifier execution on:
# - train file: fold-9-train.csv
# - test file: fold-9-test.csv
# F2-PPS: 0.898876404494382
# F1-PPS: 0.8421052631578947
# TPR: 0.9411764705882353
# PPV: 0.7619047619047619
#
# F2-PPS: 0.8781117542903192
# F1-PPS: 0.8116678129444566
# TPR: 0.930115635997989
# PPV: 0.7233993798188171
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 21, 'metric': 'minkowski'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.8673469387755102
# F1-PPS: 0.7727272727272727
# TPR: 0.9444444444444444
# PPV: 0.6538461538461539
# classifier execution on:
# - train file: fold-10-train.csv
# - test file: fold-10-test.csv
# F2-PPS: 0.9090909090909091
# F1-PPS: 0.8648648648648649
# TPR: 0.9411764705882353
# PPV: 0.8
# classifier execution on:
# - train file: fold-11-train.csv
# - test file: fold-11-test.csv
# F2-PPS: 0.872093023255814
# F1-PPS: 0.8571428571428571
# TPR: 0.8823529411764706
# PPV: 0.8333333333333334
# classifier execution on:
# - train file: fold-12-train.csv
# - test file: fold-12-test.csv
# F2-PPS: 0.8762886597938144
# F1-PPS: 0.7906976744186046
# TPR: 0.9444444444444444
# PPV: 0.68
# classifier execution on:
# - train file: fold-13-train.csv
# - test file: fold-13-test.csv
# F2-PPS: 0.9183673469387755
# F1-PPS: 0.8181818181818182
# TPR: 1.0
# PPV: 0.6923076923076923
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.8602150537634409
# F1-PPS: 0.8205128205128205
# TPR: 0.8888888888888888
# PPV: 0.7619047619047619
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.7894736842105263
# F1-PPS: 0.7317073170731707
# TPR: 0.8333333333333334
# PPV: 0.6521739130434783
# classifier execution on:
# - train file: fold-4-train.csv
# - test file: fold-4-test.csv
# F2-PPS: 0.9574468085106383
# F1-PPS: 0.9
# TPR: 1.0
# PPV: 0.8181818181818182
# classifier execution on:
# - train file: fold-5-train.csv
# - test file: fold-5-test.csv
# F2-PPS: 0.8947368421052632
# F1-PPS: 0.8292682926829268
# TPR: 0.9444444444444444
# PPV: 0.7391304347826086
# classifier execution on:
# - train file: fold-6-train.csv
# - test file: fold-6-test.csv
# F2-PPS: 0.9278350515463918
# F1-PPS: 0.8372093023255814
# TPR: 1.0
# PPV: 0.72
# classifier execution on:
# - train file: fold-7-train.csv
# - test file: fold-7-test.csv
# F2-PPS: 0.8791208791208791
# F1-PPS: 0.8
# TPR: 0.9411764705882353
# PPV: 0.6956521739130435
# classifier execution on:
# - train file: fold-8-train.csv
# - test file: fold-8-test.csv
# F2-PPS: 0.9340659340659341
# F1-PPS: 0.85
# TPR: 1.0
# PPV: 0.7391304347826086
# classifier execution on:
# - train file: fold-9-train.csv
# - test file: fold-9-test.csv
# F2-PPS: 0.9090909090909091
# F1-PPS: 0.8648648648648649
# TPR: 0.9411764705882353
# PPV: 0.8
#
# F2-PPS: 0.8919363107899081
# F1-PPS: 0.8259366988303678
# TPR: 0.9431875314228256
# PPV: 0.7373585166227308

# %% [markdown]
# ## *Statistical* **Data Analysis**

# %% [markdown]
# **Requirements**

# %%
import os
import glob
import numpy as np
import pandas as pd
import scipy.stats as stats

import seaborn as sns
import matplotlib.pyplot as plt

from typing import List, Dict

# %%
np.random.seed(42)

# %%
device = 'cpu'
device
# Out:
# 'cpu'

# %%
branch = os.path.join(f"/content/drive/MyDrive/{paths['notebook-results']}", 'k-nearest-neighbors-params')

# %%
output = os.path.join(branch, 'BiomedNLP-BiomedBERT-base-uncased-abstract')

# %% [markdown]
# *Evaluation Metrics Sorting Criteria*

# %%
order = [
    'F2-PPS', # F2-Score (Class 1 - Patient Preference Studies)
    'F1-PPS', # F1-Score (Class 1 - Patient Preference Studies)
    'TPR',    # True Positive Rate
    'PPV',    # Positive Predictive Value
    'AUC-PR', # Area Under Precision-Recall Curve
    'BA',     # Balanced Accuracy
    'AUC-ROC' # Area Under ROC Curve
]

# %%
def combine(
    dir: str,
    main: List[str],
    order: List[str]
) -> pd.DataFrame:
    """
    combine multiple .csv files into a single DataFrame

    args:
        dir (str): path to the folder with .csv files
        main (List[str]): main group-by columns
        order (List[str]): evaluation metrics sorting criteria

    returns:
        pd.DataFrame: DataFrame with scores
    """
    files = glob.glob(os.path.join(dir, "*.csv"))
    data = list()
    for file in files:
        frame = pd.read_csv(file)
        data.append(frame)
    concat = pd.concat(data)
    data = (
        concat.groupby(main)
        .agg(
            ['mean', 'std']
        )
        .reset_index()
    )
    data.columns = [
        '-'.join(column).strip('-') for column in data.columns
        if column not in main
    ]
    for column in data.columns:
        if column.endswith('-mean'):
            base = column.rsplit('-', 1)[0]
            deviation = f'{base}-std'
            if deviation in data.columns:
                # compute confidence interval
                N = len(concat.groupby(main))
                sem = data[deviation] / np.sqrt(N)
                deg = N - 1
                # 99% confidence level
                critical = stats.t.ppf(0.995, deg)
                lower = data[column] - critical * sem
                upper = data[column] + critical * sem
                data[f'{base}-ci'] = (
                    data[column].round(3).astype(str) + " ± " +
                    ((upper - lower) / 2).round(3).astype(str)
                )
    data = data.sort_values(
        by=[f"{metric}-mean" for metric in order],
        ascending=[False] * len(order)
    )
    columns = [
        column for column in data.columns
        if column.endswith('-ci')
    ]
    data = data[main + columns]
    data.columns = [
        column.replace('-ci', '') for column in data.columns
    ]
    return data

# %%
def get(
    data: pd.DataFrame,
    case: str,
    order: List[str]
) -> pd.DataFrame:
    """
    get a dataframe by group-by on input column

    args:
        data (pd.DataFrame): DataFrame with evaluation results
        case (str): group-by column to plot (e.g., 'BERT-Base Model')
        order (List[str]): evaluation metrics sorting criteria

    returns:
        pd.DataFrame: DataFrame with scores
    """
    data = data[[case] + order].copy()
    for metric in order:
        data[metric] = data[metric].str.extract(r'(\d+\.\d+)').astype(float)
    res = (
        data.groupby(case)
        .agg(
            ['mean', 'std']
        )
        .reset_index()
    )
    res.columns = [
        '-'.join(column).strip('-') for column in res.columns
        if column not in [case]
    ]
    for column in res.columns:
        if column.endswith('-mean'):
            base = column.rsplit('-', 1)[0]
            deviation = f'{base}-std'
            if deviation in res.columns:
                # compute confidence interval
                N = len(data.groupby([case]))
                sem = res[deviation] / np.sqrt(N)
                deg = N - 1
                # 99% confidence level
                critical = stats.t.ppf(0.995, deg)
                lower = res[column] - critical * sem
                upper = res[column] + critical * sem
                res[f'{base}-ci'] = (
                    res[column].round(3).astype(str) + " ± " +
                    ((upper - lower) / 2).round(3).astype(str)
                )
    res = res.sort_values(
        by=[f"{metric}-mean" for metric in order],
        ascending=[False] * len(order)
    )
    columns = [
        column for column in res.columns
        if column.endswith('-ci')
    ]
    res = res[[case] + columns]
    res.columns = [
        column.replace('-ci', '') for column in res.columns
    ]
    return res

# %%
def plot(
    data: pd.DataFrame,
    column: str,
    output: str,
    order: List[str]
) -> None:
    """
    plot performance metrics with confidence intervals

    args:
        data (pd.DataFrame): DataFrame with evaluation results
        column (str): group-by column to plot (e.g., 'BERT-Base Model')
        output (str): path to output folder to store plot
        order (List[str]): evaluation metrics sorting criteria
    """
    chart = list()
    for metric in order:
        if metric in data.columns:
            for _, row in data.iterrows():
                ci = row[metric].split(' ± ')
                mean = float(ci[0])
                error = float(ci[1])
                chart.append({
                    column: row[column],
                    'Metric': metric,
                    'Mean': mean,
                    'Error': error
                })
    chart = pd.DataFrame(chart)
    chart[column] = chart[column].astype(str)
    plt.figure(figsize=(16, 9))
    position = -0.75
    ax = sns.barplot(
        chart,
        x=column,
        y='Mean',
        hue='Metric',
        ci=None,
        palette='crest'
    )
    for bar, (_, row) in zip(ax.patches, chart.iterrows()):
        center = bar.get_x() + bar.get_width() / 2
        lower = row['Mean'] - row['Error']
        upper = row['Mean'] + row['Error']
        plt.errorbar(
            x=center,
            y=row['Mean'],
            yerr=row['Error'],
            fmt='none',
            color='black',
            linestyle='-',
            linewidth=0.5
        )
    for idx, metric in enumerate(chart['Metric'].unique()):
        columns = chart[chart['Metric'] == metric]
        row = columns.loc[columns['Mean'].idxmax()]
        value = row['Mean']
        center = (
            ax.patches[
                chart.index.get_loc(row.name)
            ].get_x() +
            ax.patches[
                chart.index.get_loc(row.name)
            ].get_width() / 2
        )
        if metric == 'F2-PPS':
            ax.plot(
                [center, position],
                [value, value],
                color='black',
                linestyle='--',
                linewidth=0.5
            )
            ax.text(
                x=position,
                y=value,
                s=f'{value:.3f}',
                ha='right',
                va='center',
                fontsize=10
            )
    plt.title(
        f'{column} Performance Distributions',
        fontsize=15
    )
    plt.xlabel(
        column,
        fontsize=10
    )
    plt.ylabel(
        'Metric Value',
        fontsize=10
    )
    plt.legend(
        title=f'Metric',
        bbox_to_anchor=(1.05, 1),
        loc='upper left'
    )
    ax.set_xticklabels(
        ax.get_xticklabels(),
        rotation=45,
        ha="right",
        rotation_mode='anchor'
    )
    plt.ylim(
        bottom=min(
            chart['Mean'] - chart['Error']
        )
    )
    plt.tight_layout()
    plt.savefig(
        f'{output}/{column.lower().replace(" ", "-")}-performance-plot.png',
        dpi=300,
        bbox_inches='tight'
    )
    plt.show()

# %% [markdown]
# **Global** *Statistical Data Analysis*

# %%
results = combine(
    dir = output,
    main = ['K-Nearest Neighbors Parameters'],
    order = order
)
results.head()
# Out:
#                 K-Nearest Neighbors Parameters         F2-PPS         F1-PPS  \
# 0   {'n_neighbors': 13, 'metric': 'euclidean'}  0.891 ± 0.008   0.818 ± 0.01
# 2   {'n_neighbors': 13, 'metric': 'minkowski'}  0.891 ± 0.008   0.818 ± 0.01
# 3   {'n_neighbors': 21, 'metric': 'euclidean'}  0.887 ± 0.002  0.822 ± 0.004
# 5   {'n_neighbors': 21, 'metric': 'minkowski'}  0.887 ± 0.002  0.822 ± 0.004
# 12   {'n_neighbors': 8, 'metric': 'euclidean'}  0.885 ± 0.012   0.81 ± 0.014
#
#               TPR            FNR            PPV            FDR         AUC-PR  \
# 0   0.949 ± 0.007  0.051 ± 0.007  0.721 ± 0.014  0.279 ± 0.014  0.929 ± 0.007
# 2   0.949 ± 0.007  0.051 ± 0.007  0.721 ± 0.014  0.279 ± 0.014  0.929 ± 0.007
# 3   0.938 ± 0.003  0.062 ± 0.003  0.734 ± 0.008  0.266 ± 0.008  0.934 ± 0.003
# 5   0.938 ± 0.003  0.062 ± 0.003  0.734 ± 0.008  0.266 ± 0.008  0.934 ± 0.003
# 12  0.945 ± 0.011  0.055 ± 0.011  0.712 ± 0.018  0.288 ± 0.018  0.914 ± 0.012
#
#                BA        AUC-ROC  ...            FPR            NPV  \
# 0   0.931 ± 0.005  0.978 ± 0.001  ...  0.087 ± 0.004  0.987 ± 0.002
# 2   0.931 ± 0.005  0.978 ± 0.001  ...  0.087 ± 0.004  0.987 ± 0.002
# 3   0.929 ± 0.001  0.977 ± 0.001  ...  0.081 ± 0.002  0.985 ± 0.001
# 5   0.929 ± 0.001  0.977 ± 0.001  ...  0.081 ± 0.002  0.985 ± 0.001
# 12  0.927 ± 0.008  0.977 ± 0.002  ...   0.09 ± 0.006  0.986 ± 0.003
#
#               FOR       Accuracy Weighted F1-Score Weighted Precision  \
# 0   0.013 ± 0.002  0.919 ± 0.004     0.924 ± 0.004      0.937 ± 0.004
# 2   0.013 ± 0.002  0.919 ± 0.004     0.924 ± 0.004      0.937 ± 0.004
# 3   0.015 ± 0.001  0.923 ± 0.002     0.926 ± 0.001      0.937 ± 0.002
# 5   0.015 ± 0.001  0.923 ± 0.002     0.926 ± 0.001      0.937 ± 0.002
# 12  0.014 ± 0.003  0.916 ± 0.006     0.921 ± 0.006      0.935 ± 0.006
#
#    Weighted Recall Macro F1-Score Macro Precision   Macro Recall
# 0    0.919 ± 0.004  0.883 ± 0.006   0.854 ± 0.008  0.931 ± 0.005
# 2    0.919 ± 0.004  0.883 ± 0.006   0.854 ± 0.008  0.931 ± 0.005
# 3    0.923 ± 0.002  0.886 ± 0.002   0.859 ± 0.004  0.929 ± 0.001
# 5    0.923 ± 0.002  0.886 ± 0.002   0.859 ± 0.004  0.929 ± 0.001
# 12   0.916 ± 0.006  0.878 ± 0.009    0.849 ± 0.01  0.927 ± 0.008
#
# [5 rows x 25 columns]

# %%
results.to_csv(os.path.join(output, f'ranks.csv'), encoding='utf-8', index=False)

# %% [markdown]
# **Local** *Statistical Data Analysis* - **by K-Nearest Neighbors Classifier Parameters**

# %%
frame = results[['K-Nearest Neighbors Parameters'] + order].copy()

plot(frame, 'K-Nearest Neighbors Parameters', output, order)

# %% [markdown]
# *What to* **Move Forward**

# %%
def select(
    dir: str,
    title: str,
    column: str,
    output: str,
    main: List[str],
    order: List[str],
    model: Dict[str, str] = None
) -> pd.DataFrame:
    """
    what to move forward

    args:
        dir (str): path to the folder with .csv file
        title (str): plot title
        column (str): group-by column to plot (e.g., 'BERT-Base Model')
        output (str): path to output folder to store plot
        main (List[str]): main group-by columns
        order (List[str]): evaluation metrics sorting criteria
        model (Dict[str, str], optional): dictionary with {'BERT-Base Model': 'bert-base model'} to filter

    returns:
        pd.DataFrame: DataFrame with scores
    """
    data = pd.read_csv(dir)
    data = data[main + order]
    if model:
        key, value = next(iter(model.items()))
        data = data[data[key] == value]
    def lower(value):
        base, error = map(float, value.split(' ± '))
        return base - error
    for metric in order:
        data[metric] = data[metric].apply(lower)
    data = data.sort_values(
        by=order,
        ascending=[False] * len(order)
    )
    data.to_csv(os.path.join(output, f'{title.lower().replace(" ", "-")}-ranks.csv'), encoding='utf-8', index=False)
    chart = []
    for metric in order:
        if metric in data.columns:
            for _, row in data.iterrows():
                mean = float(row[metric])
                chart.append({
                    column: row[column],
                    'Metric': metric,
                    'Mean': mean
                })
    chart = pd.DataFrame(chart)
    chart[column] = chart[column].astype(str)
    plt.figure(figsize=(16, 9))
    position = -0.75
    ax = sns.barplot(
        chart,
        x=column,
        y='Mean',
        hue='Metric',
        palette='crest'
    )
    for idx, metric in enumerate(chart['Metric'].unique()):
        columns = chart[chart['Metric'] == metric]
        row = columns.loc[columns['Mean'].idxmax()]
        value = row['Mean']
        center = (
            ax.patches[
                chart.index.get_loc(row.name)
            ].get_x() +
            ax.patches[
                chart.index.get_loc(row.name)
            ].get_width() / 2
        )
        if metric == 'F2-PPS':
            ax.plot(
                [center, position],
                [value, value],
                color='black',
                linestyle='--',
                linewidth=0.5
            )
            ax.text(
                x=position,
                y=value,
                s=f'{value:.3f}',
                ha='right',
                va='center',
                fontsize=10
            )
    plt.title(
        f'{title} Performance Distributions',
        fontsize=15
    )
    plt.xlabel(
        column,
        fontsize=10
    )
    plt.ylabel(
        'Metric Value',
        fontsize=10
    )
    plt.legend(
        title=f'Metric',
        bbox_to_anchor=(1.05, 1),
        loc='upper left'
    )
    ax.set_xticklabels(
        ax.get_xticklabels(),
        rotation=45,
        ha="right",
        rotation_mode='anchor'
    )
    plt.ylim(
        bottom=min(
            chart['Mean']
        )
    )
    plt.tight_layout()
    plt.savefig(
        f'{output}/{title.lower().replace(" ", "-")}-performance-plot.png',
        dpi=300,
        bbox_inches='tight'
    )
    plt.show()
    return data

# %% [markdown]
# * Select the **K-Nearest Neighbors Classifier Parameters** with the *highest performance at the lower bound of the confidence interval*

# %%
base = select(
    dir = os.path.join(output, f'ranks.csv'),
    title = "SOTA K-Nearest Neighbors Classifier Parameters",
    column = 'K-Nearest Neighbors Parameters',
    output = output,
    main = ['K-Nearest Neighbors Parameters'],
    order = order,
    model = None
)

# %% [markdown]
# # **Design & Test** *K-Nearest Neighbors Classifier* **Parameters** for **pubmedbert-base-embeddings**

# %% [markdown]
# ## **Design & Test** *K-Nearest Neighbors Classifier* **Parameters**

# %% [markdown]
# **Requirements**

# %%
import os
import numpy as np
import pandas as pd

from typing import Dict, List, Tuple, Union

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
from itertools import product
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    accuracy_score,
    balanced_accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    matthews_corrcoef,
    fbeta_score,
    roc_auc_score,
    average_precision_score,
    log_loss,
    brier_score_loss
)

# %%
np.random.seed(42)

# %%
device = 'cpu'
device
# Out:
# 'cpu'

# %%
input = f"/content/drive/MyDrive/{paths['input-data']}"

# %%
branch = os.path.join(f"/content/drive/MyDrive/{paths['notebook-results']}", 'k-nearest-neighbors-params')
if not os.path.exists(branch):
    os.makedirs(branch)

# %% [markdown]
# *pubmedbert-base-embeddings*

# %%
output = os.path.join(branch, 'pubmedbert-base-embeddings')
if not os.path.exists(output):
    os.makedirs(output)

# %%
with open(os.path.join(output, 'logs.txt'), 'w') as file:
    pass

# %% [markdown]
# **BERT-Base Model:** *pubmedbert-base-embeddings*

# %%
model = os.path.join(f"/content/drive/MyDrive/{paths['bert-embeddings']}", 'pubmedbert-base-embeddings')

# %% [markdown]
# **T&A Link:** *vector-concatenation-classification-token*

# %%
link = 'vector-concatenation-classification-token.pkl'

# %% [markdown]
# **K-Nearest Neighbors Classifier Parameters**

# %%
params = {
    'n_neighbors': [
        3, 5, 8, 13, 21
    ],
    'metric': [
        'euclidean',
        'manhattan',
        'minkowski'
    ]
}

# %% [markdown]
# **Evaluation Metrics**

# %%
def compute(
    y_true: np.ndarray,
    y_pred: np.ndarray,
    y_prob: np.ndarray
) -> Dict[str, float]:
    """
    compute classification metrics for predictions

    args:
        y_true (np.ndarray): ground truth labels for the test set
        y_pred (np.ndarray): predictions for the test set
        y_prob (np.ndarray): probabilities for the positive class

    returns:
        Dict[str, float]: a dictionary with classification metrics
    """
    metrics = {
        'F2-PPS': fbeta_score(
            y_true, y_pred, beta=2, pos_label=1
        ),  # F2-Score (Class 1)
        'F1-PPS': f1_score(
            y_true, y_pred, pos_label=1
        ),  # F1-Score (Class 1)

        'TPR': recall_score(
            y_true, y_pred, pos_label=1
        ),  # True Positive Rate (TPR)
        'FNR': 1 - recall_score(
            y_true, y_pred, pos_label=1
        ),  # False Negative Rate (FNR)
        'PPV': precision_score(
            y_true, y_pred, pos_label=1
        ),  # Positive Predictive Value (PPV)
        'FDR': 1 - precision_score(
            y_true, y_pred, pos_label=1
        ),  # False Discovery Rate (FDR)

        'AUC-PR': average_precision_score(
            y_true, y_prob
        ),  # Area Under Precision-Recall Curve (AUC-PR)
        'BA': balanced_accuracy_score(
            y_true, y_pred
        ),  # Balanced Accuracy (BA)
        'AUC-ROC': roc_auc_score(
            y_true, y_prob
        ),  # Area Under ROC Curve (AUC-ROC)

        'G-Mean': np.sqrt(
            recall_score(
                y_true, y_pred, pos_label=1
            ) *
            recall_score(
                y_true, y_pred, pos_label=0
            )
        ),  # Geometric Mean (G-Mean)
        'MCC': matthews_corrcoef(
            y_true, y_pred
        ),  # Matthews Correlation Coefficient (MCC)

        'Log-Loss': log_loss(
            y_true, y_prob
        ),  # Log-Loss
        'BS': brier_score_loss(
            y_true, y_prob
        ),  # Brier Score

        'TNR': recall_score(
            y_true, y_pred, pos_label=0
        ),  # True Negative Rate (TNR)
        'FPR': 1 - recall_score(
            y_true, y_pred, pos_label=0
        ),  # False Positive Rate (FPR)
        'NPV': precision_score(
            y_true, y_pred, pos_label=0
        ),  # Negative Predictive Value (NPV)
        'FOR': 1 - precision_score(
            y_true, y_pred, pos_label=0
        ),  # False Omission Rate (FOR)

        'Accuracy': accuracy_score(
            y_true, y_pred
        ),  # Accuracy
        'Weighted F1-Score': f1_score(
            y_true, y_pred, average='weighted'
        ),  # Weighted F1-Score
        'Weighted Precision': precision_score(
            y_true, y_pred, average='weighted'
        ),  # Weighted Precision
        'Weighted Recall': recall_score(
            y_true, y_pred, average='weighted'
        ),  # Weighted Recall
        'Macro F1-Score': f1_score(
            y_true, y_pred, average='macro'
        ),  # Macro F1-Score
        'Macro Precision': precision_score(
            y_true, y_pred, average='macro'
        ),  # Macro Precision
        'Macro Recall': recall_score(
            y_true, y_pred, average='macro'
        )   # Macro Recall
    }
    return metrics

# %% [markdown]
# *Evaluation Metrics Sorting Criteria*

# %%
order = [
    'F2-PPS', # F2-Score (Class 1 - Patient Preference Studies)
    'F1-PPS', # F1-Score (Class 1 - Patient Preference Studies)
    'TPR',    # True Positive Rate
    'PPV',    # Positive Predictive Value
    'AUC-PR', # Area Under Precision-Recall Curve
    'BA',     # Balanced Accuracy
    'AUC-ROC' # Area Under ROC Curve
]

# %% [markdown]
# **Binary Classification**

# %%
def evaluate(
    dir: str,
    loc: str,
    case: str,
    input: str,
    output: str,
    params: Dict[str, List[Union[Tuple[int, ...], str]]],
    order: List[str]
) -> pd.DataFrame:
    """
    evaluate k-nearest neighbors classifier parameters for class prediction

    args:
        dir (str): path to the directory with bert-base model
        loc (str): path to file with title-abstract link (.pkl file)
        case (str): cross-validation case identifier (e.g. 'k-fold-2' or 'k-fold-3')
        input (str): path to the input folder with data and splits
        output (str): path to output folder to store logs
        params (Dict[str, List[Union[Tuple[int, ...], str]]]): a dictionary of params
        order (List[str]): evaluation metrics sorting criteria

    returns:
        pd.DataFrame: DataFrame with evaluation results
    """

    def add(
        by: str,
        to: str
    ) -> pd.DataFrame:
        """
        add an embeddings column to the input split file

        args:
            by (str): path to the .pkl file with embeddings
            to (str): path to the .csv split file
        """
        dataset = pd.read_pickle(by)
        frame = pd.read_csv(to)
        embeddings = [
            column for column in dataset.columns
            if column not in ['title', 'abstract', 'label']
        ]
        data = frame.merge(
            dataset[['title', 'abstract', 'label'] + embeddings],
            on=['title', 'abstract', 'label'],
            how='left'
        )
        return data

    def collect(
        dir: str
    ) -> List[Tuple[str, str]]:
        """
        collect train and test file pairs from the directory

        args:
            dir (str): path to the directory with train/test files

        returns:
            List[Tuple[str, str]]: list of (train file, test file) tuples
        """
        files = {'train': [], 'test': []}
        for idx, _, walk in os.walk(dir):
            for file in walk:
                if file.endswith('.csv'):
                    if 'train' in file:
                        files['train'].append(
                            os.path.join(idx, file)
                        )
                    elif 'test' in file:
                        files['test'].append(
                            os.path.join(idx, file)
                        )
        files['train'].sort()
        files['test'].sort()
        return list(zip(files['train'], files['test']))

    log = f'\n{case}\n'
    with open(os.path.join(output, 'logs.txt'), 'a') as file:
        file.write(log + '\n')
    print(log)
    combinations = [
        {'n_neighbors': x,
         'metric': y}
        for x, y in product(
             params['n_neighbors'],
             params['metric']
        )
    ]
    results = list()
    for params in combinations:
        log = f'-' * 50 + '\n' + f'K-Nearest Neighbors Classifier Parameters: {params}\n' + f'-' * 50 + '\n'
        with open(os.path.join(output, 'logs.txt'), 'a') as file:
            file.write(log + '\n')
        print(log)
        averages = {}
        route = os.path.join(input, 'cv-splits', case)
        for files in collect(route):
            log = f'classifier execution on:\n- train file: {os.path.basename(files[0])}\n- test file: {os.path.basename(files[1])}'
            with open(os.path.join(output, 'logs.txt'), 'a') as file:
                file.write(log + '\n')
            print(log)
            embeddings = os.path.join(dir, loc)
            data_train = add(
                by=embeddings,
                to=files[0]
            )
            data_test = add(
                by=embeddings,
                to=files[1]
            )
            y_train = data_train['label']
            y_test = np.array(data_test['label'].tolist())
            # skip non-embedding columns
            column = [
                column for column in data_train.columns
                if column not in ['label', 'title', 'abstract']
            ][0]
            if not isinstance(data_train[column].values[0], np.ndarray):
                # debug
                print(f'WARNING: {column} not of type np.ndarray')
                continue
            x_train = np.array(data_train[column].tolist())
            x_test = np.array(data_test[column].tolist())
            try:
                knn = KNeighborsClassifier(
                    weights="distance",
                    **params
                )
                pipeline = Pipeline([
                    ('scaler', StandardScaler()),
                    ('classifier', knn)
                ])
                # train
                pipeline.fit(x_train, y_train)
                # test
                y_pred = pipeline.predict(x_test)
                y_prob = pipeline.predict_proba(x_test)
                metrics = compute(
                    y_true=y_test,
                    y_pred=y_pred,
                    y_prob=y_prob[:, 1]
                )
                log = f"F2-PPS: {metrics['F2-PPS']}"
                with open(os.path.join(output, 'logs.txt'), 'a') as file:
                    file.write(log + '\n')
                print(log)
                log = f"F1-PPS: {metrics['F1-PPS']}"
                with open(os.path.join(output, 'logs.txt'), 'a') as file:
                    file.write(log + '\n')
                print(log)
                log = f"TPR: {metrics['TPR']}"
                with open(os.path.join(output, 'logs.txt'), 'a') as file:
                    file.write(log + '\n')
                print(log)
                log = f"PPV: {metrics['PPV']}"
                with open(os.path.join(output, 'logs.txt'), 'a') as file:
                    file.write(log + '\n')
                print(log)
            except Exception as e:
                # debug
                print(f'ERROR for {column}: {e}')
                continue
            if str(params) not in averages:
                averages[str(params)] = {
                    key: [] for key in metrics
                }
            for key, value in metrics.items():
                averages[str(params)][key].append(value)
        for param, scores in averages.items():
            mean = {
                key: np.mean(values)
                for key, values in scores.items()
            }
            results.append({
                'K-Nearest Neighbors Parameters': param,
                **mean
            })
            log = f"\nF2-PPS: {mean['F2-PPS']}"
            with open(os.path.join(output, 'logs.txt'), 'a') as file:
                file.write(log + '\n')
            print(log)
            log = f"F1-PPS: {mean['F1-PPS']}"
            with open(os.path.join(output, 'logs.txt'), 'a') as file:
                file.write(log + '\n')
            print(log)
            log = f"TPR: {mean['TPR']}"
            with open(os.path.join(output, 'logs.txt'), 'a') as file:
                file.write(log + '\n')
            print(log)
            log = f"PPV: {mean['PPV']}"
            with open(os.path.join(output, 'logs.txt'), 'a') as file:
                file.write(log + '\n')
            print(log)
    data = pd.DataFrame(results)
    data = data.sort_values(
        by=order,
        ascending=[False] * len(order)
    )
    return data

# %% [markdown]
# *Fibonacci Sequence:* **[2, 3, 5, 8, 13, 21]**
#
# Splits: **[2 + 3 + 21]** & **[5 + 8 + 13]**
#
# *Split into 2 blocks of 26 iterations for* **M** *configurations, with* **M = 15** *parameter combinations*
#
# *Computational effort per split:* **Mx26 = 15x26=390** *iterations on* **1.215** *data points each*

# %%
for seed in [2, 3, 21]:
    print('-' * 50)
    print(f'seed: {seed}\n' + '-' * 50)
    results = evaluate(
        dir = model,
        loc = link,
        case = f'k-fold-{seed}',
        input = input,
        output = output,
        params = params,
        order = order
    )
    results.to_csv(os.path.join(output, f'k-fold-{seed}-results.csv'), index=False)
# Out:
# --------------------------------------------------
# seed: 2
# --------------------------------------------------
#
# k-fold-2
#
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 3, 'metric': 'euclidean'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.8660130718954249
# F1-PPS: 0.7940074906367042
# TPR: 0.9217391304347826
# PPV: 0.6973684210526315
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.8949096880131363
# F1-PPS: 0.8164794007490637
# TPR: 0.956140350877193
# PPV: 0.7124183006535948
#
# F2-PPS: 0.8804613799542806
# F1-PPS: 0.8052434456928839
# TPR: 0.9389397406559878
# PPV: 0.7048933608531132
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 3, 'metric': 'manhattan'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.8685064935064936
# F1-PPS: 0.7896678966789668
# TPR: 0.9304347826086956
# PPV: 0.6858974358974359
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.9060402684563759
# F1-PPS: 0.8503937007874016
# TPR: 0.9473684210526315
# PPV: 0.7714285714285715
#
# F2-PPS: 0.8872733809814347
# F1-PPS: 0.8200307987331842
# TPR: 0.9389016018306635
# PPV: 0.7286630036630037
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 3, 'metric': 'minkowski'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.8660130718954249
# F1-PPS: 0.7940074906367042
# TPR: 0.9217391304347826
# PPV: 0.6973684210526315
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.8949096880131363
# F1-PPS: 0.8164794007490637
# TPR: 0.956140350877193
# PPV: 0.7124183006535948
#
# F2-PPS: 0.8804613799542806
# F1-PPS: 0.8052434456928839
# TPR: 0.9389397406559878
# PPV: 0.7048933608531132
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 5, 'metric': 'euclidean'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.8833063209076175
# F1-PPS: 0.8014705882352942
# TPR: 0.9478260869565217
# PPV: 0.6942675159235668
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.8978583196046128
# F1-PPS: 0.8226415094339623
# TPR: 0.956140350877193
# PPV: 0.7218543046357616
#
# F2-PPS: 0.8905823202561152
# F1-PPS: 0.8120560488346282
# TPR: 0.9519832189168573
# PPV: 0.7080609102796642
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 5, 'metric': 'manhattan'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.8620689655172413
# F1-PPS: 0.7954545454545454
# TPR: 0.9130434782608695
# PPV: 0.7046979865771812
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.902317880794702
# F1-PPS: 0.8320610687022901
# TPR: 0.956140350877193
# PPV: 0.7364864864864865
#
# F2-PPS: 0.8821934231559716
# F1-PPS: 0.8137578070784177
# TPR: 0.9345919145690312
# PPV: 0.7205922365318338
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 5, 'metric': 'minkowski'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.8833063209076175
# F1-PPS: 0.8014705882352942
# TPR: 0.9478260869565217
# PPV: 0.6942675159235668
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.8978583196046128
# F1-PPS: 0.8226415094339623
# TPR: 0.956140350877193
# PPV: 0.7218543046357616
#
# F2-PPS: 0.8905823202561152
# F1-PPS: 0.8120560488346282
# TPR: 0.9519832189168573
# PPV: 0.7080609102796642
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 8, 'metric': 'euclidean'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.8741830065359477
# F1-PPS: 0.8014981273408239
# TPR: 0.9304347826086956
# PPV: 0.7039473684210527
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.9008264462809917
# F1-PPS: 0.8288973384030418
# TPR: 0.956140350877193
# PPV: 0.7315436241610739
#
# F2-PPS: 0.8875047264084697
# F1-PPS: 0.8151977328719329
# TPR: 0.9432875667429443
# PPV: 0.7177454962910632
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 8, 'metric': 'manhattan'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.8813838550247117
# F1-PPS: 0.816793893129771
# TPR: 0.9304347826086956
# PPV: 0.7278911564625851
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.9105960264900662
# F1-PPS: 0.8396946564885496
# TPR: 0.9649122807017544
# PPV: 0.7432432432432432
#
# F2-PPS: 0.895989940757389
# F1-PPS: 0.8282442748091603
# TPR: 0.9476735316552249
# PPV: 0.7355671998529141
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 8, 'metric': 'minkowski'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.8741830065359477
# F1-PPS: 0.8014981273408239
# TPR: 0.9304347826086956
# PPV: 0.7039473684210527
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.9008264462809917
# F1-PPS: 0.8288973384030418
# TPR: 0.956140350877193
# PPV: 0.7315436241610739
#
# F2-PPS: 0.8875047264084697
# F1-PPS: 0.8151977328719329
# TPR: 0.9432875667429443
# PPV: 0.7177454962910632
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 13, 'metric': 'euclidean'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.8737864077669902
# F1-PPS: 0.7912087912087912
# TPR: 0.9391304347826087
# PPV: 0.6835443037974683
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.8866995073891626
# F1-PPS: 0.8089887640449438
# TPR: 0.9473684210526315
# PPV: 0.7058823529411765
#
# F2-PPS: 0.8802429575780764
# F1-PPS: 0.8000987776268675
# TPR: 0.9432494279176201
# PPV: 0.6947133283693224
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 13, 'metric': 'manhattan'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.8823529411764706
# F1-PPS: 0.8089887640449438
# TPR: 0.9391304347826087
# PPV: 0.7105263157894737
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.9008264462809917
# F1-PPS: 0.8288973384030418
# TPR: 0.956140350877193
# PPV: 0.7315436241610739
#
# F2-PPS: 0.8915896937287311
# F1-PPS: 0.8189430512239928
# TPR: 0.9476353928299008
# PPV: 0.7210349699752738
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 13, 'metric': 'minkowski'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.8737864077669902
# F1-PPS: 0.7912087912087912
# TPR: 0.9391304347826087
# PPV: 0.6835443037974683
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.8866995073891626
# F1-PPS: 0.8089887640449438
# TPR: 0.9473684210526315
# PPV: 0.7058823529411765
#
# F2-PPS: 0.8802429575780764
# F1-PPS: 0.8000987776268675
# TPR: 0.9432494279176201
# PPV: 0.6947133283693224
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 21, 'metric': 'euclidean'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.8578431372549019
# F1-PPS: 0.7865168539325843
# TPR: 0.9130434782608695
# PPV: 0.6907894736842105
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.8934426229508197
# F1-PPS: 0.8134328358208955
# TPR: 0.956140350877193
# PPV: 0.7077922077922078
#
# F2-PPS: 0.8756428801028608
# F1-PPS: 0.7999748448767399
# TPR: 0.9345919145690312
# PPV: 0.6992908407382091
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 21, 'metric': 'manhattan'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.8770491803278688
# F1-PPS: 0.8075471698113208
# TPR: 0.9304347826086956
# PPV: 0.7133333333333334
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.8872305140961857
# F1-PPS: 0.8199233716475096
# TPR: 0.9385964912280702
# PPV: 0.7278911564625851
#
# F2-PPS: 0.8821398472120272
# F1-PPS: 0.8137352707294152
# TPR: 0.9345156369183829
# PPV: 0.7206122448979593
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 21, 'metric': 'minkowski'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.8578431372549019
# F1-PPS: 0.7865168539325843
# TPR: 0.9130434782608695
# PPV: 0.6907894736842105
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.8934426229508197
# F1-PPS: 0.8134328358208955
# TPR: 0.956140350877193
# PPV: 0.7077922077922078
#
# F2-PPS: 0.8756428801028608
# F1-PPS: 0.7999748448767399
# TPR: 0.9345919145690312
# PPV: 0.6992908407382091
# --------------------------------------------------
# seed: 3
# --------------------------------------------------
#
# k-fold-3
#
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 3, 'metric': 'euclidean'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.8684863523573201
# F1-PPS: 0.8
# TPR: 0.9210526315789473
# PPV: 0.7070707070707071
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.9068627450980392
# F1-PPS: 0.8222222222222222
# TPR: 0.9736842105263158
# PPV: 0.7115384615384616
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.9012345679012346
# F1-PPS: 0.8390804597701149
# TPR: 0.948051948051948
# PPV: 0.7525773195876289
#
# F2-PPS: 0.8921945551188646
# F1-PPS: 0.8204342273307791
# TPR: 0.9475962633857371
# PPV: 0.7237288293989325
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 3, 'metric': 'manhattan'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.8787128712871287
# F1-PPS: 0.8068181818181818
# TPR: 0.9342105263157895
# PPV: 0.71
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.9090909090909091
# F1-PPS: 0.8268156424581006
# TPR: 0.9736842105263158
# PPV: 0.7184466019417476
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.9170854271356784
# F1-PPS: 0.874251497005988
# TPR: 0.948051948051948
# PPV: 0.8111111111111111
#
# F2-PPS: 0.9016297358379054
# F1-PPS: 0.8359617737607569
# TPR: 0.9519822282980178
# PPV: 0.7465192376842863
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 3, 'metric': 'minkowski'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.8684863523573201
# F1-PPS: 0.8
# TPR: 0.9210526315789473
# PPV: 0.7070707070707071
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.9068627450980392
# F1-PPS: 0.8222222222222222
# TPR: 0.9736842105263158
# PPV: 0.7115384615384616
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.9012345679012346
# F1-PPS: 0.8390804597701149
# TPR: 0.948051948051948
# PPV: 0.7525773195876289
#
# F2-PPS: 0.8921945551188646
# F1-PPS: 0.8204342273307791
# TPR: 0.9475962633857371
# PPV: 0.7237288293989325
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 5, 'metric': 'euclidean'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.8910891089108911
# F1-PPS: 0.8181818181818182
# TPR: 0.9473684210526315
# PPV: 0.72
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.9068627450980392
# F1-PPS: 0.8222222222222222
# TPR: 0.9736842105263158
# PPV: 0.7115384615384616
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.8946078431372549
# F1-PPS: 0.8248587570621468
# TPR: 0.948051948051948
# PPV: 0.73
#
# F2-PPS: 0.8975198990487284
# F1-PPS: 0.8217542658220625
# TPR: 0.9563681932102984
# PPV: 0.7205128205128205
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 5, 'metric': 'manhattan'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.8888888888888888
# F1-PPS: 0.8135593220338984
# TPR: 0.9473684210526315
# PPV: 0.7128712871287128
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.9181141439205955
# F1-PPS: 0.8457142857142858
# TPR: 0.9736842105263158
# PPV: 0.7474747474747475
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.9079601990049752
# F1-PPS: 0.8538011695906432
# TPR: 0.948051948051948
# PPV: 0.776595744680851
#
# F2-PPS: 0.9049877439381532
# F1-PPS: 0.8376915924462757
# TPR: 0.9563681932102984
# PPV: 0.7456472597614372
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 5, 'metric': 'minkowski'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.8910891089108911
# F1-PPS: 0.8181818181818182
# TPR: 0.9473684210526315
# PPV: 0.72
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.9068627450980392
# F1-PPS: 0.8222222222222222
# TPR: 0.9736842105263158
# PPV: 0.7115384615384616
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.8946078431372549
# F1-PPS: 0.8248587570621468
# TPR: 0.948051948051948
# PPV: 0.73
#
# F2-PPS: 0.8975198990487284
# F1-PPS: 0.8217542658220625
# TPR: 0.9563681932102984
# PPV: 0.7205128205128205
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 8, 'metric': 'euclidean'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.8977556109725686
# F1-PPS: 0.8323699421965318
# TPR: 0.9473684210526315
# PPV: 0.7422680412371134
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.9158415841584159
# F1-PPS: 0.8409090909090909
# TPR: 0.9736842105263158
# PPV: 0.74
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.9057071960297767
# F1-PPS: 0.8488372093023255
# TPR: 0.948051948051948
# PPV: 0.7684210526315789
#
# F2-PPS: 0.906434797053587
# F1-PPS: 0.8407054141359828
# TPR: 0.9563681932102984
# PPV: 0.7502296979562307
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 8, 'metric': 'manhattan'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.9
# F1-PPS: 0.8372093023255814
# TPR: 0.9473684210526315
# PPV: 0.75
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.9181141439205955
# F1-PPS: 0.8457142857142858
# TPR: 0.9736842105263158
# PPV: 0.7474747474747475
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.9102244389027432
# F1-PPS: 0.8588235294117647
# TPR: 0.948051948051948
# PPV: 0.7849462365591398
#
# F2-PPS: 0.9094461942744463
# F1-PPS: 0.847249039150544
# TPR: 0.9563681932102984
# PPV: 0.7608069946779624
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 8, 'metric': 'minkowski'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.8977556109725686
# F1-PPS: 0.8323699421965318
# TPR: 0.9473684210526315
# PPV: 0.7422680412371134
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.9158415841584159
# F1-PPS: 0.8409090909090909
# TPR: 0.9736842105263158
# PPV: 0.74
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.9057071960297767
# F1-PPS: 0.8488372093023255
# TPR: 0.948051948051948
# PPV: 0.7684210526315789
#
# F2-PPS: 0.906434797053587
# F1-PPS: 0.8407054141359828
# TPR: 0.9563681932102984
# PPV: 0.7502296979562307
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 13, 'metric': 'euclidean'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.8977556109725686
# F1-PPS: 0.8323699421965318
# TPR: 0.9473684210526315
# PPV: 0.7422680412371134
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.9158415841584159
# F1-PPS: 0.8409090909090909
# TPR: 0.9736842105263158
# PPV: 0.74
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.8787128712871287
# F1-PPS: 0.8208092485549133
# TPR: 0.922077922077922
# PPV: 0.7395833333333334
#
# F2-PPS: 0.8974366888060378
# F1-PPS: 0.831362760553512
# TPR: 0.9477101845522897
# PPV: 0.7406171248568155
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 13, 'metric': 'manhattan'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.9
# F1-PPS: 0.8372093023255814
# TPR: 0.9473684210526315
# PPV: 0.75
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.9203980099502488
# F1-PPS: 0.8505747126436781
# TPR: 0.9736842105263158
# PPV: 0.7551020408163265
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.8955223880597015
# F1-PPS: 0.8421052631578947
# TPR: 0.935064935064935
# PPV: 0.7659574468085106
#
# F2-PPS: 0.9053067993366501
# F1-PPS: 0.8432964260423846
# TPR: 0.9520391888812941
# PPV: 0.757019829208279
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 13, 'metric': 'minkowski'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.8977556109725686
# F1-PPS: 0.8323699421965318
# TPR: 0.9473684210526315
# PPV: 0.7422680412371134
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.9158415841584159
# F1-PPS: 0.8409090909090909
# TPR: 0.9736842105263158
# PPV: 0.74
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.8787128712871287
# F1-PPS: 0.8208092485549133
# TPR: 0.922077922077922
# PPV: 0.7395833333333334
#
# F2-PPS: 0.8974366888060378
# F1-PPS: 0.831362760553512
# TPR: 0.9477101845522897
# PPV: 0.7406171248568155
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 21, 'metric': 'euclidean'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.8722358722358723
# F1-PPS: 0.7932960893854749
# TPR: 0.9342105263157895
# PPV: 0.6893203883495146
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.9090909090909091
# F1-PPS: 0.8268156424581006
# TPR: 0.9736842105263158
# PPV: 0.7184466019417476
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.8902439024390244
# F1-PPS: 0.8156424581005587
# TPR: 0.948051948051948
# PPV: 0.7156862745098039
#
# F2-PPS: 0.8905235612552685
# F1-PPS: 0.8119180633147115
# TPR: 0.9519822282980178
# PPV: 0.7078177549336887
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 21, 'metric': 'manhattan'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.8830845771144279
# F1-PPS: 0.8160919540229885
# TPR: 0.9342105263157895
# PPV: 0.7244897959183674
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.9226932668329177
# F1-PPS: 0.8554913294797688
# TPR: 0.9736842105263158
# PPV: 0.7628865979381443
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.8946078431372549
# F1-PPS: 0.8248587570621468
# TPR: 0.948051948051948
# PPV: 0.73
#
# F2-PPS: 0.9001285623615335
# F1-PPS: 0.8321473468549682
# TPR: 0.9519822282980178
# PPV: 0.7391254646188372
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 21, 'metric': 'minkowski'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.8722358722358723
# F1-PPS: 0.7932960893854749
# TPR: 0.9342105263157895
# PPV: 0.6893203883495146
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.9090909090909091
# F1-PPS: 0.8268156424581006
# TPR: 0.9736842105263158
# PPV: 0.7184466019417476
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.8902439024390244
# F1-PPS: 0.8156424581005587
# TPR: 0.948051948051948
# PPV: 0.7156862745098039
#
# F2-PPS: 0.8905235612552685
# F1-PPS: 0.8119180633147115
# TPR: 0.9519822282980178
# PPV: 0.7078177549336887
# --------------------------------------------------
# seed: 21
# --------------------------------------------------
#
# k-fold-21
#
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 3, 'metric': 'euclidean'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.7894736842105263
# F1-PPS: 0.75
# TPR: 0.8181818181818182
# PPV: 0.6923076923076923
# classifier execution on:
# - train file: fold-10-train.csv
# - test file: fold-10-test.csv
# F2-PPS: 0.9482758620689655
# F1-PPS: 0.88
# TPR: 1.0
# PPV: 0.7857142857142857
# classifier execution on:
# - train file: fold-11-train.csv
# - test file: fold-11-test.csv
# F2-PPS: 0.8771929824561403
# F1-PPS: 0.8333333333333334
# TPR: 0.9090909090909091
# PPV: 0.7692307692307693
# classifier execution on:
# - train file: fold-12-train.csv
# - test file: fold-12-test.csv
# F2-PPS: 0.8870967741935484
# F1-PPS: 0.7586206896551724
# TPR: 1.0
# PPV: 0.6111111111111112
# classifier execution on:
# - train file: fold-13-train.csv
# - test file: fold-13-test.csv
# F2-PPS: 0.9016393442622951
# F1-PPS: 0.7857142857142857
# TPR: 1.0
# PPV: 0.6470588235294118
# classifier execution on:
# - train file: fold-14-train.csv
# - test file: fold-14-test.csv
# F2-PPS: 0.9166666666666666
# F1-PPS: 0.8148148148148148
# TPR: 1.0
# PPV: 0.6875
# classifier execution on:
# - train file: fold-15-train.csv
# - test file: fold-15-test.csv
# F2-PPS: 0.8035714285714286
# F1-PPS: 0.782608695652174
# TPR: 0.8181818181818182
# PPV: 0.75
# classifier execution on:
# - train file: fold-16-train.csv
# - test file: fold-16-test.csv
# F2-PPS: 0.9482758620689655
# F1-PPS: 0.88
# TPR: 1.0
# PPV: 0.7857142857142857
# classifier execution on:
# - train file: fold-17-train.csv
# - test file: fold-17-test.csv
# F2-PPS: 0.9482758620689655
# F1-PPS: 0.88
# TPR: 1.0
# PPV: 0.7857142857142857
# classifier execution on:
# - train file: fold-18-train.csv
# - test file: fold-18-test.csv
# F2-PPS: 0.8771929824561403
# F1-PPS: 0.8333333333333334
# TPR: 0.9090909090909091
# PPV: 0.7692307692307693
# classifier execution on:
# - train file: fold-19-train.csv
# - test file: fold-19-test.csv
# F2-PPS: 0.9259259259259259
# F1-PPS: 0.8333333333333334
# TPR: 1.0
# PPV: 0.7142857142857143
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.9090909090909091
# F1-PPS: 0.9090909090909091
# TPR: 0.9090909090909091
# PPV: 0.9090909090909091
# classifier execution on:
# - train file: fold-20-train.csv
# - test file: fold-20-test.csv
# F2-PPS: 0.7272727272727273
# F1-PPS: 0.64
# TPR: 0.8
# PPV: 0.5333333333333333
# classifier execution on:
# - train file: fold-21-train.csv
# - test file: fold-21-test.csv
# F2-PPS: 0.9322033898305084
# F1-PPS: 0.8461538461538461
# TPR: 1.0
# PPV: 0.7333333333333333
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.8333333333333334
# F1-PPS: 0.8571428571428571
# TPR: 0.8181818181818182
# PPV: 0.9
# classifier execution on:
# - train file: fold-4-train.csv
# - test file: fold-4-test.csv
# F2-PPS: 0.7758620689655172
# F1-PPS: 0.72
# TPR: 0.8181818181818182
# PPV: 0.6428571428571429
# classifier execution on:
# - train file: fold-5-train.csv
# - test file: fold-5-test.csv
# F2-PPS: 0.9649122807017544
# F1-PPS: 0.9166666666666666
# TPR: 1.0
# PPV: 0.8461538461538461
# classifier execution on:
# - train file: fold-6-train.csv
# - test file: fold-6-test.csv
# F2-PPS: 0.9322033898305084
# F1-PPS: 0.8461538461538461
# TPR: 1.0
# PPV: 0.7333333333333333
# classifier execution on:
# - train file: fold-7-train.csv
# - test file: fold-7-test.csv
# F2-PPS: 0.8870967741935484
# F1-PPS: 0.7586206896551724
# TPR: 1.0
# PPV: 0.6111111111111112
# classifier execution on:
# - train file: fold-8-train.csv
# - test file: fold-8-test.csv
# F2-PPS: 0.8620689655172413
# F1-PPS: 0.8
# TPR: 0.9090909090909091
# PPV: 0.7142857142857143
# classifier execution on:
# - train file: fold-9-train.csv
# - test file: fold-9-test.csv
# F2-PPS: 0.9482758620689655
# F1-PPS: 0.88
# TPR: 1.0
# PPV: 0.7857142857142857
#
# F2-PPS: 0.885519384559742
# F1-PPS: 0.8193136809857021
# TPR: 0.9385281385281387
# PPV: 0.7336705117167301
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 3, 'metric': 'manhattan'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.8035714285714286
# F1-PPS: 0.782608695652174
# TPR: 0.8181818181818182
# PPV: 0.75
# classifier execution on:
# - train file: fold-10-train.csv
# - test file: fold-10-test.csv
# F2-PPS: 0.9016393442622951
# F1-PPS: 0.7857142857142857
# TPR: 1.0
# PPV: 0.6470588235294118
# classifier execution on:
# - train file: fold-11-train.csv
# - test file: fold-11-test.csv
# F2-PPS: 0.8928571428571429
# F1-PPS: 0.8695652173913043
# TPR: 0.9090909090909091
# PPV: 0.8333333333333334
# classifier execution on:
# - train file: fold-12-train.csv
# - test file: fold-12-test.csv
# F2-PPS: 0.9166666666666666
# F1-PPS: 0.8148148148148148
# TPR: 1.0
# PPV: 0.6875
# classifier execution on:
# - train file: fold-13-train.csv
# - test file: fold-13-test.csv
# F2-PPS: 0.9166666666666666
# F1-PPS: 0.8148148148148148
# TPR: 1.0
# PPV: 0.6875
# classifier execution on:
# - train file: fold-14-train.csv
# - test file: fold-14-test.csv
# F2-PPS: 0.8620689655172413
# F1-PPS: 0.8
# TPR: 0.9090909090909091
# PPV: 0.7142857142857143
# classifier execution on:
# - train file: fold-15-train.csv
# - test file: fold-15-test.csv
# F2-PPS: 0.7894736842105263
# F1-PPS: 0.75
# TPR: 0.8181818181818182
# PPV: 0.6923076923076923
# classifier execution on:
# - train file: fold-16-train.csv
# - test file: fold-16-test.csv
# F2-PPS: 0.9649122807017544
# F1-PPS: 0.9166666666666666
# TPR: 1.0
# PPV: 0.8461538461538461
# classifier execution on:
# - train file: fold-17-train.csv
# - test file: fold-17-test.csv
# F2-PPS: 0.9482758620689655
# F1-PPS: 0.88
# TPR: 1.0
# PPV: 0.7857142857142857
# classifier execution on:
# - train file: fold-18-train.csv
# - test file: fold-18-test.csv
# F2-PPS: 0.8333333333333334
# F1-PPS: 0.8571428571428571
# TPR: 0.8181818181818182
# PPV: 0.9
# classifier execution on:
# - train file: fold-19-train.csv
# - test file: fold-19-test.csv
# F2-PPS: 0.9615384615384616
# F1-PPS: 0.9090909090909091
# TPR: 1.0
# PPV: 0.8333333333333334
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.9259259259259259
# F1-PPS: 0.9523809523809523
# TPR: 0.9090909090909091
# PPV: 1.0
# classifier execution on:
# - train file: fold-20-train.csv
# - test file: fold-20-test.csv
# F2-PPS: 0.7407407407407407
# F1-PPS: 0.6666666666666666
# TPR: 0.8
# PPV: 0.5714285714285714
# classifier execution on:
# - train file: fold-21-train.csv
# - test file: fold-21-test.csv
# F2-PPS: 0.9322033898305084
# F1-PPS: 0.8461538461538461
# TPR: 1.0
# PPV: 0.7333333333333333
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.8333333333333334
# F1-PPS: 0.8571428571428571
# TPR: 0.8181818181818182
# PPV: 0.9
# classifier execution on:
# - train file: fold-4-train.csv
# - test file: fold-4-test.csv
# F2-PPS: 0.7758620689655172
# F1-PPS: 0.72
# TPR: 0.8181818181818182
# PPV: 0.6428571428571429
# classifier execution on:
# - train file: fold-5-train.csv
# - test file: fold-5-test.csv
# F2-PPS: 0.9322033898305084
# F1-PPS: 0.8461538461538461
# TPR: 1.0
# PPV: 0.7333333333333333
# classifier execution on:
# - train file: fold-6-train.csv
# - test file: fold-6-test.csv
# F2-PPS: 0.9322033898305084
# F1-PPS: 0.8461538461538461
# TPR: 1.0
# PPV: 0.7333333333333333
# classifier execution on:
# - train file: fold-7-train.csv
# - test file: fold-7-test.csv
# F2-PPS: 0.9322033898305084
# F1-PPS: 0.8461538461538461
# TPR: 1.0
# PPV: 0.7333333333333333
# classifier execution on:
# - train file: fold-8-train.csv
# - test file: fold-8-test.csv
# F2-PPS: 0.8771929824561403
# F1-PPS: 0.8333333333333334
# TPR: 0.9090909090909091
# PPV: 0.7692307692307693
# classifier execution on:
# - train file: fold-9-train.csv
# - test file: fold-9-test.csv
# F2-PPS: 0.9482758620689655
# F1-PPS: 0.88
# TPR: 1.0
# PPV: 0.7857142857142857
#
# F2-PPS: 0.8867213480574827
# F1-PPS: 0.8321217835917629
# TPR: 0.9298701298701298
# PPV: 0.7609405300581771
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 3, 'metric': 'minkowski'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.7894736842105263
# F1-PPS: 0.75
# TPR: 0.8181818181818182
# PPV: 0.6923076923076923
# classifier execution on:
# - train file: fold-10-train.csv
# - test file: fold-10-test.csv
# F2-PPS: 0.9482758620689655
# F1-PPS: 0.88
# TPR: 1.0
# PPV: 0.7857142857142857
# classifier execution on:
# - train file: fold-11-train.csv
# - test file: fold-11-test.csv
# F2-PPS: 0.8771929824561403
# F1-PPS: 0.8333333333333334
# TPR: 0.9090909090909091
# PPV: 0.7692307692307693
# classifier execution on:
# - train file: fold-12-train.csv
# - test file: fold-12-test.csv
# F2-PPS: 0.8870967741935484
# F1-PPS: 0.7586206896551724
# TPR: 1.0
# PPV: 0.6111111111111112
# classifier execution on:
# - train file: fold-13-train.csv
# - test file: fold-13-test.csv
# F2-PPS: 0.9016393442622951
# F1-PPS: 0.7857142857142857
# TPR: 1.0
# PPV: 0.6470588235294118
# classifier execution on:
# - train file: fold-14-train.csv
# - test file: fold-14-test.csv
# F2-PPS: 0.9166666666666666
# F1-PPS: 0.8148148148148148
# TPR: 1.0
# PPV: 0.6875
# classifier execution on:
# - train file: fold-15-train.csv
# - test file: fold-15-test.csv
# F2-PPS: 0.8035714285714286
# F1-PPS: 0.782608695652174
# TPR: 0.8181818181818182
# PPV: 0.75
# classifier execution on:
# - train file: fold-16-train.csv
# - test file: fold-16-test.csv
# F2-PPS: 0.9482758620689655
# F1-PPS: 0.88
# TPR: 1.0
# PPV: 0.7857142857142857
# classifier execution on:
# - train file: fold-17-train.csv
# - test file: fold-17-test.csv
# F2-PPS: 0.9482758620689655
# F1-PPS: 0.88
# TPR: 1.0
# PPV: 0.7857142857142857
# classifier execution on:
# - train file: fold-18-train.csv
# - test file: fold-18-test.csv
# F2-PPS: 0.8771929824561403
# F1-PPS: 0.8333333333333334
# TPR: 0.9090909090909091
# PPV: 0.7692307692307693
# classifier execution on:
# - train file: fold-19-train.csv
# - test file: fold-19-test.csv
# F2-PPS: 0.9259259259259259
# F1-PPS: 0.8333333333333334
# TPR: 1.0
# PPV: 0.7142857142857143
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.9090909090909091
# F1-PPS: 0.9090909090909091
# TPR: 0.9090909090909091
# PPV: 0.9090909090909091
# classifier execution on:
# - train file: fold-20-train.csv
# - test file: fold-20-test.csv
# F2-PPS: 0.7272727272727273
# F1-PPS: 0.64
# TPR: 0.8
# PPV: 0.5333333333333333
# classifier execution on:
# - train file: fold-21-train.csv
# - test file: fold-21-test.csv
# F2-PPS: 0.9322033898305084
# F1-PPS: 0.8461538461538461
# TPR: 1.0
# PPV: 0.7333333333333333
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.8333333333333334
# F1-PPS: 0.8571428571428571
# TPR: 0.8181818181818182
# PPV: 0.9
# classifier execution on:
# - train file: fold-4-train.csv
# - test file: fold-4-test.csv
# F2-PPS: 0.7758620689655172
# F1-PPS: 0.72
# TPR: 0.8181818181818182
# PPV: 0.6428571428571429
# classifier execution on:
# - train file: fold-5-train.csv
# - test file: fold-5-test.csv
# F2-PPS: 0.9649122807017544
# F1-PPS: 0.9166666666666666
# TPR: 1.0
# PPV: 0.8461538461538461
# classifier execution on:
# - train file: fold-6-train.csv
# - test file: fold-6-test.csv
# F2-PPS: 0.9322033898305084
# F1-PPS: 0.8461538461538461
# TPR: 1.0
# PPV: 0.7333333333333333
# classifier execution on:
# - train file: fold-7-train.csv
# - test file: fold-7-test.csv
# F2-PPS: 0.8870967741935484
# F1-PPS: 0.7586206896551724
# TPR: 1.0
# PPV: 0.6111111111111112
# classifier execution on:
# - train file: fold-8-train.csv
# - test file: fold-8-test.csv
# F2-PPS: 0.8620689655172413
# F1-PPS: 0.8
# TPR: 0.9090909090909091
# PPV: 0.7142857142857143
# classifier execution on:
# - train file: fold-9-train.csv
# - test file: fold-9-test.csv
# F2-PPS: 0.9482758620689655
# F1-PPS: 0.88
# TPR: 1.0
# PPV: 0.7857142857142857
#
# F2-PPS: 0.885519384559742
# F1-PPS: 0.8193136809857021
# TPR: 0.9385281385281387
# PPV: 0.7336705117167301
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 5, 'metric': 'euclidean'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.8928571428571429
# F1-PPS: 0.8695652173913043
# TPR: 0.9090909090909091
# PPV: 0.8333333333333334
# classifier execution on:
# - train file: fold-10-train.csv
# - test file: fold-10-test.csv
# F2-PPS: 0.9482758620689655
# F1-PPS: 0.88
# TPR: 1.0
# PPV: 0.7857142857142857
# classifier execution on:
# - train file: fold-11-train.csv
# - test file: fold-11-test.csv
# F2-PPS: 0.8771929824561403
# F1-PPS: 0.8333333333333334
# TPR: 0.9090909090909091
# PPV: 0.7692307692307693
# classifier execution on:
# - train file: fold-12-train.csv
# - test file: fold-12-test.csv
# F2-PPS: 0.9016393442622951
# F1-PPS: 0.7857142857142857
# TPR: 1.0
# PPV: 0.6470588235294118
# classifier execution on:
# - train file: fold-13-train.csv
# - test file: fold-13-test.csv
# F2-PPS: 0.9166666666666666
# F1-PPS: 0.8148148148148148
# TPR: 1.0
# PPV: 0.6875
# classifier execution on:
# - train file: fold-14-train.csv
# - test file: fold-14-test.csv
# F2-PPS: 0.9322033898305084
# F1-PPS: 0.8461538461538461
# TPR: 1.0
# PPV: 0.7333333333333333
# classifier execution on:
# - train file: fold-15-train.csv
# - test file: fold-15-test.csv
# F2-PPS: 0.7894736842105263
# F1-PPS: 0.75
# TPR: 0.8181818181818182
# PPV: 0.6923076923076923
# classifier execution on:
# - train file: fold-16-train.csv
# - test file: fold-16-test.csv
# F2-PPS: 0.9649122807017544
# F1-PPS: 0.9166666666666666
# TPR: 1.0
# PPV: 0.8461538461538461
# classifier execution on:
# - train file: fold-17-train.csv
# - test file: fold-17-test.csv
# F2-PPS: 0.9482758620689655
# F1-PPS: 0.88
# TPR: 1.0
# PPV: 0.7857142857142857
# classifier execution on:
# - train file: fold-18-train.csv
# - test file: fold-18-test.csv
# F2-PPS: 0.9090909090909091
# F1-PPS: 0.9090909090909091
# TPR: 0.9090909090909091
# PPV: 0.9090909090909091
# classifier execution on:
# - train file: fold-19-train.csv
# - test file: fold-19-test.csv
# F2-PPS: 0.9259259259259259
# F1-PPS: 0.8333333333333334
# TPR: 1.0
# PPV: 0.7142857142857143
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.8928571428571429
# F1-PPS: 0.8695652173913043
# TPR: 0.9090909090909091
# PPV: 0.8333333333333334
# classifier execution on:
# - train file: fold-20-train.csv
# - test file: fold-20-test.csv
# F2-PPS: 0.8181818181818182
# F1-PPS: 0.72
# TPR: 0.9
# PPV: 0.6
# classifier execution on:
# - train file: fold-21-train.csv
# - test file: fold-21-test.csv
# F2-PPS: 0.9482758620689655
# F1-PPS: 0.88
# TPR: 1.0
# PPV: 0.7857142857142857
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.9090909090909091
# F1-PPS: 0.9090909090909091
# TPR: 0.9090909090909091
# PPV: 0.9090909090909091
# classifier execution on:
# - train file: fold-4-train.csv
# - test file: fold-4-test.csv
# F2-PPS: 0.8620689655172413
# F1-PPS: 0.8
# TPR: 0.9090909090909091
# PPV: 0.7142857142857143
# classifier execution on:
# - train file: fold-5-train.csv
# - test file: fold-5-test.csv
# F2-PPS: 0.9649122807017544
# F1-PPS: 0.9166666666666666
# TPR: 1.0
# PPV: 0.8461538461538461
# classifier execution on:
# - train file: fold-6-train.csv
# - test file: fold-6-test.csv
# F2-PPS: 0.9166666666666666
# F1-PPS: 0.8148148148148148
# TPR: 1.0
# PPV: 0.6875
# classifier execution on:
# - train file: fold-7-train.csv
# - test file: fold-7-test.csv
# F2-PPS: 0.9166666666666666
# F1-PPS: 0.8148148148148148
# TPR: 1.0
# PPV: 0.6875
# classifier execution on:
# - train file: fold-8-train.csv
# - test file: fold-8-test.csv
# F2-PPS: 0.8771929824561403
# F1-PPS: 0.8333333333333334
# TPR: 0.9090909090909091
# PPV: 0.7692307692307693
# classifier execution on:
# - train file: fold-9-train.csv
# - test file: fold-9-test.csv
# F2-PPS: 0.9166666666666666
# F1-PPS: 0.8148148148148148
# TPR: 1.0
# PPV: 0.6875
#
# F2-PPS: 0.9061473338577988
# F1-PPS: 0.8424653798773879
# TPR: 0.9562770562770563
# PPV: 0.7582872309763067
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 5, 'metric': 'manhattan'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.8928571428571429
# F1-PPS: 0.8695652173913043
# TPR: 0.9090909090909091
# PPV: 0.8333333333333334
# classifier execution on:
# - train file: fold-10-train.csv
# - test file: fold-10-test.csv
# F2-PPS: 0.9482758620689655
# F1-PPS: 0.88
# TPR: 1.0
# PPV: 0.7857142857142857
# classifier execution on:
# - train file: fold-11-train.csv
# - test file: fold-11-test.csv
# F2-PPS: 0.8928571428571429
# F1-PPS: 0.8695652173913043
# TPR: 0.9090909090909091
# PPV: 0.8333333333333334
# classifier execution on:
# - train file: fold-12-train.csv
# - test file: fold-12-test.csv
# F2-PPS: 0.9322033898305084
# F1-PPS: 0.8461538461538461
# TPR: 1.0
# PPV: 0.7333333333333333
# classifier execution on:
# - train file: fold-13-train.csv
# - test file: fold-13-test.csv
# F2-PPS: 0.9166666666666666
# F1-PPS: 0.8148148148148148
# TPR: 1.0
# PPV: 0.6875
# classifier execution on:
# - train file: fold-14-train.csv
# - test file: fold-14-test.csv
# F2-PPS: 0.9322033898305084
# F1-PPS: 0.8461538461538461
# TPR: 1.0
# PPV: 0.7333333333333333
# classifier execution on:
# - train file: fold-15-train.csv
# - test file: fold-15-test.csv
# F2-PPS: 0.7894736842105263
# F1-PPS: 0.75
# TPR: 0.8181818181818182
# PPV: 0.6923076923076923
# classifier execution on:
# - train file: fold-16-train.csv
# - test file: fold-16-test.csv
# F2-PPS: 0.9482758620689655
# F1-PPS: 0.88
# TPR: 1.0
# PPV: 0.7857142857142857
# classifier execution on:
# - train file: fold-17-train.csv
# - test file: fold-17-test.csv
# F2-PPS: 0.9649122807017544
# F1-PPS: 0.9166666666666666
# TPR: 1.0
# PPV: 0.8461538461538461
# classifier execution on:
# - train file: fold-18-train.csv
# - test file: fold-18-test.csv
# F2-PPS: 0.9090909090909091
# F1-PPS: 0.9090909090909091
# TPR: 0.9090909090909091
# PPV: 0.9090909090909091
# classifier execution on:
# - train file: fold-19-train.csv
# - test file: fold-19-test.csv
# F2-PPS: 0.8490566037735849
# F1-PPS: 0.782608695652174
# TPR: 0.9
# PPV: 0.6923076923076923
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.9090909090909091
# F1-PPS: 0.9090909090909091
# TPR: 0.9090909090909091
# PPV: 0.9090909090909091
# classifier execution on:
# - train file: fold-20-train.csv
# - test file: fold-20-test.csv
# F2-PPS: 0.8490566037735849
# F1-PPS: 0.782608695652174
# TPR: 0.9
# PPV: 0.6923076923076923
# classifier execution on:
# - train file: fold-21-train.csv
# - test file: fold-21-test.csv
# F2-PPS: 0.9649122807017544
# F1-PPS: 0.9166666666666666
# TPR: 1.0
# PPV: 0.8461538461538461
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.9090909090909091
# F1-PPS: 0.9090909090909091
# TPR: 0.9090909090909091
# PPV: 0.9090909090909091
# classifier execution on:
# - train file: fold-4-train.csv
# - test file: fold-4-test.csv
# F2-PPS: 0.8333333333333334
# F1-PPS: 0.7407407407407407
# TPR: 0.9090909090909091
# PPV: 0.625
# classifier execution on:
# - train file: fold-5-train.csv
# - test file: fold-5-test.csv
# F2-PPS: 0.9649122807017544
# F1-PPS: 0.9166666666666666
# TPR: 1.0
# PPV: 0.8461538461538461
# classifier execution on:
# - train file: fold-6-train.csv
# - test file: fold-6-test.csv
# F2-PPS: 0.9649122807017544
# F1-PPS: 0.9166666666666666
# TPR: 1.0
# PPV: 0.8461538461538461
# classifier execution on:
# - train file: fold-7-train.csv
# - test file: fold-7-test.csv
# F2-PPS: 0.9166666666666666
# F1-PPS: 0.8148148148148148
# TPR: 1.0
# PPV: 0.6875
# classifier execution on:
# - train file: fold-8-train.csv
# - test file: fold-8-test.csv
# F2-PPS: 0.8771929824561403
# F1-PPS: 0.8333333333333334
# TPR: 0.9090909090909091
# PPV: 0.7692307692307693
# classifier execution on:
# - train file: fold-9-train.csv
# - test file: fold-9-test.csv
# F2-PPS: 0.9166666666666666
# F1-PPS: 0.8148148148148148
# TPR: 1.0
# PPV: 0.6875
#
# F2-PPS: 0.9086527546257215
# F1-PPS: 0.8532911157548836
# TPR: 0.9515151515151516
# PPV: 0.7785858982287556
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 5, 'metric': 'minkowski'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.8928571428571429
# F1-PPS: 0.8695652173913043
# TPR: 0.9090909090909091
# PPV: 0.8333333333333334
# classifier execution on:
# - train file: fold-10-train.csv
# - test file: fold-10-test.csv
# F2-PPS: 0.9482758620689655
# F1-PPS: 0.88
# TPR: 1.0
# PPV: 0.7857142857142857
# classifier execution on:
# - train file: fold-11-train.csv
# - test file: fold-11-test.csv
# F2-PPS: 0.8771929824561403
# F1-PPS: 0.8333333333333334
# TPR: 0.9090909090909091
# PPV: 0.7692307692307693
# classifier execution on:
# - train file: fold-12-train.csv
# - test file: fold-12-test.csv
# F2-PPS: 0.9016393442622951
# F1-PPS: 0.7857142857142857
# TPR: 1.0
# PPV: 0.6470588235294118
# classifier execution on:
# - train file: fold-13-train.csv
# - test file: fold-13-test.csv
# F2-PPS: 0.9166666666666666
# F1-PPS: 0.8148148148148148
# TPR: 1.0
# PPV: 0.6875
# classifier execution on:
# - train file: fold-14-train.csv
# - test file: fold-14-test.csv
# F2-PPS: 0.9322033898305084
# F1-PPS: 0.8461538461538461
# TPR: 1.0
# PPV: 0.7333333333333333
# classifier execution on:
# - train file: fold-15-train.csv
# - test file: fold-15-test.csv
# F2-PPS: 0.7894736842105263
# F1-PPS: 0.75
# TPR: 0.8181818181818182
# PPV: 0.6923076923076923
# classifier execution on:
# - train file: fold-16-train.csv
# - test file: fold-16-test.csv
# F2-PPS: 0.9649122807017544
# F1-PPS: 0.9166666666666666
# TPR: 1.0
# PPV: 0.8461538461538461
# classifier execution on:
# - train file: fold-17-train.csv
# - test file: fold-17-test.csv
# F2-PPS: 0.9482758620689655
# F1-PPS: 0.88
# TPR: 1.0
# PPV: 0.7857142857142857
# classifier execution on:
# - train file: fold-18-train.csv
# - test file: fold-18-test.csv
# F2-PPS: 0.9090909090909091
# F1-PPS: 0.9090909090909091
# TPR: 0.9090909090909091
# PPV: 0.9090909090909091
# classifier execution on:
# - train file: fold-19-train.csv
# - test file: fold-19-test.csv
# F2-PPS: 0.9259259259259259
# F1-PPS: 0.8333333333333334
# TPR: 1.0
# PPV: 0.7142857142857143
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.8928571428571429
# F1-PPS: 0.8695652173913043
# TPR: 0.9090909090909091
# PPV: 0.8333333333333334
# classifier execution on:
# - train file: fold-20-train.csv
# - test file: fold-20-test.csv
# F2-PPS: 0.8181818181818182
# F1-PPS: 0.72
# TPR: 0.9
# PPV: 0.6
# classifier execution on:
# - train file: fold-21-train.csv
# - test file: fold-21-test.csv
# F2-PPS: 0.9482758620689655
# F1-PPS: 0.88
# TPR: 1.0
# PPV: 0.7857142857142857
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.9090909090909091
# F1-PPS: 0.9090909090909091
# TPR: 0.9090909090909091
# PPV: 0.9090909090909091
# classifier execution on:
# - train file: fold-4-train.csv
# - test file: fold-4-test.csv
# F2-PPS: 0.8620689655172413
# F1-PPS: 0.8
# TPR: 0.9090909090909091
# PPV: 0.7142857142857143
# classifier execution on:
# - train file: fold-5-train.csv
# - test file: fold-5-test.csv
# F2-PPS: 0.9649122807017544
# F1-PPS: 0.9166666666666666
# TPR: 1.0
# PPV: 0.8461538461538461
# classifier execution on:
# - train file: fold-6-train.csv
# - test file: fold-6-test.csv
# F2-PPS: 0.9166666666666666
# F1-PPS: 0.8148148148148148
# TPR: 1.0
# PPV: 0.6875
# classifier execution on:
# - train file: fold-7-train.csv
# - test file: fold-7-test.csv
# F2-PPS: 0.9166666666666666
# F1-PPS: 0.8148148148148148
# TPR: 1.0
# PPV: 0.6875
# classifier execution on:
# - train file: fold-8-train.csv
# - test file: fold-8-test.csv
# F2-PPS: 0.8771929824561403
# F1-PPS: 0.8333333333333334
# TPR: 0.9090909090909091
# PPV: 0.7692307692307693
# classifier execution on:
# - train file: fold-9-train.csv
# - test file: fold-9-test.csv
# F2-PPS: 0.9166666666666666
# F1-PPS: 0.8148148148148148
# TPR: 1.0
# PPV: 0.6875
#
# F2-PPS: 0.9061473338577988
# F1-PPS: 0.8424653798773879
# TPR: 0.9562770562770563
# PPV: 0.7582872309763067
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 8, 'metric': 'euclidean'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.8928571428571429
# F1-PPS: 0.8695652173913043
# TPR: 0.9090909090909091
# PPV: 0.8333333333333334
# classifier execution on:
# - train file: fold-10-train.csv
# - test file: fold-10-test.csv
# F2-PPS: 0.9482758620689655
# F1-PPS: 0.88
# TPR: 1.0
# PPV: 0.7857142857142857
# classifier execution on:
# - train file: fold-11-train.csv
# - test file: fold-11-test.csv
# F2-PPS: 0.8928571428571429
# F1-PPS: 0.8695652173913043
# TPR: 0.9090909090909091
# PPV: 0.8333333333333334
# classifier execution on:
# - train file: fold-12-train.csv
# - test file: fold-12-test.csv
# F2-PPS: 0.9166666666666666
# F1-PPS: 0.8148148148148148
# TPR: 1.0
# PPV: 0.6875
# classifier execution on:
# - train file: fold-13-train.csv
# - test file: fold-13-test.csv
# F2-PPS: 0.9166666666666666
# F1-PPS: 0.8148148148148148
# TPR: 1.0
# PPV: 0.6875
# classifier execution on:
# - train file: fold-14-train.csv
# - test file: fold-14-test.csv
# F2-PPS: 0.9322033898305084
# F1-PPS: 0.8461538461538461
# TPR: 1.0
# PPV: 0.7333333333333333
# classifier execution on:
# - train file: fold-15-train.csv
# - test file: fold-15-test.csv
# F2-PPS: 0.7894736842105263
# F1-PPS: 0.75
# TPR: 0.8181818181818182
# PPV: 0.6923076923076923
# classifier execution on:
# - train file: fold-16-train.csv
# - test file: fold-16-test.csv
# F2-PPS: 0.9482758620689655
# F1-PPS: 0.88
# TPR: 1.0
# PPV: 0.7857142857142857
# classifier execution on:
# - train file: fold-17-train.csv
# - test file: fold-17-test.csv
# F2-PPS: 0.9482758620689655
# F1-PPS: 0.88
# ...
# - train file: fold-9-train.csv
# - test file: fold-9-test.csv
# F2-PPS: 0.9166666666666666
# F1-PPS: 0.8148148148148148
# TPR: 1.0
# PPV: 0.6875
#
# F2-PPS: 0.9022735246540644
# F1-PPS: 0.8448547872435926
# TPR: 0.9471861471861474
# PPV: 0.768170586027729
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 13, 'metric': 'minkowski'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.8771929824561403
# F1-PPS: 0.8333333333333334
# TPR: 0.9090909090909091
# PPV: 0.7692307692307693
# classifier execution on:
# - train file: fold-10-train.csv
# - test file: fold-10-test.csv
# F2-PPS: 0.9482758620689655
# F1-PPS: 0.88
# TPR: 1.0
# PPV: 0.7857142857142857
# classifier execution on:
# - train file: fold-11-train.csv
# - test file: fold-11-test.csv
# F2-PPS: 0.8771929824561403
# F1-PPS: 0.8333333333333334
# TPR: 0.9090909090909091
# PPV: 0.7692307692307693
# classifier execution on:
# - train file: fold-12-train.csv
# - test file: fold-12-test.csv
# F2-PPS: 0.9166666666666666
# F1-PPS: 0.8148148148148148
# TPR: 1.0
# PPV: 0.6875
# classifier execution on:
# - train file: fold-13-train.csv
# - test file: fold-13-test.csv
# F2-PPS: 0.9322033898305084
# F1-PPS: 0.8461538461538461
# TPR: 1.0
# PPV: 0.7333333333333333
# classifier execution on:
# - train file: fold-14-train.csv
# - test file: fold-14-test.csv
# F2-PPS: 0.9322033898305084
# F1-PPS: 0.8461538461538461
# TPR: 1.0
# PPV: 0.7333333333333333
# classifier execution on:
# - train file: fold-15-train.csv
# - test file: fold-15-test.csv
# F2-PPS: 0.7894736842105263
# F1-PPS: 0.75
# TPR: 0.8181818181818182
# PPV: 0.6923076923076923
# classifier execution on:
# - train file: fold-16-train.csv
# - test file: fold-16-test.csv
# F2-PPS: 0.9482758620689655
# F1-PPS: 0.88
# TPR: 1.0
# PPV: 0.7857142857142857
# classifier execution on:
# - train file: fold-17-train.csv
# - test file: fold-17-test.csv
# F2-PPS: 0.9322033898305084
# F1-PPS: 0.8461538461538461
# TPR: 1.0
# PPV: 0.7333333333333333
# classifier execution on:
# - train file: fold-18-train.csv
# - test file: fold-18-test.csv
# F2-PPS: 0.8333333333333334
# F1-PPS: 0.8571428571428571
# TPR: 0.8181818181818182
# PPV: 0.9
# classifier execution on:
# - train file: fold-19-train.csv
# - test file: fold-19-test.csv
# F2-PPS: 0.9259259259259259
# F1-PPS: 0.8333333333333334
# TPR: 1.0
# PPV: 0.7142857142857143
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.9649122807017544
# F1-PPS: 0.9166666666666666
# TPR: 1.0
# PPV: 0.8461538461538461
# classifier execution on:
# - train file: fold-20-train.csv
# - test file: fold-20-test.csv
# F2-PPS: 0.8490566037735849
# F1-PPS: 0.782608695652174
# TPR: 0.9
# PPV: 0.6923076923076923
# classifier execution on:
# - train file: fold-21-train.csv
# - test file: fold-21-test.csv
# F2-PPS: 0.9482758620689655
# F1-PPS: 0.88
# TPR: 1.0
# PPV: 0.7857142857142857
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.8928571428571429
# F1-PPS: 0.8695652173913043
# TPR: 0.9090909090909091
# PPV: 0.8333333333333334
# classifier execution on:
# - train file: fold-4-train.csv
# - test file: fold-4-test.csv
# F2-PPS: 0.8620689655172413
# F1-PPS: 0.8
# TPR: 0.9090909090909091
# PPV: 0.7142857142857143
# classifier execution on:
# - train file: fold-5-train.csv
# - test file: fold-5-test.csv
# F2-PPS: 0.8928571428571429
# F1-PPS: 0.8695652173913043
# TPR: 0.9090909090909091
# PPV: 0.8333333333333334
# classifier execution on:
# - train file: fold-6-train.csv
# - test file: fold-6-test.csv
# F2-PPS: 0.9649122807017544
# F1-PPS: 0.9166666666666666
# TPR: 1.0
# PPV: 0.8461538461538461
# classifier execution on:
# - train file: fold-7-train.csv
# - test file: fold-7-test.csv
# F2-PPS: 0.8870967741935484
# F1-PPS: 0.7586206896551724
# TPR: 1.0
# PPV: 0.6111111111111112
# classifier execution on:
# - train file: fold-8-train.csv
# - test file: fold-8-test.csv
# F2-PPS: 0.9482758620689655
# F1-PPS: 0.88
# TPR: 1.0
# PPV: 0.7857142857142857
# classifier execution on:
# - train file: fold-9-train.csv
# - test file: fold-9-test.csv
# F2-PPS: 0.9322033898305084
# F1-PPS: 0.8461538461538461
# TPR: 1.0
# PPV: 0.7333333333333333
#
# F2-PPS: 0.9074030368213712
# F1-PPS: 0.8447745814283972
# TPR: 0.9562770562770563
# PPV: 0.761210680853538
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 21, 'metric': 'euclidean'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.8771929824561403
# F1-PPS: 0.8333333333333334
# TPR: 0.9090909090909091
# PPV: 0.7692307692307693
# classifier execution on:
# - train file: fold-10-train.csv
# - test file: fold-10-test.csv
# F2-PPS: 0.9322033898305084
# F1-PPS: 0.8461538461538461
# TPR: 1.0
# PPV: 0.7333333333333333
# classifier execution on:
# - train file: fold-11-train.csv
# - test file: fold-11-test.csv
# F2-PPS: 0.8928571428571429
# F1-PPS: 0.8695652173913043
# TPR: 0.9090909090909091
# PPV: 0.8333333333333334
# classifier execution on:
# - train file: fold-12-train.csv
# - test file: fold-12-test.csv
# F2-PPS: 0.8870967741935484
# F1-PPS: 0.7586206896551724
# TPR: 1.0
# PPV: 0.6111111111111112
# classifier execution on:
# - train file: fold-13-train.csv
# - test file: fold-13-test.csv
# F2-PPS: 0.9322033898305084
# F1-PPS: 0.8461538461538461
# TPR: 1.0
# PPV: 0.7333333333333333
# classifier execution on:
# - train file: fold-14-train.csv
# - test file: fold-14-test.csv
# F2-PPS: 0.9322033898305084
# F1-PPS: 0.8461538461538461
# TPR: 1.0
# PPV: 0.7333333333333333
# classifier execution on:
# - train file: fold-15-train.csv
# - test file: fold-15-test.csv
# F2-PPS: 0.7758620689655172
# F1-PPS: 0.72
# TPR: 0.8181818181818182
# PPV: 0.6428571428571429
# classifier execution on:
# - train file: fold-16-train.csv
# - test file: fold-16-test.csv
# F2-PPS: 0.9482758620689655
# F1-PPS: 0.88
# TPR: 1.0
# PPV: 0.7857142857142857
# classifier execution on:
# - train file: fold-17-train.csv
# - test file: fold-17-test.csv
# F2-PPS: 0.9322033898305084
# F1-PPS: 0.8461538461538461
# TPR: 1.0
# PPV: 0.7333333333333333
# classifier execution on:
# - train file: fold-18-train.csv
# - test file: fold-18-test.csv
# F2-PPS: 0.8181818181818182
# F1-PPS: 0.8181818181818182
# TPR: 0.8181818181818182
# PPV: 0.8181818181818182
# classifier execution on:
# - train file: fold-19-train.csv
# - test file: fold-19-test.csv
# F2-PPS: 0.9090909090909091
# F1-PPS: 0.8
# TPR: 1.0
# PPV: 0.6666666666666666
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 1.0
# F1-PPS: 1.0
# TPR: 1.0
# PPV: 1.0
# classifier execution on:
# - train file: fold-20-train.csv
# - test file: fold-20-test.csv
# F2-PPS: 0.8490566037735849
# F1-PPS: 0.782608695652174
# TPR: 0.9
# PPV: 0.6923076923076923
# classifier execution on:
# - train file: fold-21-train.csv
# - test file: fold-21-test.csv
# F2-PPS: 0.9649122807017544
# F1-PPS: 0.9166666666666666
# TPR: 1.0
# PPV: 0.8461538461538461
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.8928571428571429
# F1-PPS: 0.8695652173913043
# TPR: 0.9090909090909091
# PPV: 0.8333333333333334
# classifier execution on:
# - train file: fold-4-train.csv
# - test file: fold-4-test.csv
# F2-PPS: 0.847457627118644
# F1-PPS: 0.7692307692307693
# TPR: 0.9090909090909091
# PPV: 0.6666666666666666
# classifier execution on:
# - train file: fold-5-train.csv
# - test file: fold-5-test.csv
# F2-PPS: 0.8928571428571429
# F1-PPS: 0.8695652173913043
# TPR: 0.9090909090909091
# PPV: 0.8333333333333334
# classifier execution on:
# - train file: fold-6-train.csv
# - test file: fold-6-test.csv
# F2-PPS: 0.9649122807017544
# F1-PPS: 0.9166666666666666
# TPR: 1.0
# PPV: 0.8461538461538461
# classifier execution on:
# - train file: fold-7-train.csv
# - test file: fold-7-test.csv
# F2-PPS: 0.9016393442622951
# F1-PPS: 0.7857142857142857
# TPR: 1.0
# PPV: 0.6470588235294118
# classifier execution on:
# - train file: fold-8-train.csv
# - test file: fold-8-test.csv
# F2-PPS: 0.8771929824561403
# F1-PPS: 0.8333333333333334
# TPR: 0.9090909090909091
# PPV: 0.7692307692307693
# classifier execution on:
# - train file: fold-9-train.csv
# - test file: fold-9-test.csv
# F2-PPS: 0.9322033898305084
# F1-PPS: 0.8461538461538461
# TPR: 1.0
# PPV: 0.7333333333333333
#
# F2-PPS: 0.9028790434140497
# F1-PPS: 0.8406581495893983
# TPR: 0.951948051948052
# PPV: 0.7584761954509854
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 21, 'metric': 'manhattan'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.8771929824561403
# F1-PPS: 0.8333333333333334
# TPR: 0.9090909090909091
# PPV: 0.7692307692307693
# classifier execution on:
# - train file: fold-10-train.csv
# - test file: fold-10-test.csv
# F2-PPS: 0.9322033898305084
# F1-PPS: 0.8461538461538461
# TPR: 1.0
# PPV: 0.7333333333333333
# classifier execution on:
# - train file: fold-11-train.csv
# - test file: fold-11-test.csv
# F2-PPS: 0.8928571428571429
# F1-PPS: 0.8695652173913043
# TPR: 0.9090909090909091
# PPV: 0.8333333333333334
# classifier execution on:
# - train file: fold-12-train.csv
# - test file: fold-12-test.csv
# F2-PPS: 0.9166666666666666
# F1-PPS: 0.8148148148148148
# TPR: 1.0
# PPV: 0.6875
# classifier execution on:
# - train file: fold-13-train.csv
# - test file: fold-13-test.csv
# F2-PPS: 0.9322033898305084
# F1-PPS: 0.8461538461538461
# TPR: 1.0
# PPV: 0.7333333333333333
# classifier execution on:
# - train file: fold-14-train.csv
# - test file: fold-14-test.csv
# F2-PPS: 0.9322033898305084
# F1-PPS: 0.8461538461538461
# TPR: 1.0
# PPV: 0.7333333333333333
# classifier execution on:
# - train file: fold-15-train.csv
# - test file: fold-15-test.csv
# F2-PPS: 0.7758620689655172
# F1-PPS: 0.72
# TPR: 0.8181818181818182
# PPV: 0.6428571428571429
# classifier execution on:
# - train file: fold-16-train.csv
# - test file: fold-16-test.csv
# F2-PPS: 0.9649122807017544
# F1-PPS: 0.9166666666666666
# TPR: 1.0
# PPV: 0.8461538461538461
# classifier execution on:
# - train file: fold-17-train.csv
# - test file: fold-17-test.csv
# F2-PPS: 0.9482758620689655
# F1-PPS: 0.88
# TPR: 1.0
# PPV: 0.7857142857142857
# classifier execution on:
# - train file: fold-18-train.csv
# - test file: fold-18-test.csv
# F2-PPS: 0.8928571428571429
# F1-PPS: 0.8695652173913043
# TPR: 0.9090909090909091
# PPV: 0.8333333333333334
# classifier execution on:
# - train file: fold-19-train.csv
# - test file: fold-19-test.csv
# F2-PPS: 0.8928571428571429
# F1-PPS: 0.7692307692307693
# TPR: 1.0
# PPV: 0.625
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 1.0
# F1-PPS: 1.0
# TPR: 1.0
# PPV: 1.0
# classifier execution on:
# - train file: fold-20-train.csv
# - test file: fold-20-test.csv
# F2-PPS: 0.8490566037735849
# F1-PPS: 0.782608695652174
# TPR: 0.9
# PPV: 0.6923076923076923
# classifier execution on:
# - train file: fold-21-train.csv
# - test file: fold-21-test.csv
# F2-PPS: 0.9649122807017544
# F1-PPS: 0.9166666666666666
# TPR: 1.0
# PPV: 0.8461538461538461
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.8928571428571429
# F1-PPS: 0.8695652173913043
# TPR: 0.9090909090909091
# PPV: 0.8333333333333334
# classifier execution on:
# - train file: fold-4-train.csv
# - test file: fold-4-test.csv
# F2-PPS: 0.847457627118644
# F1-PPS: 0.7692307692307693
# TPR: 0.9090909090909091
# PPV: 0.6666666666666666
# classifier execution on:
# - train file: fold-5-train.csv
# - test file: fold-5-test.csv
# F2-PPS: 0.8928571428571429
# F1-PPS: 0.8695652173913043
# TPR: 0.9090909090909091
# PPV: 0.8333333333333334
# classifier execution on:
# - train file: fold-6-train.csv
# - test file: fold-6-test.csv
# F2-PPS: 0.9649122807017544
# F1-PPS: 0.9166666666666666
# TPR: 1.0
# PPV: 0.8461538461538461
# classifier execution on:
# - train file: fold-7-train.csv
# - test file: fold-7-test.csv
# F2-PPS: 0.9016393442622951
# F1-PPS: 0.7857142857142857
# TPR: 1.0
# PPV: 0.6470588235294118
# classifier execution on:
# - train file: fold-8-train.csv
# - test file: fold-8-test.csv
# F2-PPS: 0.8620689655172413
# F1-PPS: 0.8
# TPR: 0.9090909090909091
# PPV: 0.7142857142857143
# classifier execution on:
# - train file: fold-9-train.csv
# - test file: fold-9-test.csv
# F2-PPS: 0.9482758620689655
# F1-PPS: 0.88
# TPR: 1.0
# PPV: 0.7857142857142857
#
# F2-PPS: 0.9086727956562154
# F1-PPS: 0.8476978607620429
# TPR: 0.9562770562770565
# PPV: 0.7661014405762304
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 21, 'metric': 'minkowski'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.8771929824561403
# F1-PPS: 0.8333333333333334
# TPR: 0.9090909090909091
# PPV: 0.7692307692307693
# classifier execution on:
# - train file: fold-10-train.csv
# - test file: fold-10-test.csv
# F2-PPS: 0.9322033898305084
# F1-PPS: 0.8461538461538461
# TPR: 1.0
# PPV: 0.7333333333333333
# classifier execution on:
# - train file: fold-11-train.csv
# - test file: fold-11-test.csv
# F2-PPS: 0.8928571428571429
# F1-PPS: 0.8695652173913043
# TPR: 0.9090909090909091
# PPV: 0.8333333333333334
# classifier execution on:
# - train file: fold-12-train.csv
# - test file: fold-12-test.csv
# F2-PPS: 0.8870967741935484
# F1-PPS: 0.7586206896551724
# TPR: 1.0
# PPV: 0.6111111111111112
# classifier execution on:
# - train file: fold-13-train.csv
# - test file: fold-13-test.csv
# F2-PPS: 0.9322033898305084
# F1-PPS: 0.8461538461538461
# TPR: 1.0
# PPV: 0.7333333333333333
# classifier execution on:
# - train file: fold-14-train.csv
# - test file: fold-14-test.csv
# F2-PPS: 0.9322033898305084
# F1-PPS: 0.8461538461538461
# TPR: 1.0
# PPV: 0.7333333333333333
# classifier execution on:
# - train file: fold-15-train.csv
# - test file: fold-15-test.csv
# F2-PPS: 0.7758620689655172
# F1-PPS: 0.72
# TPR: 0.8181818181818182
# PPV: 0.6428571428571429
# classifier execution on:
# - train file: fold-16-train.csv
# - test file: fold-16-test.csv
# F2-PPS: 0.9482758620689655
# F1-PPS: 0.88
# TPR: 1.0
# PPV: 0.7857142857142857
# classifier execution on:
# - train file: fold-17-train.csv
# - test file: fold-17-test.csv
# F2-PPS: 0.9322033898305084
# F1-PPS: 0.8461538461538461
# TPR: 1.0
# PPV: 0.7333333333333333
# classifier execution on:
# - train file: fold-18-train.csv
# - test file: fold-18-test.csv
# F2-PPS: 0.8181818181818182
# F1-PPS: 0.8181818181818182
# TPR: 0.8181818181818182
# PPV: 0.8181818181818182
# classifier execution on:
# - train file: fold-19-train.csv
# - test file: fold-19-test.csv
# F2-PPS: 0.9090909090909091
# F1-PPS: 0.8
# TPR: 1.0
# PPV: 0.6666666666666666
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 1.0
# F1-PPS: 1.0
# TPR: 1.0
# PPV: 1.0
# classifier execution on:
# - train file: fold-20-train.csv
# - test file: fold-20-test.csv
# F2-PPS: 0.8490566037735849
# F1-PPS: 0.782608695652174
# TPR: 0.9
# PPV: 0.6923076923076923
# classifier execution on:
# - train file: fold-21-train.csv
# - test file: fold-21-test.csv
# F2-PPS: 0.9649122807017544
# F1-PPS: 0.9166666666666666
# TPR: 1.0
# PPV: 0.8461538461538461
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.8928571428571429
# F1-PPS: 0.8695652173913043
# TPR: 0.9090909090909091
# PPV: 0.8333333333333334
# classifier execution on:
# - train file: fold-4-train.csv
# - test file: fold-4-test.csv
# F2-PPS: 0.847457627118644
# F1-PPS: 0.7692307692307693
# TPR: 0.9090909090909091
# PPV: 0.6666666666666666
# classifier execution on:
# - train file: fold-5-train.csv
# - test file: fold-5-test.csv
# F2-PPS: 0.8928571428571429
# F1-PPS: 0.8695652173913043
# TPR: 0.9090909090909091
# PPV: 0.8333333333333334
# classifier execution on:
# - train file: fold-6-train.csv
# - test file: fold-6-test.csv
# F2-PPS: 0.9649122807017544
# F1-PPS: 0.9166666666666666
# TPR: 1.0
# PPV: 0.8461538461538461
# classifier execution on:
# - train file: fold-7-train.csv
# - test file: fold-7-test.csv
# F2-PPS: 0.9016393442622951
# F1-PPS: 0.7857142857142857
# TPR: 1.0
# PPV: 0.6470588235294118
# classifier execution on:
# - train file: fold-8-train.csv
# - test file: fold-8-test.csv
# F2-PPS: 0.8771929824561403
# F1-PPS: 0.8333333333333334
# TPR: 0.9090909090909091
# PPV: 0.7692307692307693
# classifier execution on:
# - train file: fold-9-train.csv
# - test file: fold-9-test.csv
# F2-PPS: 0.9322033898305084
# F1-PPS: 0.8461538461538461
# TPR: 1.0
# PPV: 0.7333333333333333
#
# F2-PPS: 0.9028790434140497
# F1-PPS: 0.8406581495893983
# TPR: 0.951948051948052
# PPV: 0.7584761954509854

# %%
for seed in [5, 8, 13]:
    print('-' * 50)
    print(f'seed: {seed}\n' + '-' * 50)
    results = evaluate(
        dir = model,
        loc = link,
        case = f'k-fold-{seed}',
        input = input,
        output = output,
        params = params,
        order = order
    )
    results.to_csv(os.path.join(output, f'k-fold-{seed}-results.csv'), index=False)
# Out:
# --------------------------------------------------
# seed: 5
# --------------------------------------------------
#
# k-fold-5
#
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 3, 'metric': 'euclidean'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.8478260869565217
# F1-PPS: 0.8210526315789474
# TPR: 0.8666666666666667
# PPV: 0.78
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.8870967741935484
# F1-PPS: 0.8
# TPR: 0.9565217391304348
# PPV: 0.6875
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.9036144578313253
# F1-PPS: 0.8108108108108109
# TPR: 0.9782608695652174
# PPV: 0.6923076923076923
# classifier execution on:
# - train file: fold-4-train.csv
# - test file: fold-4-test.csv
# F2-PPS: 0.8811475409836066
# F1-PPS: 0.8113207547169812
# TPR: 0.9347826086956522
# PPV: 0.7166666666666667
# classifier execution on:
# - train file: fold-5-train.csv
# - test file: fold-5-test.csv
# F2-PPS: 0.8884297520661157
# F1-PPS: 0.8269230769230769
# TPR: 0.9347826086956522
# PPV: 0.7413793103448276
#
# F2-PPS: 0.8816229224062235
# F1-PPS: 0.8140214548059633
# TPR: 0.9342028985507247
# PPV: 0.7235707338638374
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 3, 'metric': 'manhattan'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.8149779735682819
# F1-PPS: 0.8043478260869565
# TPR: 0.8222222222222222
# PPV: 0.7872340425531915
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.9183673469387755
# F1-PPS: 0.8411214953271028
# TPR: 0.9782608695652174
# PPV: 0.7377049180327869
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.9146341463414634
# F1-PPS: 0.8333333333333334
# TPR: 0.9782608695652174
# PPV: 0.7258064516129032
# classifier execution on:
# - train file: fold-4-train.csv
# - test file: fold-4-test.csv
# F2-PPS: 0.8811475409836066
# F1-PPS: 0.8113207547169812
# TPR: 0.9347826086956522
# PPV: 0.7166666666666667
# classifier execution on:
# - train file: fold-5-train.csv
# - test file: fold-5-test.csv
# F2-PPS: 0.8936170212765957
# F1-PPS: 0.865979381443299
# TPR: 0.9130434782608695
# PPV: 0.8235294117647058
#
# F2-PPS: 0.8845488058217447
# F1-PPS: 0.8312205581815345
# TPR: 0.9253140096618357
# PPV: 0.7581882981260508
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 3, 'metric': 'minkowski'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.8478260869565217
# F1-PPS: 0.8210526315789474
# TPR: 0.8666666666666667
# PPV: 0.78
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.8870967741935484
# F1-PPS: 0.8
# TPR: 0.9565217391304348
# PPV: 0.6875
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.9036144578313253
# F1-PPS: 0.8108108108108109
# TPR: 0.9782608695652174
# PPV: 0.6923076923076923
# classifier execution on:
# - train file: fold-4-train.csv
# - test file: fold-4-test.csv
# F2-PPS: 0.8811475409836066
# F1-PPS: 0.8113207547169812
# TPR: 0.9347826086956522
# PPV: 0.7166666666666667
# classifier execution on:
# - train file: fold-5-train.csv
# - test file: fold-5-test.csv
# F2-PPS: 0.8884297520661157
# F1-PPS: 0.8269230769230769
# TPR: 0.9347826086956522
# PPV: 0.7413793103448276
#
# F2-PPS: 0.8816229224062235
# F1-PPS: 0.8140214548059633
# TPR: 0.9342028985507247
# PPV: 0.7235707338638374
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 5, 'metric': 'euclidean'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.8620689655172413
# F1-PPS: 0.8247422680412371
# TPR: 0.8888888888888888
# PPV: 0.7692307692307693
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.9109311740890689
# F1-PPS: 0.8256880733944955
# TPR: 0.9782608695652174
# PPV: 0.7142857142857143
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.9109311740890689
# F1-PPS: 0.8256880733944955
# TPR: 0.9782608695652174
# PPV: 0.7142857142857143
# classifier execution on:
# - train file: fold-4-train.csv
# - test file: fold-4-test.csv
# F2-PPS: 0.9090909090909091
# F1-PPS: 0.8461538461538461
# TPR: 0.9565217391304348
# PPV: 0.7586206896551724
# classifier execution on:
# - train file: fold-5-train.csv
# - test file: fold-5-test.csv
# F2-PPS: 0.9166666666666666
# F1-PPS: 0.8627450980392157
# TPR: 0.9565217391304348
# PPV: 0.7857142857142857
#
# F2-PPS: 0.901937777890591
# F1-PPS: 0.837003471804658
# TPR: 0.9516908212560387
# PPV: 0.7484274346343313
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 5, 'metric': 'manhattan'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.8695652173913043
# F1-PPS: 0.8421052631578947
# TPR: 0.8888888888888888
# PPV: 0.8
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.9146341463414634
# F1-PPS: 0.8333333333333334
# TPR: 0.9782608695652174
# PPV: 0.7258064516129032
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.9183673469387755
# F1-PPS: 0.8411214953271028
# TPR: 0.9782608695652174
# PPV: 0.7377049180327869
# classifier execution on:
# - train file: fold-4-train.csv
# - test file: fold-4-test.csv
# F2-PPS: 0.9053497942386831
# F1-PPS: 0.8380952380952381
# TPR: 0.9565217391304348
# PPV: 0.7457627118644068
# classifier execution on:
# - train file: fold-5-train.csv
# - test file: fold-5-test.csv
# F2-PPS: 0.9110169491525424
# F1-PPS: 0.8775510204081632
# TPR: 0.9347826086956522
# PPV: 0.8269230769230769
#
# F2-PPS: 0.9037866908125537
# F1-PPS: 0.8464412700643464
# TPR: 0.9473429951690822
# PPV: 0.7672394316866347
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 5, 'metric': 'minkowski'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.8620689655172413
# F1-PPS: 0.8247422680412371
# TPR: 0.8888888888888888
# PPV: 0.7692307692307693
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.9109311740890689
# F1-PPS: 0.8256880733944955
# TPR: 0.9782608695652174
# PPV: 0.7142857142857143
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.9109311740890689
# F1-PPS: 0.8256880733944955
# TPR: 0.9782608695652174
# PPV: 0.7142857142857143
# classifier execution on:
# - train file: fold-4-train.csv
# - test file: fold-4-test.csv
# F2-PPS: 0.9090909090909091
# F1-PPS: 0.8461538461538461
# TPR: 0.9565217391304348
# PPV: 0.7586206896551724
# classifier execution on:
# - train file: fold-5-train.csv
# - test file: fold-5-test.csv
# F2-PPS: 0.9166666666666666
# F1-PPS: 0.8627450980392157
# TPR: 0.9565217391304348
# PPV: 0.7857142857142857
#
# F2-PPS: 0.901937777890591
# F1-PPS: 0.837003471804658
# TPR: 0.9516908212560387
# PPV: 0.7484274346343313
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 8, 'metric': 'euclidean'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.8547008547008547
# F1-PPS: 0.8080808080808081
# TPR: 0.8888888888888888
# PPV: 0.7407407407407407
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.9183673469387755
# F1-PPS: 0.8411214953271028
# TPR: 0.9782608695652174
# PPV: 0.7377049180327869
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.9183673469387755
# F1-PPS: 0.8411214953271028
# TPR: 0.9782608695652174
# PPV: 0.7377049180327869
# classifier execution on:
# - train file: fold-4-train.csv
# - test file: fold-4-test.csv
# F2-PPS: 0.8943089430894309
# F1-PPS: 0.8148148148148148
# TPR: 0.9565217391304348
# PPV: 0.7096774193548387
# classifier execution on:
# - train file: fold-5-train.csv
# - test file: fold-5-test.csv
# F2-PPS: 0.9053497942386831
# F1-PPS: 0.8380952380952381
# TPR: 0.9565217391304348
# PPV: 0.7457627118644068
#
# F2-PPS: 0.8982188571813039
# F1-PPS: 0.8286467703290133
# TPR: 0.9516908212560387
# PPV: 0.734318141605112
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 8, 'metric': 'manhattan'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.8620689655172413
# F1-PPS: 0.8247422680412371
# TPR: 0.8888888888888888
# PPV: 0.7692307692307693
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.9259259259259259
# F1-PPS: 0.8571428571428571
# TPR: 0.9782608695652174
# PPV: 0.7627118644067796
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.9221311475409836
# F1-PPS: 0.8490566037735849
# TPR: 0.9782608695652174
# PPV: 0.75
# classifier execution on:
# - train file: fold-4-train.csv
# - test file: fold-4-test.csv
# F2-PPS: 0.9128630705394191
# F1-PPS: 0.8543689320388349
# TPR: 0.9565217391304348
# PPV: 0.7719298245614035
# classifier execution on:
# - train file: fold-5-train.csv
# - test file: fold-5-test.csv
# F2-PPS: 0.9090909090909091
# F1-PPS: 0.8461538461538461
# TPR: 0.9565217391304348
# PPV: 0.7586206896551724
#
# F2-PPS: 0.9064160037228957
# F1-PPS: 0.846292901430072
# TPR: 0.9516908212560387
# PPV: 0.762498629570825
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 8, 'metric': 'minkowski'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.8547008547008547
# F1-PPS: 0.8080808080808081
# TPR: 0.8888888888888888
# PPV: 0.7407407407407407
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.9183673469387755
# F1-PPS: 0.8411214953271028
# TPR: 0.9782608695652174
# PPV: 0.7377049180327869
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.9183673469387755
# F1-PPS: 0.8411214953271028
# TPR: 0.9782608695652174
# PPV: 0.7377049180327869
# classifier execution on:
# - train file: fold-4-train.csv
# - test file: fold-4-test.csv
# F2-PPS: 0.8943089430894309
# F1-PPS: 0.8148148148148148
# TPR: 0.9565217391304348
# PPV: 0.7096774193548387
# classifier execution on:
# - train file: fold-5-train.csv
# - test file: fold-5-test.csv
# F2-PPS: 0.9053497942386831
# F1-PPS: 0.8380952380952381
# TPR: 0.9565217391304348
# PPV: 0.7457627118644068
#
# F2-PPS: 0.8982188571813039
# F1-PPS: 0.8286467703290133
# TPR: 0.9516908212560387
# PPV: 0.734318141605112
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 13, 'metric': 'euclidean'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.9012875536480687
# F1-PPS: 0.8571428571428571
# TPR: 0.9333333333333333
# PPV: 0.7924528301886793
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.8979591836734694
# F1-PPS: 0.822429906542056
# TPR: 0.9565217391304348
# PPV: 0.7213114754098361
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.9259259259259259
# F1-PPS: 0.8571428571428571
# TPR: 0.9782608695652174
# PPV: 0.7627118644067796
# classifier execution on:
# - train file: fold-4-train.csv
# - test file: fold-4-test.csv
# F2-PPS: 0.8943089430894309
# F1-PPS: 0.8148148148148148
# TPR: 0.9565217391304348
# PPV: 0.7096774193548387
# classifier execution on:
# - train file: fold-5-train.csv
# - test file: fold-5-test.csv
# F2-PPS: 0.8958333333333334
# F1-PPS: 0.8431372549019608
# TPR: 0.9347826086956522
# PPV: 0.7678571428571429
#
# F2-PPS: 0.9030629879340456
# F1-PPS: 0.8389335381089091
# TPR: 0.9518840579710146
# PPV: 0.7508021464434553
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 13, 'metric': 'manhattan'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.9090909090909091
# F1-PPS: 0.875
# TPR: 0.9333333333333333
# PPV: 0.8235294117647058
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.9221311475409836
# F1-PPS: 0.8490566037735849
# TPR: 0.9782608695652174
# PPV: 0.75
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.9183673469387755
# F1-PPS: 0.8411214953271028
# TPR: 0.9782608695652174
# PPV: 0.7377049180327869
# classifier execution on:
# - train file: fold-4-train.csv
# - test file: fold-4-test.csv
# F2-PPS: 0.9090909090909091
# F1-PPS: 0.8461538461538461
# TPR: 0.9565217391304348
# PPV: 0.7586206896551724
# classifier execution on:
# - train file: fold-5-train.csv
# - test file: fold-5-test.csv
# F2-PPS: 0.9071729957805907
# F1-PPS: 0.8686868686868687
# TPR: 0.9347826086956522
# PPV: 0.8113207547169812
#
# F2-PPS: 0.9131706616884336
# F1-PPS: 0.8560037627882805
# TPR: 0.956231884057971
# PPV: 0.7762351548339292
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 13, 'metric': 'minkowski'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.9012875536480687
# F1-PPS: 0.8571428571428571
# TPR: 0.9333333333333333
# PPV: 0.7924528301886793
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.8979591836734694
# F1-PPS: 0.822429906542056
# TPR: 0.9565217391304348
# PPV: 0.7213114754098361
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.9259259259259259
# F1-PPS: 0.8571428571428571
# TPR: 0.9782608695652174
# PPV: 0.7627118644067796
# classifier execution on:
# - train file: fold-4-train.csv
# - test file: fold-4-test.csv
# F2-PPS: 0.8943089430894309
# F1-PPS: 0.8148148148148148
# TPR: 0.9565217391304348
# PPV: 0.7096774193548387
# classifier execution on:
# - train file: fold-5-train.csv
# - test file: fold-5-test.csv
# F2-PPS: 0.8958333333333334
# F1-PPS: 0.8431372549019608
# TPR: 0.9347826086956522
# PPV: 0.7678571428571429
#
# F2-PPS: 0.9030629879340456
# F1-PPS: 0.8389335381089091
# TPR: 0.9518840579710146
# PPV: 0.7508021464434553
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 21, 'metric': 'euclidean'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.8860759493670886
# F1-PPS: 0.8235294117647058
# TPR: 0.9333333333333333
# PPV: 0.7368421052631579
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.8775510204081632
# F1-PPS: 0.8037383177570093
# TPR: 0.9347826086956522
# PPV: 0.7049180327868853
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.907258064516129
# F1-PPS: 0.8181818181818182
# TPR: 0.9782608695652174
# PPV: 0.703125
# classifier execution on:
# - train file: fold-4-train.csv
# - test file: fold-4-test.csv
# F2-PPS: 0.9016393442622951
# F1-PPS: 0.8301886792452831
# TPR: 0.9565217391304348
# PPV: 0.7333333333333333
# classifier execution on:
# - train file: fold-5-train.csv
# - test file: fold-5-test.csv
# F2-PPS: 0.9090909090909091
# F1-PPS: 0.8461538461538461
# TPR: 0.9565217391304348
# PPV: 0.7586206896551724
#
# F2-PPS: 0.8963230575289168
# F1-PPS: 0.8243584146205325
# TPR: 0.9518840579710144
# PPV: 0.7273678322077097
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 21, 'metric': 'manhattan'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.8974358974358975
# F1-PPS: 0.8484848484848485
# TPR: 0.9333333333333333
# PPV: 0.7777777777777778
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.8884297520661157
# F1-PPS: 0.8269230769230769
# TPR: 0.9347826086956522
# PPV: 0.7413793103448276
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.9259259259259259
# F1-PPS: 0.8571428571428571
# TPR: 0.9782608695652174
# PPV: 0.7627118644067796
# classifier execution on:
# - train file: fold-4-train.csv
# - test file: fold-4-test.csv
# F2-PPS: 0.9016393442622951
# F1-PPS: 0.8301886792452831
# TPR: 0.9565217391304348
# PPV: 0.7333333333333333
# classifier execution on:
# - train file: fold-5-train.csv
# - test file: fold-5-test.csv
# F2-PPS: 0.9205020920502092
# F1-PPS: 0.8712871287128713
# TPR: 0.9565217391304348
# PPV: 0.8
#
# F2-PPS: 0.9067866023480887
# F1-PPS: 0.8468053181017874
# TPR: 0.9518840579710144
# PPV: 0.7630404571725438
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 21, 'metric': 'minkowski'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.8860759493670886
# F1-PPS: 0.8235294117647058
# TPR: 0.9333333333333333
# PPV: 0.7368421052631579
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.8775510204081632
# F1-PPS: 0.8037383177570093
# TPR: 0.9347826086956522
# PPV: 0.7049180327868853
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.907258064516129
# F1-PPS: 0.8181818181818182
# TPR: 0.9782608695652174
# PPV: 0.703125
# classifier execution on:
# - train file: fold-4-train.csv
# - test file: fold-4-test.csv
# F2-PPS: 0.9016393442622951
# F1-PPS: 0.8301886792452831
# TPR: 0.9565217391304348
# PPV: 0.7333333333333333
# classifier execution on:
# - train file: fold-5-train.csv
# - test file: fold-5-test.csv
# F2-PPS: 0.9090909090909091
# F1-PPS: 0.8461538461538461
# TPR: 0.9565217391304348
# PPV: 0.7586206896551724
#
# F2-PPS: 0.8963230575289168
# F1-PPS: 0.8243584146205325
# TPR: 0.9518840579710144
# PPV: 0.7273678322077097
# --------------------------------------------------
# seed: 8
# --------------------------------------------------
#
# k-fold-8
#
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 3, 'metric': 'euclidean'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.8450704225352113
# F1-PPS: 0.8275862068965517
# TPR: 0.8571428571428571
# PPV: 0.8
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.8503401360544217
# F1-PPS: 0.7936507936507936
# TPR: 0.8928571428571429
# PPV: 0.7142857142857143
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.89171974522293
# F1-PPS: 0.8
# TPR: 0.9655172413793104
# PPV: 0.6829268292682927
# classifier execution on:
# - train file: fold-4-train.csv
# - test file: fold-4-test.csv
# F2-PPS: 0.8823529411764706
# F1-PPS: 0.8181818181818182
# TPR: 0.9310344827586207
# PPV: 0.7297297297297297
# classifier execution on:
# - train file: fold-5-train.csv
# - test file: fold-5-test.csv
# F2-PPS: 0.9177215189873418
# F1-PPS: 0.8169014084507042
# TPR: 1.0
# PPV: 0.6904761904761905
# classifier execution on:
# - train file: fold-6-train.csv
# - test file: fold-6-test.csv
# F2-PPS: 0.8823529411764706
# F1-PPS: 0.8181818181818182
# TPR: 0.9310344827586207
# PPV: 0.7297297297297297
# classifier execution on:
# - train file: fold-7-train.csv
# - test file: fold-7-test.csv
# F2-PPS: 0.9271523178807947
# F1-PPS: 0.875
# TPR: 0.9655172413793104
# PPV: 0.8
# classifier execution on:
# - train file: fold-8-train.csv
# - test file: fold-8-test.csv
# F2-PPS: 0.8552631578947368
# F1-PPS: 0.7647058823529411
# TPR: 0.9285714285714286
# PPV: 0.65
#
# F2-PPS: 0.8814966476160472
# F1-PPS: 0.8142759909643283
# TPR: 0.9339593596059113
# PPV: 0.724643524186207
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 3, 'metric': 'manhattan'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.8156028368794326
# F1-PPS: 0.8070175438596491
# TPR: 0.8214285714285714
# PPV: 0.7931034482758621
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.8445945945945946
# F1-PPS: 0.78125
# TPR: 0.8928571428571429
# PPV: 0.6944444444444444
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.9415584415584416
# F1-PPS: 0.8656716417910447
# TPR: 1.0
# PPV: 0.7631578947368421
# classifier execution on:
# - train file: fold-4-train.csv
# - test file: fold-4-test.csv
# F2-PPS: 0.8881578947368421
# F1-PPS: 0.8307692307692308
# TPR: 0.9310344827586207
# PPV: 0.75
# classifier execution on:
# - train file: fold-5-train.csv
# - test file: fold-5-test.csv
# F2-PPS: 0.9354838709677419
# F1-PPS: 0.8529411764705882
# TPR: 1.0
# PPV: 0.7435897435897436
# classifier execution on:
# - train file: fold-6-train.csv
# - test file: fold-6-test.csv
# F2-PPS: 0.8881578947368421
# F1-PPS: 0.8307692307692308
# TPR: 0.9310344827586207
# PPV: 0.75
# classifier execution on:
# - train file: fold-7-train.csv
# - test file: fold-7-test.csv
# F2-PPS: 0.9395973154362416
# F1-PPS: 0.9032258064516129
# TPR: 0.9655172413793104
# PPV: 0.8484848484848485
# classifier execution on:
# - train file: fold-8-train.csv
# - test file: fold-8-test.csv
# F2-PPS: 0.8783783783783784
# F1-PPS: 0.8125
# TPR: 0.9285714285714286
# PPV: 0.7222222222222222
#
# F2-PPS: 0.8914414034110644
# F1-PPS: 0.8355180787639196
# TPR: 0.9338054187192117
# PPV: 0.7581253252192454
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 3, 'metric': 'minkowski'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.8450704225352113
# F1-PPS: 0.8275862068965517
# TPR: 0.8571428571428571
# PPV: 0.8
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.8503401360544217
# F1-PPS: 0.7936507936507936
# TPR: 0.8928571428571429
# PPV: 0.7142857142857143
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.89171974522293
# F1-PPS: 0.8
# TPR: 0.9655172413793104
# PPV: 0.6829268292682927
# classifier execution on:
# - train file: fold-4-train.csv
# - test file: fold-4-test.csv
# F2-PPS: 0.8823529411764706
# F1-PPS: 0.8181818181818182
# TPR: 0.9310344827586207
# PPV: 0.7297297297297297
# classifier execution on:
# - train file: fold-5-train.csv
# - test file: fold-5-test.csv
# F2-PPS: 0.9177215189873418
# F1-PPS: 0.8169014084507042
# TPR: 1.0
# PPV: 0.6904761904761905
# classifier execution on:
# - train file: fold-6-train.csv
# - test file: fold-6-test.csv
# F2-PPS: 0.8823529411764706
# F1-PPS: 0.8181818181818182
# TPR: 0.9310344827586207
# PPV: 0.7297297297297297
# classifier execution on:
# - train file: fold-7-train.csv
# - test file: fold-7-test.csv
# F2-PPS: 0.9271523178807947
# F1-PPS: 0.875
# TPR: 0.9655172413793104
# PPV: 0.8
# classifier execution on:
# - train file: fold-8-train.csv
# - test file: fold-8-test.csv
# F2-PPS: 0.8552631578947368
# F1-PPS: 0.7647058823529411
# TPR: 0.9285714285714286
# PPV: 0.65
#
# F2-PPS: 0.8814966476160472
# F1-PPS: 0.8142759909643283
# TPR: 0.9339593596059113
# PPV: 0.724643524186207
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 5, 'metric': 'euclidean'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.896551724137931
# F1-PPS: 0.8524590163934426
# TPR: 0.9285714285714286
# PPV: 0.7878787878787878
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.8904109589041096
# F1-PPS: 0.8387096774193549
# TPR: 0.9285714285714286
# PPV: 0.7647058823529411
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.9294871794871795
# F1-PPS: 0.8405797101449275
# TPR: 1.0
# PPV: 0.725
# classifier execution on:
# - train file: fold-4-train.csv
# - test file: fold-4-test.csv
# F2-PPS: 0.8823529411764706
# F1-PPS: 0.8181818181818182
# TPR: 0.9310344827586207
# PPV: 0.7297297297297297
# classifier execution on:
# - train file: fold-5-train.csv
# - test file: fold-5-test.csv
# F2-PPS: 0.9235668789808917
# F1-PPS: 0.8285714285714286
# TPR: 1.0
# PPV: 0.7073170731707317
# classifier execution on:
# - train file: fold-6-train.csv
# - test file: fold-6-test.csv
# F2-PPS: 0.8940397350993378
# F1-PPS: 0.84375
# TPR: 0.9310344827586207
# PPV: 0.7714285714285715
# classifier execution on:
# - train file: fold-7-train.csv
# - test file: fold-7-test.csv
# F2-PPS: 0.9333333333333333
# F1-PPS: 0.8888888888888888
# TPR: 0.9655172413793104
# PPV: 0.8235294117647058
# classifier execution on:
# - train file: fold-8-train.csv
# - test file: fold-8-test.csv
# F2-PPS: 0.9
# F1-PPS: 0.8181818181818182
# TPR: 0.9642857142857143
# PPV: 0.7105263157894737
#
# F2-PPS: 0.9062178438899067
# F1-PPS: 0.8411652947227098
# TPR: 0.9561268472906403
# PPV: 0.7525144715143677
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 5, 'metric': 'manhattan'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.9090909090909091
# F1-PPS: 0.8813559322033898
# TPR: 0.9285714285714286
# PPV: 0.8387096774193549
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.8843537414965986
# F1-PPS: 0.8253968253968254
# TPR: 0.9285714285714286
# PPV: 0.7428571428571429
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.9354838709677419
# F1-PPS: 0.8529411764705882
# TPR: 1.0
# PPV: 0.7435897435897436
# classifier execution on:
# - train file: fold-4-train.csv
# - test file: fold-4-test.csv
# F2-PPS: 0.8823529411764706
# F1-PPS: 0.8181818181818182
# TPR: 0.9310344827586207
# PPV: 0.7297297297297297
# classifier execution on:
# - train file: fold-5-train.csv
# - test file: fold-5-test.csv
# F2-PPS: 0.9294871794871795
# F1-PPS: 0.8405797101449275
# TPR: 1.0
# PPV: 0.725
# classifier execution on:
# - train file: fold-6-train.csv
# - test file: fold-6-test.csv
# F2-PPS: 0.8881578947368421
# F1-PPS: 0.8307692307692308
# TPR: 0.9310344827586207
# PPV: 0.75
# classifier execution on:
# - train file: fold-7-train.csv
# - test file: fold-7-test.csv
# F2-PPS: 0.9060402684563759
# F1-PPS: 0.8709677419354839
# TPR: 0.9310344827586207
# PPV: 0.8181818181818182
# classifier execution on:
# - train file: fold-8-train.csv
# - test file: fold-8-test.csv
# F2-PPS: 0.8843537414965986
# F1-PPS: 0.8253968253968254
# TPR: 0.9285714285714286
# PPV: 0.7428571428571429
#
# F2-PPS: 0.9024150683635896
# F1-PPS: 0.8431986575623861
# TPR: 0.9473522167487685
# PPV: 0.7613656568293665
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 5, 'metric': 'minkowski'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.896551724137931
# F1-PPS: 0.8524590163934426
# TPR: 0.9285714285714286
# PPV: 0.7878787878787878
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.8904109589041096
# F1-PPS: 0.8387096774193549
# TPR: 0.9285714285714286
# PPV: 0.7647058823529411
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.9294871794871795
# F1-PPS: 0.8405797101449275
# TPR: 1.0
# PPV: 0.725
# classifier execution on:
# - train file: fold-4-train.csv
# - test file: fold-4-test.csv
# F2-PPS: 0.8823529411764706
# F1-PPS: 0.8181818181818182
# TPR: 0.9310344827586207
# PPV: 0.7297297297297297
# classifier execution on:
# - train file: fold-5-train.csv
# - test file: fold-5-test.csv
# F2-PPS: 0.9235668789808917
# F1-PPS: 0.8285714285714286
# TPR: 1.0
# PPV: 0.7073170731707317
# classifier execution on:
# - train file: fold-6-train.csv
# - test file: fold-6-test.csv
# F2-PPS: 0.8940397350993378
# F1-PPS: 0.84375
# TPR: 0.9310344827586207
# PPV: 0.7714285714285715
# classifier execution on:
# - train file: fold-7-train.csv
# - test file: fold-7-test.csv
# F2-PPS: 0.9333333333333333
# F1-PPS: 0.8888888888888888
# TPR: 0.9655172413793104
# PPV: 0.8235294117647058
# classifier execution on:
# - train file: fold-8-train.csv
# - test file: fold-8-test.csv
# F2-PPS: 0.9
# F1-PPS: 0.8181818181818182
# TPR: 0.9642857142857143
# PPV: 0.7105263157894737
#
# F2-PPS: 0.9062178438899067
# F1-PPS: 0.8411652947227098
# TPR: 0.9561268472906403
# PPV: 0.7525144715143677
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 8, 'metric': 'euclidean'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.8904109589041096
# F1-PPS: 0.8387096774193549
# TPR: 0.9285714285714286
# PPV: 0.7647058823529411
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.8904109589041096
# F1-PPS: 0.8387096774193549
# TPR: 0.9285714285714286
# PPV: 0.7647058823529411
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.9415584415584416
# F1-PPS: 0.8656716417910447
# TPR: 1.0
# PPV: 0.7631578947368421
# classifier execution on:
# - train file: fold-4-train.csv
# - test file: fold-4-test.csv
# F2-PPS: 0.8881578947368421
# F1-PPS: 0.8307692307692308
# TPR: 0.9310344827586207
# PPV: 0.75
# classifier execution on:
# - train file: fold-5-train.csv
# - test file: fold-5-test.csv
# F2-PPS: 0.9235668789808917
# F1-PPS: 0.8285714285714286
# TPR: 1.0
# PPV: 0.7073170731707317
# classifier execution on:
# - train file: fold-6-train.csv
# - test file: fold-6-test.csv
# F2-PPS: 0.8766233766233766
# F1-PPS: 0.8059701492537313
# TPR: 0.9310344827586207
# PPV: 0.7105263157894737
# classifier execution on:
# - train file: fold-7-train.csv
# - test file: fold-7-test.csv
# F2-PPS: 0.9032258064516129
# F1-PPS: 0.8235294117647058
# TPR: 0.9655172413793104
# PPV: 0.717948717948718
# classifier execution on:
# - train file: fold-8-train.csv
# - test file: fold-8-test.csv
# F2-PPS: 0.9060402684563759
# F1-PPS: 0.8307692307692308
# TPR: 0.9642857142857143
# PPV: 0.7297297297297297
#
# F2-PPS: 0.90249932307697
# F1-PPS: 0.8328375559697603
# TPR: 0.9561268472906403
# PPV: 0.7385114370101722
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 8, 'metric': 'manhattan'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.8741258741258742
# F1-PPS: 0.847457627118644
# TPR: 0.8928571428571429
# PPV: 0.8064516129032258
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.8620689655172413
# F1-PPS: 0.819672131147541
# TPR: 0.8928571428571429
# PPV: 0.7575757575757576
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.9415584415584416
# F1-PPS: 0.8656716417910447
# TPR: 1.0
# PPV: 0.7631578947368421
# classifier execution on:
# - train file: fold-4-train.csv
# - test file: fold-4-test.csv
# F2-PPS: 0.8881578947368421
# F1-PPS: 0.8307692307692308
# TPR: 0.9310344827586207
# PPV: 0.75
# classifier execution on:
# - train file: fold-5-train.csv
# - test file: fold-5-test.csv
# F2-PPS: 0.9294871794871795
# F1-PPS: 0.8405797101449275
# TPR: 1.0
# PPV: 0.725
# classifier execution on:
# - train file: fold-6-train.csv
# - test file: fold-6-test.csv
# F2-PPS: 0.8881578947368421
# F1-PPS: 0.8307692307692308
# TPR: 0.9310344827586207
# PPV: 0.75
# classifier execution on:
# - train file: fold-7-train.csv
# - test file: fold-7-test.csv
# F2-PPS: 0.9210526315789473
# F1-PPS: 0.8615384615384616
# TPR: 0.9655172413793104
# PPV: 0.7777777777777778
# classifier execution on:
# - train file: fold-8-train.csv
# - test file: fold-8-test.csv
# F2-PPS: 0.9121621621621622
# F1-PPS: 0.84375
# TPR: 0.9642857142857143
# PPV: 0.75
#
# F2-PPS: 0.9020963804879414
# F1-PPS: 0.842526004159885
# TPR: 0.947198275862069
# PPV: 0.7599953803742003
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 8, 'metric': 'minkowski'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.8904109589041096
# F1-PPS: 0.8387096774193549
# TPR: 0.9285714285714286
# PPV: 0.7647058823529411
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.8904109589041096
# F1-PPS: 0.8387096774193549
# TPR: 0.9285714285714286
# PPV: 0.7647058823529411
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.9415584415584416
# F1-PPS: 0.8656716417910447
# TPR: 1.0
# PPV: 0.7631578947368421
# classifier execution on:
# - train file: fold-4-train.csv
# - test file: fold-4-test.csv
# F2-PPS: 0.8881578947368421
# F1-PPS: 0.8307692307692308
# TPR: 0.9310344827586207
# PPV: 0.75
# classifier execution on:
# - train file: fold-5-train.csv
# - test file: fold-5-test.csv
# F2-PPS: 0.9235668789808917
# F1-PPS: 0.8285714285714286
# TPR: 1.0
# PPV: 0.7073170731707317
# classifier execution on:
# - train file: fold-6-train.csv
# - test file: fold-6-test.csv
# F2-PPS: 0.8766233766233766
# F1-PPS: 0.8059701492537313
# TPR: 0.9310344827586207
# PPV: 0.7105263157894737
# classifier execution on:
# - train file: fold-7-train.csv
# - test file: fold-7-test.csv
# F2-PPS: 0.9032258064516129
# F1-PPS: 0.8235294117647058
# TPR: 0.9655172413793104
# PPV: 0.717948717948718
# classifier execution on:
# - train file: fold-8-train.csv
# - test file: fold-8-test.csv
# F2-PPS: 0.9060402684563759
# F1-PPS: 0.8307692307692308
# TPR: 0.9642857142857143
# PPV: 0.7297297297297297
#
# F2-PPS: 0.90249932307697
# F1-PPS: 0.8328375559697603
# TPR: 0.9561268472906403
# PPV: 0.7385114370101722
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 13, 'metric': 'euclidean'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.9183673469387755
# F1-PPS: 0.8571428571428571
# TPR: 0.9642857142857143
# PPV: 0.7714285714285715
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.8620689655172413
# F1-PPS: 0.819672131147541
# TPR: 0.8928571428571429
# PPV: 0.7575757575757576
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.9235668789808917
# F1-PPS: 0.8285714285714286
# TPR: 1.0
# PPV: 0.7073170731707317
# classifier execution on:
# - train file: fold-4-train.csv
# - test file: fold-4-test.csv
# F2-PPS: 0.8766233766233766
# F1-PPS: 0.8059701492537313
# TPR: 0.9310344827586207
# PPV: 0.7105263157894737
# classifier execution on:
# - train file: fold-5-train.csv
# - test file: fold-5-test.csv
# F2-PPS: 0.9294871794871795
# F1-PPS: 0.8405797101449275
# TPR: 1.0
# PPV: 0.725
# classifier execution on:
# - train file: fold-6-train.csv
# - test file: fold-6-test.csv
# F2-PPS: 0.8766233766233766
# F1-PPS: 0.8059701492537313
# TPR: 0.9310344827586207
# PPV: 0.7105263157894737
# classifier execution on:
# - train file: fold-7-train.csv
# - test file: fold-7-test.csv
# F2-PPS: 0.9
# F1-PPS: 0.8571428571428571
# TPR: 0.9310344827586207
# PPV: 0.7941176470588235
# classifier execution on:
# - train file: fold-8-train.csv
# - test file: fold-8-test.csv
# F2-PPS: 0.9183673469387755
# F1-PPS: 0.8571428571428571
# TPR: 0.9642857142857143
# PPV: 0.7714285714285715
#
# F2-PPS: 0.9006380588887022
# F1-PPS: 0.8340240174749913
# TPR: 0.9518165024630542
# PPV: 0.7434900315301753
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 13, 'metric': 'manhattan'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.9375
# F1-PPS: 0.9
# TPR: 0.9642857142857143
# PPV: 0.84375
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.8620689655172413
# F1-PPS: 0.819672131147541
# TPR: 0.8928571428571429
# PPV: 0.7575757575757576
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.9235668789808917
# F1-PPS: 0.8285714285714286
# TPR: 1.0
# PPV: 0.7073170731707317
# classifier execution on:
# - train file: fold-4-train.csv
# - test file: fold-4-test.csv
# F2-PPS: 0.8766233766233766
# F1-PPS: 0.8059701492537313
# TPR: 0.9310344827586207
# PPV: 0.7105263157894737
# classifier execution on:
# - train file: fold-5-train.csv
# - test file: fold-5-test.csv
# F2-PPS: 0.9294871794871795
# F1-PPS: 0.8405797101449275
# TPR: 1.0
# PPV: 0.725
# classifier execution on:
# - train file: fold-6-train.csv
# - test file: fold-6-test.csv
# F2-PPS: 0.8823529411764706
# F1-PPS: 0.8181818181818182
# TPR: 0.9310344827586207
# PPV: 0.7297297297297297
# classifier execution on:
# - train file: fold-7-train.csv
# - test file: fold-7-test.csv
# F2-PPS: 0.9060402684563759
# F1-PPS: 0.8709677419354839
# TPR: 0.9310344827586207
# PPV: 0.8181818181818182
# classifier execution on:
# - train file: fold-8-train.csv
# - test file: fold-8-test.csv
# F2-PPS: 0.8904109589041096
# F1-PPS: 0.8387096774193549
# TPR: 0.9285714285714286
# PPV: 0.7647058823529411
#
# F2-PPS: 0.9010063211432056
# F1-PPS: 0.8403315820817856
# TPR: 0.9473522167487685
# PPV: 0.7570983221000565
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 13, 'metric': 'minkowski'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.9183673469387755
# F1-PPS: 0.8571428571428571
# TPR: 0.9642857142857143
# PPV: 0.7714285714285715
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.8620689655172413
# F1-PPS: 0.819672131147541
# TPR: 0.8928571428571429
# PPV: 0.7575757575757576
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.9235668789808917
# F1-PPS: 0.8285714285714286
# TPR: 1.0
# PPV: 0.7073170731707317
# classifier execution on:
# - train file: fold-4-train.csv
# - test file: fold-4-test.csv
# F2-PPS: 0.8766233766233766
# F1-PPS: 0.8059701492537313
# TPR: 0.9310344827586207
# PPV: 0.7105263157894737
# classifier execution on:
# - train file: fold-5-train.csv
# - test file: fold-5-test.csv
# F2-PPS: 0.9294871794871795
# F1-PPS: 0.8405797101449275
# TPR: 1.0
# PPV: 0.725
# classifier execution on:
# - train file: fold-6-train.csv
# - test file: fold-6-test.csv
# F2-PPS: 0.8766233766233766
# F1-PPS: 0.8059701492537313
# TPR: 0.9310344827586207
# PPV: 0.7105263157894737
# classifier execution on:
# - train file: fold-7-train.csv
# - test file: fold-7-test.csv
# F2-PPS: 0.9
# F1-PPS: 0.8571428571428571
# TPR: 0.9310344827586207
# PPV: 0.7941176470588235
# classifier execution on:
# - train file: fold-8-train.csv
# - test file: fold-8-test.csv
# F2-PPS: 0.9183673469387755
# F1-PPS: 0.8571428571428571
# TPR: 0.9642857142857143
# PPV: 0.7714285714285715
#
# F2-PPS: 0.9006380588887022
# F1-PPS: 0.8340240174749913
# TPR: 0.9518165024630542
# PPV: 0.7434900315301753
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 21, 'metric': 'euclidean'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.9246575342465754
# F1-PPS: 0.8709677419354839
# TPR: 0.9642857142857143
# PPV: 0.7941176470588235
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.8680555555555556
# F1-PPS: 0.8333333333333334
# TPR: 0.8928571428571429
# PPV: 0.78125
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.9354838709677419
# F1-PPS: 0.8529411764705882
# TPR: 1.0
# PPV: 0.7435897435897436
# classifier execution on:
# - train file: fold-4-train.csv
# - test file: fold-4-test.csv
# F2-PPS: 0.8709677419354839
# F1-PPS: 0.7941176470588235
# TPR: 0.9310344827586207
# PPV: 0.6923076923076923
# classifier execution on:
# - train file: fold-5-train.csv
# - test file: fold-5-test.csv
# F2-PPS: 0.9235668789808917
# F1-PPS: 0.8285714285714286
# TPR: 1.0
# PPV: 0.7073170731707317
# classifier execution on:
# - train file: fold-6-train.csv
# - test file: fold-6-test.csv
# F2-PPS: 0.8766233766233766
# F1-PPS: 0.8059701492537313
# TPR: 0.9310344827586207
# PPV: 0.7105263157894737
# classifier execution on:
# - train file: fold-7-train.csv
# - test file: fold-7-test.csv
# F2-PPS: 0.8940397350993378
# F1-PPS: 0.84375
# TPR: 0.9310344827586207
# PPV: 0.7714285714285715
# classifier execution on:
# - train file: fold-8-train.csv
# - test file: fold-8-test.csv
# F2-PPS: 0.9246575342465754
# F1-PPS: 0.8709677419354839
# TPR: 0.9642857142857143
# PPV: 0.7941176470588235
#
# F2-PPS: 0.9022565284569424
# F1-PPS: 0.8375774023198591
# TPR: 0.9518165024630542
# PPV: 0.7493318363004825
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 21, 'metric': 'manhattan'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.9027777777777778
# F1-PPS: 0.8666666666666667
# TPR: 0.9285714285714286
# PPV: 0.8125
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.8680555555555556
# F1-PPS: 0.8333333333333334
# TPR: 0.8928571428571429
# PPV: 0.78125
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.9354838709677419
# F1-PPS: 0.8529411764705882
# TPR: 1.0
# PPV: 0.7435897435897436
# classifier execution on:
# - train file: fold-4-train.csv
# - test file: fold-4-test.csv
# F2-PPS: 0.8823529411764706
# F1-PPS: 0.8181818181818182
# TPR: 0.9310344827586207
# PPV: 0.7297297297297297
# classifier execution on:
# - train file: fold-5-train.csv
# - test file: fold-5-test.csv
# F2-PPS: 0.9354838709677419
# F1-PPS: 0.8529411764705882
# TPR: 1.0
# PPV: 0.7435897435897436
# classifier execution on:
# - train file: fold-6-train.csv
# - test file: fold-6-test.csv
# F2-PPS: 0.8766233766233766
# F1-PPS: 0.8059701492537313
# TPR: 0.9310344827586207
# PPV: 0.7105263157894737
# classifier execution on:
# - train file: fold-7-train.csv
# - test file: fold-7-test.csv
# F2-PPS: 0.9090909090909091
# F1-PPS: 0.835820895522388
# TPR: 0.9655172413793104
# PPV: 0.7368421052631579
# classifier execution on:
# - train file: fold-8-train.csv
# - test file: fold-8-test.csv
# F2-PPS: 0.9183673469387755
# F1-PPS: 0.8571428571428571
# TPR: 0.9642857142857143
# PPV: 0.7714285714285715
#
# F2-PPS: 0.9035294561372936
# F1-PPS: 0.8403747591302464
# TPR: 0.9516625615763546
# PPV: 0.7536820261738025
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 21, 'metric': 'minkowski'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.9246575342465754
# F1-PPS: 0.8709677419354839
# TPR: 0.9642857142857143
# PPV: 0.7941176470588235
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.8680555555555556
# F1-PPS: 0.8333333333333334
# TPR: 0.8928571428571429
# PPV: 0.78125
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.9354838709677419
# F1-PPS: 0.8529411764705882
# TPR: 1.0
# PPV: 0.7435897435897436
# classifier execution on:
# - train file: fold-4-train.csv
# - test file: fold-4-test.csv
# F2-PPS: 0.8709677419354839
# F1-PPS: 0.7941176470588235
# TPR: 0.9310344827586207
# PPV: 0.6923076923076923
# classifier execution on:
# - train file: fold-5-train.csv
# - test file: fold-5-test.csv
# F2-PPS: 0.9235668789808917
# F1-PPS: 0.8285714285714286
# TPR: 1.0
# PPV: 0.7073170731707317
# classifier execution on:
# - train file: fold-6-train.csv
# - test file: fold-6-test.csv
# F2-PPS: 0.8766233766233766
# F1-PPS: 0.8059701492537313
# TPR: 0.9310344827586207
# PPV: 0.7105263157894737
# classifier execution on:
# - train file: fold-7-train.csv
# - test file: fold-7-test.csv
# F2-PPS: 0.8940397350993378
# F1-PPS: 0.84375
# TPR: 0.9310344827586207
# PPV: 0.7714285714285715
# classifier execution on:
# - train file: fold-8-train.csv
# - test file: fold-8-test.csv
# F2-PPS: 0.9246575342465754
# F1-PPS: 0.8709677419354839
# TPR: 0.9642857142857143
# PPV: 0.7941176470588235
#
# F2-PPS: 0.9022565284569424
# F1-PPS: 0.8375774023198591
# TPR: 0.9518165024630542
# PPV: 0.7493318363004825
# --------------------------------------------------
# seed: 13
# --------------------------------------------------
#
# k-fold-13
#
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 3, 'metric': 'euclidean'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.8333333333333334
# F1-PPS: 0.8333333333333334
# TPR: 0.8333333333333334
# PPV: 0.8333333333333334
# classifier execution on:
# - train file: fold-10-train.csv
# - test file: fold-10-test.csv
# F2-PPS: 0.8522727272727273
# F1-PPS: 0.8108108108108109
# TPR: 0.8823529411764706
# PPV: 0.75
# classifier execution on:
# - train file: fold-11-train.csv
# - test file: fold-11-test.csv
# F2-PPS: 0.9090909090909091
# F1-PPS: 0.8648648648648649
# TPR: 0.9411764705882353
# PPV: 0.8
# classifier execution on:
# - train file: fold-12-train.csv
# - test file: fold-12-test.csv
# F2-PPS: 0.9183673469387755
# F1-PPS: 0.8181818181818182
# TPR: 1.0
# PPV: 0.6923076923076923
# classifier execution on:
# - train file: fold-13-train.csv
# - test file: fold-13-test.csv
# F2-PPS: 0.8333333333333334
# F1-PPS: 0.7619047619047619
# TPR: 0.8888888888888888
# PPV: 0.6666666666666666
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.8791208791208791
# F1-PPS: 0.8648648648648649
# TPR: 0.8888888888888888
# PPV: 0.8421052631578947
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.8602150537634409
# F1-PPS: 0.8205128205128205
# TPR: 0.8888888888888888
# PPV: 0.7619047619047619
# classifier execution on:
# - train file: fold-4-train.csv
# - test file: fold-4-test.csv
# F2-PPS: 0.9183673469387755
# F1-PPS: 0.8181818181818182
# TPR: 1.0
# PPV: 0.6923076923076923
# classifier execution on:
# - train file: fold-5-train.csv
# - test file: fold-5-test.csv
# F2-PPS: 0.8762886597938144
# F1-PPS: 0.7906976744186046
# TPR: 0.9444444444444444
# PPV: 0.68
# classifier execution on:
# - train file: fold-6-train.csv
# - test file: fold-6-test.csv
# F2-PPS: 0.9473684210526315
# F1-PPS: 0.8780487804878049
# TPR: 1.0
# PPV: 0.782608695652174
# classifier execution on:
# - train file: fold-7-train.csv
# - test file: fold-7-test.csv
# F2-PPS: 0.8695652173913043
# F1-PPS: 0.7804878048780488
# TPR: 0.9411764705882353
# PPV: 0.6666666666666666
# classifier execution on:
# - train file: fold-8-train.csv
# - test file: fold-8-test.csv
# F2-PPS: 0.8947368421052632
# F1-PPS: 0.7727272727272727
# TPR: 1.0
# PPV: 0.6296296296296297
# classifier execution on:
# - train file: fold-9-train.csv
# - test file: fold-9-test.csv
# F2-PPS: 0.9340659340659341
# F1-PPS: 0.85
# TPR: 1.0
# PPV: 0.7391304347826086
#
# F2-PPS: 0.8866250772462402
# F1-PPS: 0.8203551250128327
# TPR: 0.9391654097536452
# PPV: 0.7335892951083938
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 3, 'metric': 'manhattan'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.8426966292134831
# F1-PPS: 0.8571428571428571
# TPR: 0.8333333333333334
# PPV: 0.8823529411764706
# classifier execution on:
# - train file: fold-10-train.csv
# - test file: fold-10-test.csv
# F2-PPS: 0.8522727272727273
# F1-PPS: 0.8108108108108109
# TPR: 0.8823529411764706
# PPV: 0.75
# classifier execution on:
# - train file: fold-11-train.csv
# - test file: fold-11-test.csv
# F2-PPS: 0.9302325581395349
# F1-PPS: 0.9142857142857143
# TPR: 0.9411764705882353
# PPV: 0.8888888888888888
# classifier execution on:
# - train file: fold-12-train.csv
# - test file: fold-12-test.csv
# F2-PPS: 0.9278350515463918
# F1-PPS: 0.8372093023255814
# TPR: 1.0
# PPV: 0.72
# classifier execution on:
# - train file: fold-13-train.csv
# - test file: fold-13-test.csv
# F2-PPS: 0.851063829787234
# F1-PPS: 0.8
# ...
# - test file: fold-6-test.csv
# F2-PPS: 0.9473684210526315
# F1-PPS: 0.8780487804878049
# TPR: 1.0
# PPV: 0.782608695652174
# classifier execution on:
# - train file: fold-7-train.csv
# - test file: fold-7-test.csv
# F2-PPS: 0.8791208791208791
# F1-PPS: 0.8
# TPR: 0.9411764705882353
# PPV: 0.6956521739130435
# classifier execution on:
# - train file: fold-8-train.csv
# - test file: fold-8-test.csv
# F2-PPS: 0.9239130434782609
# F1-PPS: 0.8292682926829268
# TPR: 1.0
# PPV: 0.7083333333333334
# classifier execution on:
# - train file: fold-9-train.csv
# - test file: fold-9-test.csv
# F2-PPS: 0.9340659340659341
# F1-PPS: 0.85
# TPR: 1.0
# PPV: 0.7391304347826086
#
# F2-PPS: 0.9046163536830018
# F1-PPS: 0.8376478333697235
# TPR: 0.9562594268476622
# PPV: 0.7471204920175173
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 13, 'metric': 'euclidean'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.9042553191489362
# F1-PPS: 0.85
# TPR: 0.9444444444444444
# PPV: 0.7727272727272727
# classifier execution on:
# - train file: fold-10-train.csv
# - test file: fold-10-test.csv
# F2-PPS: 0.8426966292134831
# F1-PPS: 0.7894736842105263
# TPR: 0.8823529411764706
# PPV: 0.7142857142857143
# classifier execution on:
# - train file: fold-11-train.csv
# - test file: fold-11-test.csv
# F2-PPS: 0.872093023255814
# F1-PPS: 0.8571428571428571
# TPR: 0.8823529411764706
# PPV: 0.8333333333333334
# classifier execution on:
# - train file: fold-12-train.csv
# - test file: fold-12-test.csv
# F2-PPS: 0.9278350515463918
# F1-PPS: 0.8372093023255814
# TPR: 1.0
# PPV: 0.72
# classifier execution on:
# - train file: fold-13-train.csv
# - test file: fold-13-test.csv
# F2-PPS: 0.9042553191489362
# F1-PPS: 0.85
# TPR: 0.9444444444444444
# PPV: 0.7727272727272727
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.9139784946236559
# F1-PPS: 0.8717948717948718
# TPR: 0.9444444444444444
# PPV: 0.8095238095238095
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.8695652173913043
# F1-PPS: 0.8421052631578947
# TPR: 0.8888888888888888
# PPV: 0.8
# classifier execution on:
# - train file: fold-4-train.csv
# - test file: fold-4-test.csv
# F2-PPS: 0.9278350515463918
# F1-PPS: 0.8372093023255814
# TPR: 1.0
# PPV: 0.72
# classifier execution on:
# - train file: fold-5-train.csv
# - test file: fold-5-test.csv
# F2-PPS: 0.9183673469387755
# F1-PPS: 0.8181818181818182
# TPR: 1.0
# PPV: 0.6923076923076923
# classifier execution on:
# - train file: fold-6-train.csv
# - test file: fold-6-test.csv
# F2-PPS: 0.9473684210526315
# F1-PPS: 0.8780487804878049
# TPR: 1.0
# PPV: 0.782608695652174
# classifier execution on:
# - train file: fold-7-train.csv
# - test file: fold-7-test.csv
# F2-PPS: 0.8695652173913043
# F1-PPS: 0.7804878048780488
# TPR: 0.9411764705882353
# PPV: 0.6666666666666666
# classifier execution on:
# - train file: fold-8-train.csv
# - test file: fold-8-test.csv
# F2-PPS: 0.9340659340659341
# F1-PPS: 0.85
# TPR: 1.0
# PPV: 0.7391304347826086
# classifier execution on:
# - train file: fold-9-train.csv
# - test file: fold-9-test.csv
# F2-PPS: 0.9340659340659341
# F1-PPS: 0.85
# TPR: 1.0
# PPV: 0.7391304347826086
#
# F2-PPS: 0.9050728430299612
# F1-PPS: 0.8393579757311527
# TPR: 0.9560080442433384
# PPV: 0.7509570251376273
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 13, 'metric': 'manhattan'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.9139784946236559
# F1-PPS: 0.8717948717948718
# TPR: 0.9444444444444444
# PPV: 0.8095238095238095
# classifier execution on:
# - train file: fold-10-train.csv
# - test file: fold-10-test.csv
# F2-PPS: 0.8522727272727273
# F1-PPS: 0.8108108108108109
# TPR: 0.8823529411764706
# PPV: 0.75
# classifier execution on:
# - train file: fold-11-train.csv
# - test file: fold-11-test.csv
# F2-PPS: 0.8928571428571429
# F1-PPS: 0.9090909090909091
# TPR: 0.8823529411764706
# PPV: 0.9375
# classifier execution on:
# - train file: fold-12-train.csv
# - test file: fold-12-test.csv
# F2-PPS: 0.8762886597938144
# F1-PPS: 0.7906976744186046
# TPR: 0.9444444444444444
# PPV: 0.68
# classifier execution on:
# - train file: fold-13-train.csv
# - test file: fold-13-test.csv
# F2-PPS: 0.9139784946236559
# F1-PPS: 0.8717948717948718
# TPR: 0.9444444444444444
# PPV: 0.8095238095238095
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.9340659340659341
# F1-PPS: 0.918918918918919
# TPR: 0.9444444444444444
# PPV: 0.8947368421052632
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.8602150537634409
# F1-PPS: 0.8205128205128205
# TPR: 0.8888888888888888
# PPV: 0.7619047619047619
# classifier execution on:
# - train file: fold-4-train.csv
# - test file: fold-4-test.csv
# F2-PPS: 0.9375
# F1-PPS: 0.8571428571428571
# TPR: 1.0
# PPV: 0.75
# classifier execution on:
# - train file: fold-5-train.csv
# - test file: fold-5-test.csv
# F2-PPS: 0.8673469387755102
# F1-PPS: 0.7727272727272727
# TPR: 0.9444444444444444
# PPV: 0.6538461538461539
# classifier execution on:
# - train file: fold-6-train.csv
# - test file: fold-6-test.csv
# F2-PPS: 0.9278350515463918
# F1-PPS: 0.8372093023255814
# TPR: 1.0
# PPV: 0.72
# classifier execution on:
# - train file: fold-7-train.csv
# - test file: fold-7-test.csv
# F2-PPS: 0.8791208791208791
# F1-PPS: 0.8
# TPR: 0.9411764705882353
# PPV: 0.6956521739130435
# classifier execution on:
# - train file: fold-8-train.csv
# - test file: fold-8-test.csv
# F2-PPS: 0.9340659340659341
# F1-PPS: 0.85
# TPR: 1.0
# PPV: 0.7391304347826086
# classifier execution on:
# - train file: fold-9-train.csv
# - test file: fold-9-test.csv
# F2-PPS: 0.9340659340659341
# F1-PPS: 0.85
# TPR: 1.0
# PPV: 0.7391304347826086
#
# F2-PPS: 0.9018147111211555
# F1-PPS: 0.8431307930413475
# TPR: 0.9474610356963299
# PPV: 0.7646883400293892
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 13, 'metric': 'minkowski'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.9042553191489362
# F1-PPS: 0.85
# TPR: 0.9444444444444444
# PPV: 0.7727272727272727
# classifier execution on:
# - train file: fold-10-train.csv
# - test file: fold-10-test.csv
# F2-PPS: 0.8426966292134831
# F1-PPS: 0.7894736842105263
# TPR: 0.8823529411764706
# PPV: 0.7142857142857143
# classifier execution on:
# - train file: fold-11-train.csv
# - test file: fold-11-test.csv
# F2-PPS: 0.872093023255814
# F1-PPS: 0.8571428571428571
# TPR: 0.8823529411764706
# PPV: 0.8333333333333334
# classifier execution on:
# - train file: fold-12-train.csv
# - test file: fold-12-test.csv
# F2-PPS: 0.9278350515463918
# F1-PPS: 0.8372093023255814
# TPR: 1.0
# PPV: 0.72
# classifier execution on:
# - train file: fold-13-train.csv
# - test file: fold-13-test.csv
# F2-PPS: 0.9042553191489362
# F1-PPS: 0.85
# TPR: 0.9444444444444444
# PPV: 0.7727272727272727
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.9139784946236559
# F1-PPS: 0.8717948717948718
# TPR: 0.9444444444444444
# PPV: 0.8095238095238095
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.8695652173913043
# F1-PPS: 0.8421052631578947
# TPR: 0.8888888888888888
# PPV: 0.8
# classifier execution on:
# - train file: fold-4-train.csv
# - test file: fold-4-test.csv
# F2-PPS: 0.9278350515463918
# F1-PPS: 0.8372093023255814
# TPR: 1.0
# PPV: 0.72
# classifier execution on:
# - train file: fold-5-train.csv
# - test file: fold-5-test.csv
# F2-PPS: 0.9183673469387755
# F1-PPS: 0.8181818181818182
# TPR: 1.0
# PPV: 0.6923076923076923
# classifier execution on:
# - train file: fold-6-train.csv
# - test file: fold-6-test.csv
# F2-PPS: 0.9473684210526315
# F1-PPS: 0.8780487804878049
# TPR: 1.0
# PPV: 0.782608695652174
# classifier execution on:
# - train file: fold-7-train.csv
# - test file: fold-7-test.csv
# F2-PPS: 0.8695652173913043
# F1-PPS: 0.7804878048780488
# TPR: 0.9411764705882353
# PPV: 0.6666666666666666
# classifier execution on:
# - train file: fold-8-train.csv
# - test file: fold-8-test.csv
# F2-PPS: 0.9340659340659341
# F1-PPS: 0.85
# TPR: 1.0
# PPV: 0.7391304347826086
# classifier execution on:
# - train file: fold-9-train.csv
# - test file: fold-9-test.csv
# F2-PPS: 0.9340659340659341
# F1-PPS: 0.85
# TPR: 1.0
# PPV: 0.7391304347826086
#
# F2-PPS: 0.9050728430299612
# F1-PPS: 0.8393579757311527
# TPR: 0.9560080442433384
# PPV: 0.7509570251376273
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 21, 'metric': 'euclidean'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.9042553191489362
# F1-PPS: 0.85
# TPR: 0.9444444444444444
# PPV: 0.7727272727272727
# classifier execution on:
# - train file: fold-10-train.csv
# - test file: fold-10-test.csv
# F2-PPS: 0.8426966292134831
# F1-PPS: 0.7894736842105263
# TPR: 0.8823529411764706
# PPV: 0.7142857142857143
# classifier execution on:
# - train file: fold-11-train.csv
# - test file: fold-11-test.csv
# F2-PPS: 0.9195402298850575
# F1-PPS: 0.8888888888888888
# TPR: 0.9411764705882353
# PPV: 0.8421052631578947
# classifier execution on:
# - train file: fold-12-train.csv
# - test file: fold-12-test.csv
# F2-PPS: 0.9183673469387755
# F1-PPS: 0.8181818181818182
# TPR: 1.0
# PPV: 0.6923076923076923
# classifier execution on:
# - train file: fold-13-train.csv
# - test file: fold-13-test.csv
# F2-PPS: 0.9239130434782609
# F1-PPS: 0.8947368421052632
# TPR: 0.9444444444444444
# PPV: 0.85
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.9042553191489362
# F1-PPS: 0.85
# TPR: 0.9444444444444444
# PPV: 0.7727272727272727
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.8695652173913043
# F1-PPS: 0.8421052631578947
# TPR: 0.8888888888888888
# PPV: 0.8
# classifier execution on:
# - train file: fold-4-train.csv
# - test file: fold-4-test.csv
# F2-PPS: 0.9278350515463918
# F1-PPS: 0.8372093023255814
# TPR: 1.0
# PPV: 0.72
# classifier execution on:
# - train file: fold-5-train.csv
# - test file: fold-5-test.csv
# F2-PPS: 0.8854166666666666
# F1-PPS: 0.8095238095238095
# TPR: 0.9444444444444444
# PPV: 0.7083333333333334
# classifier execution on:
# - train file: fold-6-train.csv
# - test file: fold-6-test.csv
# F2-PPS: 0.9278350515463918
# F1-PPS: 0.8372093023255814
# TPR: 1.0
# PPV: 0.72
# classifier execution on:
# - train file: fold-7-train.csv
# - test file: fold-7-test.csv
# F2-PPS: 0.8791208791208791
# F1-PPS: 0.8
# TPR: 0.9411764705882353
# PPV: 0.6956521739130435
# classifier execution on:
# - train file: fold-8-train.csv
# - test file: fold-8-test.csv
# F2-PPS: 0.9239130434782609
# F1-PPS: 0.8292682926829268
# TPR: 1.0
# PPV: 0.7083333333333334
# classifier execution on:
# - train file: fold-9-train.csv
# - test file: fold-9-test.csv
# F2-PPS: 0.9139784946236559
# F1-PPS: 0.8095238095238095
# TPR: 1.0
# PPV: 0.68
#
# F2-PPS: 0.903130176322077
# F1-PPS: 0.8350862317635463
# TPR: 0.9562594268476622
# PPV: 0.7443440042911966
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 21, 'metric': 'manhattan'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.9139784946236559
# F1-PPS: 0.8717948717948718
# TPR: 0.9444444444444444
# PPV: 0.8095238095238095
# classifier execution on:
# - train file: fold-10-train.csv
# - test file: fold-10-test.csv
# F2-PPS: 0.8620689655172413
# F1-PPS: 0.8333333333333334
# TPR: 0.8823529411764706
# PPV: 0.7894736842105263
# classifier execution on:
# - train file: fold-11-train.csv
# - test file: fold-11-test.csv
# F2-PPS: 0.9302325581395349
# F1-PPS: 0.9142857142857143
# TPR: 0.9411764705882353
# PPV: 0.8888888888888888
# classifier execution on:
# - train file: fold-12-train.csv
# - test file: fold-12-test.csv
# F2-PPS: 0.9183673469387755
# F1-PPS: 0.8181818181818182
# TPR: 1.0
# PPV: 0.6923076923076923
# classifier execution on:
# - train file: fold-13-train.csv
# - test file: fold-13-test.csv
# F2-PPS: 0.9139784946236559
# F1-PPS: 0.8717948717948718
# TPR: 0.9444444444444444
# PPV: 0.8095238095238095
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.9139784946236559
# F1-PPS: 0.8717948717948718
# TPR: 0.9444444444444444
# PPV: 0.8095238095238095
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.8695652173913043
# F1-PPS: 0.8421052631578947
# TPR: 0.8888888888888888
# PPV: 0.8
# classifier execution on:
# - train file: fold-4-train.csv
# - test file: fold-4-test.csv
# F2-PPS: 0.9375
# F1-PPS: 0.8571428571428571
# TPR: 1.0
# PPV: 0.75
# classifier execution on:
# - train file: fold-5-train.csv
# - test file: fold-5-test.csv
# F2-PPS: 0.8762886597938144
# F1-PPS: 0.7906976744186046
# TPR: 0.9444444444444444
# PPV: 0.68
# classifier execution on:
# - train file: fold-6-train.csv
# - test file: fold-6-test.csv
# F2-PPS: 0.9375
# F1-PPS: 0.8571428571428571
# TPR: 1.0
# PPV: 0.75
# classifier execution on:
# - train file: fold-7-train.csv
# - test file: fold-7-test.csv
# F2-PPS: 0.8888888888888888
# F1-PPS: 0.8205128205128205
# TPR: 0.9411764705882353
# PPV: 0.7272727272727273
# classifier execution on:
# - train file: fold-8-train.csv
# - test file: fold-8-test.csv
# F2-PPS: 0.9340659340659341
# F1-PPS: 0.85
# TPR: 1.0
# PPV: 0.7391304347826086
# classifier execution on:
# - train file: fold-9-train.csv
# - test file: fold-9-test.csv
# F2-PPS: 0.9139784946236559
# F1-PPS: 0.8095238095238095
# TPR: 1.0
# PPV: 0.68
#
# F2-PPS: 0.9084916576330859
# F1-PPS: 0.8467931356218712
# TPR: 0.9562594268476622
# PPV: 0.7635111427718363
# --------------------------------------------------
# K-Nearest Neighbors Classifier Parameters: {'n_neighbors': 21, 'metric': 'minkowski'}
# --------------------------------------------------
#
# classifier execution on:
# - train file: fold-1-train.csv
# - test file: fold-1-test.csv
# F2-PPS: 0.9042553191489362
# F1-PPS: 0.85
# TPR: 0.9444444444444444
# PPV: 0.7727272727272727
# classifier execution on:
# - train file: fold-10-train.csv
# - test file: fold-10-test.csv
# F2-PPS: 0.8426966292134831
# F1-PPS: 0.7894736842105263
# TPR: 0.8823529411764706
# PPV: 0.7142857142857143
# classifier execution on:
# - train file: fold-11-train.csv
# - test file: fold-11-test.csv
# F2-PPS: 0.9195402298850575
# F1-PPS: 0.8888888888888888
# TPR: 0.9411764705882353
# PPV: 0.8421052631578947
# classifier execution on:
# - train file: fold-12-train.csv
# - test file: fold-12-test.csv
# F2-PPS: 0.9183673469387755
# F1-PPS: 0.8181818181818182
# TPR: 1.0
# PPV: 0.6923076923076923
# classifier execution on:
# - train file: fold-13-train.csv
# - test file: fold-13-test.csv
# F2-PPS: 0.9239130434782609
# F1-PPS: 0.8947368421052632
# TPR: 0.9444444444444444
# PPV: 0.85
# classifier execution on:
# - train file: fold-2-train.csv
# - test file: fold-2-test.csv
# F2-PPS: 0.9042553191489362
# F1-PPS: 0.85
# TPR: 0.9444444444444444
# PPV: 0.7727272727272727
# classifier execution on:
# - train file: fold-3-train.csv
# - test file: fold-3-test.csv
# F2-PPS: 0.8695652173913043
# F1-PPS: 0.8421052631578947
# TPR: 0.8888888888888888
# PPV: 0.8
# classifier execution on:
# - train file: fold-4-train.csv
# - test file: fold-4-test.csv
# F2-PPS: 0.9278350515463918
# F1-PPS: 0.8372093023255814
# TPR: 1.0
# PPV: 0.72
# classifier execution on:
# - train file: fold-5-train.csv
# - test file: fold-5-test.csv
# F2-PPS: 0.8854166666666666
# F1-PPS: 0.8095238095238095
# TPR: 0.9444444444444444
# PPV: 0.7083333333333334
# classifier execution on:
# - train file: fold-6-train.csv
# - test file: fold-6-test.csv
# F2-PPS: 0.9278350515463918
# F1-PPS: 0.8372093023255814
# TPR: 1.0
# PPV: 0.72
# classifier execution on:
# - train file: fold-7-train.csv
# - test file: fold-7-test.csv
# F2-PPS: 0.8791208791208791
# F1-PPS: 0.8
# TPR: 0.9411764705882353
# PPV: 0.6956521739130435
# classifier execution on:
# - train file: fold-8-train.csv
# - test file: fold-8-test.csv
# F2-PPS: 0.9239130434782609
# F1-PPS: 0.8292682926829268
# TPR: 1.0
# PPV: 0.7083333333333334
# classifier execution on:
# - train file: fold-9-train.csv
# - test file: fold-9-test.csv
# F2-PPS: 0.9139784946236559
# F1-PPS: 0.8095238095238095
# TPR: 1.0
# PPV: 0.68
#
# F2-PPS: 0.903130176322077
# F1-PPS: 0.8350862317635463
# TPR: 0.9562594268476622
# PPV: 0.7443440042911966

# %% [markdown]
# ## *Statistical* **Data Analysis**

# %% [markdown]
# **Requirements**

# %%
import os
import glob
import numpy as np
import pandas as pd
import scipy.stats as stats

import seaborn as sns
import matplotlib.pyplot as plt

from typing import List, Dict

# %%
np.random.seed(42)

# %%
device = 'cpu'
device
# Out:
# 'cpu'

# %%
branch = os.path.join(f"/content/drive/MyDrive/{paths['notebook-results']}", 'k-nearest-neighbors-params')

# %%
output = os.path.join(branch, 'pubmedbert-base-embeddings')

# %% [markdown]
# *Evaluation Metrics Sorting Criteria*

# %%
order = [
    'F2-PPS', # F2-Score (Class 1 - Patient Preference Studies)
    'F1-PPS', # F1-Score (Class 1 - Patient Preference Studies)
    'TPR',    # True Positive Rate
    'PPV',    # Positive Predictive Value
    'AUC-PR', # Area Under Precision-Recall Curve
    'BA',     # Balanced Accuracy
    'AUC-ROC' # Area Under ROC Curve
]

# %%
def combine(
    dir: str,
    main: List[str],
    order: List[str]
) -> pd.DataFrame:
    """
    combine multiple .csv files into a single DataFrame

    args:
        dir (str): path to the folder with .csv files
        main (List[str]): main group-by columns
        order (List[str]): evaluation metrics sorting criteria

    returns:
        pd.DataFrame: DataFrame with scores
    """
    files = glob.glob(os.path.join(dir, "*.csv"))
    data = list()
    for file in files:
        frame = pd.read_csv(file)
        data.append(frame)
    concat = pd.concat(data)
    data = (
        concat.groupby(main)
        .agg(
            ['mean', 'std']
        )
        .reset_index()
    )
    data.columns = [
        '-'.join(column).strip('-') for column in data.columns
        if column not in main
    ]
    for column in data.columns:
        if column.endswith('-mean'):
            base = column.rsplit('-', 1)[0]
            deviation = f'{base}-std'
            if deviation in data.columns:
                # compute confidence interval
                N = len(concat.groupby(main))
                sem = data[deviation] / np.sqrt(N)
                deg = N - 1
                # 99% confidence level
                critical = stats.t.ppf(0.995, deg)
                lower = data[column] - critical * sem
                upper = data[column] + critical * sem
                data[f'{base}-ci'] = (
                    data[column].round(3).astype(str) + " ± " +
                    ((upper - lower) / 2).round(3).astype(str)
                )
    data = data.sort_values(
        by=[f"{metric}-mean" for metric in order],
        ascending=[False] * len(order)
    )
    columns = [
        column for column in data.columns
        if column.endswith('-ci')
    ]
    data = data[main + columns]
    data.columns = [
        column.replace('-ci', '') for column in data.columns
    ]
    return data

# %%
def get(
    data: pd.DataFrame,
    case: str,
    order: List[str]
) -> pd.DataFrame:
    """
    get a dataframe by group-by on input column

    args:
        data (pd.DataFrame): DataFrame with evaluation results
        case (str): group-by column to plot (e.g., 'BERT-Base Model')
        order (List[str]): evaluation metrics sorting criteria

    returns:
        pd.DataFrame: DataFrame with scores
    """
    data = data[[case] + order].copy()
    for metric in order:
        data[metric] = data[metric].str.extract(r'(\d+\.\d+)').astype(float)
    res = (
        data.groupby(case)
        .agg(
            ['mean', 'std']
        )
        .reset_index()
    )
    res.columns = [
        '-'.join(column).strip('-') for column in res.columns
        if column not in [case]
    ]
    for column in res.columns:
        if column.endswith('-mean'):
            base = column.rsplit('-', 1)[0]
            deviation = f'{base}-std'
            if deviation in res.columns:
                # compute confidence interval
                N = len(data.groupby([case]))
                sem = res[deviation] / np.sqrt(N)
                deg = N - 1
                # 99% confidence level
                critical = stats.t.ppf(0.995, deg)
                lower = res[column] - critical * sem
                upper = res[column] + critical * sem
                res[f'{base}-ci'] = (
                    res[column].round(3).astype(str) + " ± " +
                    ((upper - lower) / 2).round(3).astype(str)
                )
    res = res.sort_values(
        by=[f"{metric}-mean" for metric in order],
        ascending=[False] * len(order)
    )
    columns = [
        column for column in res.columns
        if column.endswith('-ci')
    ]
    res = res[[case] + columns]
    res.columns = [
        column.replace('-ci', '') for column in res.columns
    ]
    return res

# %%
def plot(
    data: pd.DataFrame,
    column: str,
    output: str,
    order: List[str]
) -> None:
    """
    plot performance metrics with confidence intervals

    args:
        data (pd.DataFrame): DataFrame with evaluation results
        column (str): group-by column to plot (e.g., 'BERT-Base Model')
        output (str): path to output folder to store plot
        order (List[str]): evaluation metrics sorting criteria
    """
    chart = list()
    for metric in order:
        if metric in data.columns:
            for _, row in data.iterrows():
                ci = row[metric].split(' ± ')
                mean = float(ci[0])
                error = float(ci[1])
                chart.append({
                    column: row[column],
                    'Metric': metric,
                    'Mean': mean,
                    'Error': error
                })
    chart = pd.DataFrame(chart)
    chart[column] = chart[column].astype(str)
    plt.figure(figsize=(16, 9))
    position = -0.75
    ax = sns.barplot(
        chart,
        x=column,
        y='Mean',
        hue='Metric',
        ci=None,
        palette='crest'
    )
    for bar, (_, row) in zip(ax.patches, chart.iterrows()):
        center = bar.get_x() + bar.get_width() / 2
        lower = row['Mean'] - row['Error']
        upper = row['Mean'] + row['Error']
        plt.errorbar(
            x=center,
            y=row['Mean'],
            yerr=row['Error'],
            fmt='none',
            color='black',
            linestyle='-',
            linewidth=0.5
        )
    for idx, metric in enumerate(chart['Metric'].unique()):
        columns = chart[chart['Metric'] == metric]
        row = columns.loc[columns['Mean'].idxmax()]
        value = row['Mean']
        center = (
            ax.patches[
                chart.index.get_loc(row.name)
            ].get_x() +
            ax.patches[
                chart.index.get_loc(row.name)
            ].get_width() / 2
        )
        if metric == 'F2-PPS':
            ax.plot(
                [center, position],
                [value, value],
                color='black',
                linestyle='--',
                linewidth=0.5
            )
            ax.text(
                x=position,
                y=value,
                s=f'{value:.3f}',
                ha='right',
                va='center',
                fontsize=10
            )
    plt.title(
        f'{column} Performance Distributions',
        fontsize=15
    )
    plt.xlabel(
        column,
        fontsize=10
    )
    plt.ylabel(
        'Metric Value',
        fontsize=10
    )
    plt.legend(
        title=f'Metric',
        bbox_to_anchor=(1.05, 1),
        loc='upper left'
    )
    ax.set_xticklabels(
        ax.get_xticklabels(),
        rotation=45,
        ha="right",
        rotation_mode='anchor'
    )
    plt.ylim(
        bottom=min(
            chart['Mean'] - chart['Error']
        )
    )
    plt.tight_layout()
    plt.savefig(
        f'{output}/{column.lower().replace(" ", "-")}-performance-plot.png',
        dpi=300,
        bbox_inches='tight'
    )
    plt.show()

# %% [markdown]
# **Global** *Statistical Data Analysis*

# %%
results = combine(
    dir = output,
    main = ['K-Nearest Neighbors Parameters'],
    order = order
)
results.head()
# Out:
#                 K-Nearest Neighbors Parameters         F2-PPS         F1-PPS  \
# 13   {'n_neighbors': 8, 'metric': 'manhattan'}  0.903 ± 0.004  0.844 ± 0.006
# 1   {'n_neighbors': 13, 'metric': 'manhattan'}  0.903 ± 0.005  0.841 ± 0.009
# 10   {'n_neighbors': 5, 'metric': 'manhattan'}  0.902 ± 0.008  0.841 ± 0.011
# 4   {'n_neighbors': 21, 'metric': 'manhattan'}  0.902 ± 0.008   0.838 ± 0.01
# 9    {'n_neighbors': 5, 'metric': 'euclidean'}  0.902 ± 0.005   0.833 ± 0.01
#
#               TPR            FNR            PPV            FDR         AUC-PR  \
# 13  0.948 ± 0.004  0.052 ± 0.004  0.762 ± 0.012  0.238 ± 0.012  0.926 ± 0.004
# 1    0.95 ± 0.003   0.05 ± 0.003  0.757 ± 0.015  0.243 ± 0.015  0.938 ± 0.003
# 10  0.948 ± 0.006  0.052 ± 0.006  0.759 ± 0.017  0.241 ± 0.017  0.905 ± 0.005
# 4    0.95 ± 0.006   0.05 ± 0.006  0.751 ± 0.014  0.249 ± 0.014  0.943 ± 0.005
# 9   0.955 ± 0.002  0.045 ± 0.002  0.741 ± 0.017  0.259 ± 0.017  0.891 ± 0.008
#
#                BA        AUC-ROC  ...            FPR            NPV  \
# 13  0.939 ± 0.002  0.976 ± 0.001  ...   0.07 ± 0.004  0.987 ± 0.001
# 1   0.939 ± 0.004  0.978 ± 0.001  ...  0.072 ± 0.005  0.988 ± 0.001
# 10  0.938 ± 0.005  0.972 ± 0.001  ...  0.071 ± 0.006  0.987 ± 0.001
# 4   0.938 ± 0.005  0.977 ± 0.002  ...  0.074 ± 0.004  0.988 ± 0.002
# 9   0.938 ± 0.003   0.97 ± 0.002  ...  0.079 ± 0.006  0.989 ± 0.001
#
#               FOR       Accuracy Weighted F1-Score Weighted Precision  \
# 13  0.013 ± 0.001  0.934 ± 0.003     0.936 ± 0.003      0.945 ± 0.002
# 1   0.012 ± 0.001  0.932 ± 0.005     0.935 ± 0.004      0.944 ± 0.003
# 10  0.013 ± 0.001  0.932 ± 0.005     0.935 ± 0.005      0.944 ± 0.004
# 4   0.012 ± 0.002   0.93 ± 0.005     0.934 ± 0.004      0.943 ± 0.004
# 9   0.011 ± 0.001  0.928 ± 0.005     0.931 ± 0.005      0.942 ± 0.003
#
#    Weighted Recall Macro F1-Score Macro Precision   Macro Recall
# 13   0.934 ± 0.003  0.901 ± 0.004   0.875 ± 0.006  0.939 ± 0.002
# 1    0.932 ± 0.005  0.899 ± 0.006   0.873 ± 0.008  0.939 ± 0.004
# 10   0.932 ± 0.005  0.899 ± 0.007   0.873 ± 0.009  0.938 ± 0.005
# 4     0.93 ± 0.005  0.897 ± 0.007   0.869 ± 0.008  0.938 ± 0.005
# 9    0.928 ± 0.005  0.893 ± 0.007   0.865 ± 0.009  0.938 ± 0.003
#
# [5 rows x 25 columns]

# %%
results.to_csv(os.path.join(output, f'ranks.csv'), encoding='utf-8', index=False)

# %% [markdown]
# **Local** *Statistical Data Analysis* - **by K-Nearest Neighbors Classifier Parameters**

# %%
frame = results[['K-Nearest Neighbors Parameters'] + order].copy()

plot(frame, 'K-Nearest Neighbors Parameters', output, order)

# %% [markdown]
# *What to* **Move Forward**

# %%
def select(
    dir: str,
    title: str,
    column: str,
    output: str,
    main: List[str],
    order: List[str],
    model: Dict[str, str] = None
) -> pd.DataFrame:
    """
    what to move forward

    args:
        dir (str): path to the folder with .csv file
        title (str): plot title
        column (str): group-by column to plot (e.g., 'BERT-Base Model')
        output (str): path to output folder to store plot
        main (List[str]): main group-by columns
        order (List[str]): evaluation metrics sorting criteria
        model (Dict[str, str], optional): dictionary with {'BERT-Base Model': 'bert-base model'} to filter

    returns:
        pd.DataFrame: DataFrame with scores
    """
    data = pd.read_csv(dir)
    data = data[main + order]
    if model:
        key, value = next(iter(model.items()))
        data = data[data[key] == value]
    def lower(value):
        base, error = map(float, value.split(' ± '))
        return base - error
    for metric in order:
        data[metric] = data[metric].apply(lower)
    data = data.sort_values(
        by=order,
        ascending=[False] * len(order)
    )
    data.to_csv(os.path.join(output, f'{title.lower().replace(" ", "-")}-ranks.csv'), encoding='utf-8', index=False)
    chart = []
    for metric in order:
        if metric in data.columns:
            for _, row in data.iterrows():
                mean = float(row[metric])
                chart.append({
                    column: row[column],
                    'Metric': metric,
                    'Mean': mean
                })
    chart = pd.DataFrame(chart)
    chart[column] = chart[column].astype(str)
    plt.figure(figsize=(16, 9))
    position = -0.75
    ax = sns.barplot(
        chart,
        x=column,
        y='Mean',
        hue='Metric',
        palette='crest'
    )
    for idx, metric in enumerate(chart['Metric'].unique()):
        columns = chart[chart['Metric'] == metric]
        row = columns.loc[columns['Mean'].idxmax()]
        value = row['Mean']
        center = (
            ax.patches[
                chart.index.get_loc(row.name)
            ].get_x() +
            ax.patches[
                chart.index.get_loc(row.name)
            ].get_width() / 2
        )
        if metric == 'F2-PPS':
            ax.plot(
                [center, position],
                [value, value],
                color='black',
                linestyle='--',
                linewidth=0.5
            )
            ax.text(
                x=position,
                y=value,
                s=f'{value:.3f}',
                ha='right',
                va='center',
                fontsize=10
            )
    plt.title(
        f'{title} Performance Distributions',
        fontsize=15
    )
    plt.xlabel(
        column,
        fontsize=10
    )
    plt.ylabel(
        'Metric Value',
        fontsize=10
    )
    plt.legend(
        title=f'Metric',
        bbox_to_anchor=(1.05, 1),
        loc='upper left'
    )
    ax.set_xticklabels(
        ax.get_xticklabels(),
        rotation=45,
        ha="right",
        rotation_mode='anchor'
    )
    plt.ylim(
        bottom=min(
            chart['Mean']
        )
    )
    plt.tight_layout()
    plt.savefig(
        f'{output}/{title.lower().replace(" ", "-")}-performance-plot.png',
        dpi=300,
        bbox_inches='tight'
    )
    plt.show()
    return data

# %% [markdown]
# * Select the **K-Nearest Neighbors Classifier Parameters** with the *highest performance at the lower bound of the confidence interval*

# %%
base = select(
    dir = os.path.join(output, f'ranks.csv'),
    title = "SOTA K-Nearest Neighbors Classifier Parameters",
    column = 'K-Nearest Neighbors Parameters',
    output = output,
    main = ['K-Nearest Neighbors Parameters'],
    order = order,
    model = None
)
